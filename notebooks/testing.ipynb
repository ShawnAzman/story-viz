# %% [markdown]
# ## format txt file

# %%
def split_long_lines(filename, folder="scripts", max_length=80):
    # Open the file for reading
    with open(folder + "/" + filename, 'r') as file:
        lines = file.readlines()

    new_lines = []
    
    # Iterate through each line
    for line in lines:
        while len(line) > max_length:
            # Find the last space before the max_length
            split_index = line[:max_length].rfind(' ')
            if split_index == -1:
                split_index = max_length  # No space found, split at max_length
                
            # Append the portion of the line up to the split point
            new_lines.append(line[:split_index].strip() + '\n')
            
            # Continue processing the rest of the line
            line = line[split_index:].strip()
        
        new_lines.append(line + '\n')  # Add the rest of the line (if any) or short lines directly

    # remove any lines that are 'XXX'
    new_lines = [line for line in new_lines if line.strip() != 'XXX']
    
    # Write the modified lines back to the file or a new file
    with open(folder + '/split_' + filename, 'w') as file:
        file.writelines(new_lines)

# %%
split_long_lines('threads.txt')

# %%
import re 

def remove_extra_newlines(filename, folder):
    # Open the file for reading
    with open(folder + "/" + filename, 'r') as file:
        lines = file.read()
    
    # Replace 3+ newlines with just 2 newlines
    cleaned_lines = re.sub(r'\n{3,}', '\n\n', lines)

    # Write the cleaned content back to the file (or a new file)
    with open(folder + "/" + filename, 'w') as file:
        file.write(cleaned_lines)

# %%
remove_extra_newlines('split_threads.txt', 'scripts')

# %% [markdown]
# ## character/location counting

# %%
# read in json
import json

with open('json/threads/story_outline.json', 'r') as file:
    story_outline = json.load(file)

scenes = story_outline['scenes']
chapters = story_outline['chapters']
characters = story_outline['characters']
locations = story_outline['locations']

# %%
# count how many scenes each character is in per chapter
character_scene_count = {}

for scene in scenes:
    chapter = scene['chapter']  # Ensure this is a string or integer
    if chapter not in character_scene_count:
        character_scene_count[chapter] = {}
        
    for character in scene['characters']:
        character_name = character['name']  # Extract a unique identifier from the character dictionary
        if character_name not in character_scene_count[chapter]:
            character_scene_count[chapter][character_name] = 1
        else:
            character_scene_count[chapter][character_name] += 1

character_scene_count
# Out:
# {'Chapter 1': {'Elara': 3, 'Grandmother Nira': 1, 'Tomis': 1, 'Adena': 1},
#  'Chapter 2': {'The Traveler (Iskra)': 3,
#   'Tavern Keeper Edric': 1,
#   'Elara': 2},
#  'Chapter 3': {'Elara': 3, 'Grandmother Nira': 1, 'Lysa': 1},
#  'Chapter 4': {'Elara': 3, 'Mayor Felin': 2, 'Liza': 2, 'Rurik': 2},
#  'Chapter 5': {'Elara': 3, 'Galen': 1, 'Daria': 1, 'Jarek': 1, 'Rurik': 1},
#  'Chapter 6': {'Elara': 4,
#   'Maelis': 3,
#   'Grandmother Nira': 1,
#   'Grandmaster Theron': 1,
#   'Acolyte Sarin': 1},
#  'Chapter 7': {'Elara': 3,
#   'Maelis': 1,
#   'Acolyte Sarin': 1,
#   'Grandmaster Theron': 1,
#   'Mistress Valeria': 2},
#  'Chapter 8': {'Elara': 4,
#   'Mayor Felin': 1,
#   'Rurik': 1,
#   'Daria': 1,
#   'The Traveler (Iskra)': 1,
#   'Maelis': 1},
#  'Chapter 9': {'Elara': 4,
#   'Maelis': 2,
#   'Rurik': 3,
#   'Daria': 1,
#   'Mayor Felin': 1},
#  'Chapter 10': {'Grandmaster Theron': 1,
#   'Maelis': 4,
#   'Acolyte Sarin': 1,
#   'Elara': 3,
#   'Mistress Valeria': 3,
#   'Rurik': 1,
#   'Mayor Felin': 1},
#  'Chapter 11': {'Elara': 4,
#   'Maelis': 3,
#   'Grandmaster Theron': 2,
#   'Acolyte Sarin': 2,
#   'Mistress Valeria': 2},
#  'Chapter 12': {'Elara': 4,
#   'Mistress Valeria': 1,
#   'Acolyte Sarin': 1,
#   'Grandmaster Theron': 1,
#   'Maelis': 1,
#   'Lysa': 2}}

# %%
# repeat for locations
location_scene_count = {}

for scene in scenes:
    chapter = scene['chapter']
    if chapter not in location_scene_count:
        location_scene_count[chapter] = {}
        
    location_name = scene['location']
    if location_name not in location_scene_count[chapter]:
        location_scene_count[chapter][location_name] = 1
    else:
        location_scene_count[chapter][location_name] += 1

location_scene_count
# Out:
# {'Chapter 1': {"Elara's Cottage": 2, 'The Village Market': 1},
#  'Chapter 2': {'The Tavern': 1,
#   "Elara's Cottage": 1,
#   'The Nearby Village (Glenth)': 1},
#  'Chapter 3': {"Elara's Cottage": 2, 'The Forest Shrine': 1},
#  'Chapter 4': {'Village Square': 2, 'The Wheat Fields': 1},
#  'Chapter 5': {"Elara's Cottage": 2, 'Village Square': 1},
#  'Chapter 6': {'Village Square': 1,
#   "Elara's Cottage": 1,
#   'The Guild Hall (Seren)': 1,
#   'The Forest Shrine': 1},
#  'Chapter 7': {'The Guild Hall (Seren)': 2, 'The Hall of Threads': 1},
#  'Chapter 8': {'Village Square': 2,
#   'The Forest Shrine': 1,
#   "Elara's Cottage": 1},
#  'Chapter 9': {"Elara's Cottage": 1,
#   'The Wheat Fields': 2,
#   'Village Square': 1},
#  'Chapter 10': {'The Guild Hall (Seren)': 1, 'The Wheat Fields': 3},
#  'Chapter 11': {'The Hidden Loom Chamber': 4},
#  'Chapter 12': {'The Hidden Loom Chamber': 2, "Elara's Cottage": 2}}

# %%
# update counts in chapter json object
for chapter in chapters:
    chap_characters = chapter['characters']
    chap_locations = chapter['locations']
    chap_name = chapter['chapter'].split(':')[0]

    for character in chap_characters:
        chap_characters[character]['count'] = character_scene_count[chap_name][character]
    
    for location in chap_locations:
        chap_locations[location]['count'] = location_scene_count[chap_name][location]

# %%
chapters
# Out:
# [{'chapter': "Chapter 1: The Weaver's Gift",
#   'summary': 'Elara discovers her mysterious power to weave fate.',
#   'description': 'Introduce Elara, a young seamstress in a quiet village, who discovers her powers while weaving a tapestry. The threads seem to guide her hands, hinting at her unique gift of weaving fate.',
#   'importance': 0.58,
#   'conflict': 0.33,
#   'scenes': 3,
#   'locations': {"Elara's Cottage": {'role': 'A small home and weaving studio.',
#     'count': 2},
#    'The Village Market': {'role': 'A lively center where Elara sells her tapestries and interacts with villagers.',
#     'count': 1}},
#   'characters': {'Elara': {'role': 'Protagonist, young seamstress discovering her powers.',
#     'count': 3},
#    'Grandmother Nira': {'role': "Elara's wise and stern grandmother, keeper of the family's weaving traditions.",
#     'count': 1},
#    'Tomis': {'role': "Elara's childhood friend and local farmer, providing support but also skeptical of magic.",
#     'count': 1},
#    'Adena': {'role': 'A village elder who commissions tapestries from Elara.',
#     'count': 1}}},
#  {'chapter': 'Chapter 2: The Mysterious Customer',
#   'summary': 'A strange traveler commissions a future-predicting tapestry from Elara.',
#   'description': 'A mysterious traveler arrives in the village and asks Elara to weave a tapestry showing the future. The prophecy of a nearby village burning comes true, causing unease.',
#   'importance': 0.42,
#   'conflict': 0.42,
#   'scenes': 3,
#   'locations': {'The Tavern': {'role': "The village's main social hub where Iskra arrives, creating curiosity.",
#     'count': 1},
#    'The Nearby Village (Glenth)': {'role': "The village that burns after Elara's first prophecy tapestry.",
#     'count': 1},
#    "Elara's Cottage": {'role': "Setting for the mysterious commission and the revelation of the prophecy's fulfillment.",
#     'count': 1}},
#   'characters': {'The Traveler (Iskra)': {'role': 'A mysterious customer who commissions a tapestry showing the future, later revealed to be a rogue guild member.',
#     'count': 3},
#    'Tavern Keeper Edric': {'role': 'Owner of the village tavern where the traveler stays.',
#     'count': 1},
#    'Elara': {'role': 'Reluctantly uses her newfound powers to fulfill a mysterious commission, leading to unforeseen consequences.',
#     'count': 2}}},
#  {'chapter': 'Chapter 3: Threads of Fate',
#   'summary': "Elara learns about her family's fate-weaving heritage.",
#   'description': "Elara's grandmother reveals the family's secret heritage: the ability to weave fate. Elara grapples with the weight of this discovery and her role in shaping destinies.",
#   'importance': 0.33,
#   'conflict': 0.25,
#   'scenes': 3,
#   'locations': {"Elara's Cottage": {'role': 'Setting for a deep conversation between Elara and her grandmother about fate-weaving.',
#     'count': 2},
#    'The Forest Shrine': {'role': 'A hidden, mystical spot outside the village where Elara goes to reflect on her powers.',
#     'count': 1}},
#   'characters': {'Grandmother Nira': {'role': "Reveals the family's secret heritage.",
#     'count': 1},
#    'Lysa': {'role': "Elara's younger sister, who is curious but unaware of the family's powers.",
#     'count': 1},
#    'Elara': {'role': "Learns of her family's fate-weaving legacy and struggles with the weight of her newfound power.",
#     'count': 3}}},
#  {'chapter': 'Chapter 4: A Village in Peril',
#   'summary': 'Strange events plague the village, and Elara is blamed.',
#   'description': 'Strange and disastrous events affect the village, leading to growing distrust toward Elara as the villagers suspect her magic is causing the problems.',
#   'importance': 0.25,
#   'conflict': 0.17,
#   'scenes': 3,
#   'locations': {'Village Square': {'role': 'The center of town where rumors about Elara spread and tensions rise.',
#     'count': 2},
#    'The Wheat Fields': {'role': 'Crops wither, causing unrest among the villagers.',
#     'count': 1}},
#   'characters': {'Mayor Felin': {'role': "The village leader who becomes increasingly suspicious of Elara's powers.",
#     'count': 2},
#    'Rurik': {'role': 'A hot-headed blacksmith who stirs up distrust against Elara after the strange events begin.',
#     'count': 2},
#    'Liza': {'role': 'A healer who notices the strange events in the village and suspects magical interference.',
#     'count': 2},
#    'Elara': {'role': 'Becomes the target of suspicion and blame as strange events plague the village, with even trusted villagers questioning her powers.',
#     'count': 3}}},
#  {'chapter': 'Chapter 5: The Tapestry of Lives',
#   'summary': 'Elara experiments with small weavings to change village life.',
#   'description': 'Elara tests her powers by weaving small changes that subtly influence the lives of her neighbors. She sees both positive and unintended consequences of her actions.',
#   'importance': 0.67,
#   'conflict': 0.58,
#   'scenes': 3,
#   'locations': {"Elara's Cottage": {'role': 'Where Elara experiments with small weavings that affect her neighbors.',
#     'count': 2},
#    'Village Square': {'role': "Continues to be a hotspot of gossip and changes after Elara's interventions.",
#     'count': 1}},
#   'characters': {'Elara': {'role': 'As she experiments with her powers, she interacts more with villagers.',
#     'count': 3},
#    'Galen': {'role': "A sickly child whose recovery after Elara's weaving brings joy but also suspicion.",
#     'count': 1},
#    'Daria': {'role': "Galen's mother, deeply grateful to Elara.", 'count': 1},
#    'Jarek': {'role': "A local merchant whose petty disputes with his neighbor are soothed by Elara's subtle fate-weaving.",
#     'count': 1},
#    'Rurik': {'role': "Grows increasingly suspicious of Elara's powers, viewing her subtle manipulations with anger and distrust.",
#     'count': 1}}},
#  {'chapter': "Chapter 6: The Guild's Return",
#   'summary': "Elara meets a member of the Weaver's Guild and learns of their agenda.",
#   'description': "Elara encounters Maelis, a member of the ancient Weaver's Guild, who invites her to train with them. He reveals that the guild has been watching her family and controlling fate for generations.",
#   'importance': 0.75,
#   'conflict': 0.67,
#   'scenes': 4,
#   'locations': {'The Guild Hall (Seren)': {'role': "A hidden city where the Weaver's Guild operates. This is Elara's first exposure to the larger world of fate-weaving.",
#     'count': 1},
#    'Village Square': {'role': 'Where Maelis first approaches Elara, setting the stage for her pivotal decision.',
#     'count': 1},
#    "Elara's Cottage": {'role': 'Where Elara receives the invitation to join the guild.',
#     'count': 1},
#    'The Forest Shrine': {'role': "A place of reflection for Elara as she contemplates the guild's offer.",
#     'count': 1}},
#   'characters': {'Maelis': {'role': "A guild member sent to bring Elara into the fold. He's charismatic but hides his true intentions.",
#     'count': 3},
#    'Grandmaster Theron': {'role': "Leader of the Weaver's Guild, who sees Elara as a potential threat or asset.",
#     'count': 1},
#    'Acolyte Sarin': {'role': 'A young, eager weaver in training who befriends Elara at the guild.',
#     'count': 1},
#    'Elara': {'role': "Faces a pivotal choice as she is invited to join the Weaver's Guild, torn between her village and the allure of mastering her powers.",
#     'count': 4}}},
#  {'chapter': "Chapter 7: The Guild's Secrets",
#   'summary': "Elara learns about the guild's dark control over fate.",
#   'description': 'Elara begins her training at the guild and discovers the dark truth: the guild has been manipulating entire kingdoms through their fate-weaving. She becomes conflicted about their methods.',
#   'importance': 0.83,
#   'conflict': 0.58,
#   'scenes': 3,
#   'locations': {'The Guild Hall (Seren)': {'role': "Various rooms in the guild where Elara learns the dark truth about the guild's history.",
#     'count': 2},
#    'The Hall of Threads': {'role': 'A mystical place within the guild where tapestries of fate for entire regions are stored.',
#     'count': 1}},
#   'characters': {'Maelis': {'role': 'Guides Elara through her training.',
#     'count': 1},
#    'Grandmaster Theron': {'role': "Reveals more about the guild's control over kingdoms.",
#     'count': 1},
#    'Acolyte Sarin': {'role': "A supportive figure during Elara's training.",
#     'count': 1},
#    'Mistress Valeria': {'role': "A powerful guild member who secretly opposes the guild's manipulation and starts mentoring Elara.",
#     'count': 2},
#    'Elara': {'role': "Begins her training at the Weaver's Guild, but soon learns about their dark control over fate, leading to doubts about their true intentions.",
#     'count': 3}}},
#  {'chapter': 'Chapter 8: A Fraying Pattern',
#   'summary': "Elara's efforts to fix her village start causing chaos.",
#   'description': 'Elara returns to her village and uses her powers to try to fix things, but her interventions cause even greater chaos. The guild warns her of the consequences, and villagers begin to turn against her.',
#   'importance': 0.58,
#   'conflict': 0.75,
#   'scenes': 4,
#   'locations': {'Village Square': {'role': "Chaos starts to spread as Elara's efforts to fix things backfire.",
#     'count': 2},
#    'The Forest Shrine': {'role': 'Elara visits again to seek solace and clarity.',
#     'count': 1},
#    "Elara's Cottage": {'role': 'Becomes a place of confrontation as the guild sends Maelis to warn her against interfering further with fate.',
#     'count': 1}},
#   'characters': {'Elara': {'role': "Returns to her village, struggling with what she's learned.",
#     'count': 4},
#    'The Traveler (Iskra)': {'role': 'Reappears and warns Elara of further consequences.',
#     'count': 1},
#    'Mayor Felin': {'role': "Grows increasingly suspicious of Elara's power.",
#     'count': 1},
#    'Rurik': {'role': 'Begins to rally villagers against Elara.', 'count': 1},
#    'Daria': {'role': "Grateful for Elara's help, but now confused by the worsening situation in the village.",
#     'count': 1},
#    'Maelis': {'role': 'Sent by the guild to warn Elara of the consequences of her actions.',
#     'count': 1}}},
#  {'chapter': 'Chapter 9: The Unraveling',
#   'summary': "Elara's powers spiral out of control as the village falls apart.",
#   'description': 'As Elara tries to weave solutions, her powers spiral out of control, causing chaos in the village. She realizes that she cannot fix everything, and the guild sends Maelis to confront her.',
#   'importance': 0.92,
#   'conflict': 0.92,
#   'scenes': 4,
#   'locations': {'The Wheat Fields': {'role': 'The scene of a dramatic confrontation as crops fail and tensions erupt into violence.',
#     'count': 2},
#    'Village Square': {'role': 'A pivotal location where the villagers accuse Elara of causing their misfortunes.',
#     'count': 1},
#    "Elara's Cottage": {'role': 'A place of refuge and reflection for Elara as she struggles with her powers.',
#     'count': 1}},
#   'characters': {'Elara': {'role': 'Her powers spiral out of control as she tries to save her village.',
#     'count': 4},
#    'Maelis': {'role': 'Returns to warn Elara that her actions are causing irreparable damage.',
#     'count': 2},
#    'Rurik': {'role': 'Leads a group of villagers to confront Elara directly.',
#     'count': 3},
#    'Daria': {'role': 'Torn between her trust in Elara and fear of the growing chaos.',
#     'count': 1},
#    'Mayor Felin': {'role': "Caught between loyalty to the village and fear of Elara's powers.",
#     'count': 1}}},
#  {'chapter': 'Chapter 10: Threads of War',
#   'summary': "Elara faces the guild's enforcers as conflict erupts.",
#   'description': 'The guild declares war on Elara for threatening their control over fate. Maelis leads enforcers to stop her, while Mistress Valeria helps her escape. A final confrontation looms.',
#   'importance': 0.75,
#   'conflict': 1.0,
#   'scenes': 4,
#   'locations': {'The Guild Hall (Seren)': {'role': "The location of the guild's leadership, where the decision to confront Elara is made.",
#     'count': 1},
#    'The Wheat Fields': {'role': 'A battleground as guild enforcers and villagers clash.',
#     'count': 3}},
#   'characters': {'Elara': {'role': 'Now viewed as both a savior and a threat by different factions.',
#     'count': 3},
#    'Maelis': {'role': "Leads the guild's enforcers to stop Elara.",
#     'count': 4},
#    'Grandmaster Theron': {'role': 'Declares war on Elara for threatening the balance of fate.',
#     'count': 1},
#    'Mistress Valeria': {'role': "Sides with Elara and helps her escape the guild's enforcers.",
#     'count': 3},
#    'Mayor Felin': {'role': "Caught between loyalty to the village and fear of Elara's powers.",
#     'count': 1},
#    'Rurik': {'role': 'Becomes a key antagonist, leading the village against Elara.',
#     'count': 1},
#    'Acolyte Sarin': {'role': 'Torn between loyalty to the guild and friendship with Elara.',
#     'count': 1}}},
#  {'chapter': 'Chapter 11: The Loom of Creation',
#   'summary': 'Elara discovers the ancient loom that controls fate.',
#   'description': "Elara discovers the ancient loom beneath her village, capable of controlling the world's fate. She faces a pivotal decision: whether to wield its power or destroy it.",
#   'importance': 1.0,
#   'conflict': 0.83,
#   'scenes': 4,
#   'locations': {'The Hidden Loom Chamber': {'role': 'Beneath the village, the ancient loom that controls fate is revealed.',
#     'count': 4}},
#   'characters': {'Elara': {'role': 'Makes the ultimate decision about the loom.',
#     'count': 4},
#    'Maelis': {'role': 'Tries to convince Elara to use the loom for control.',
#     'count': 3},
#    'Mistress Valeria': {'role': "Encourages Elara to destroy the loom and free the world from the guild's control.",
#     'count': 2},
#    'Acolyte Sarin': {'role': 'Appears to offer Elara one final chance to join the guild.',
#     'count': 2},
#    'Grandmaster Theron': {'role': 'Watches as Elara makes her final choice.',
#     'count': 2}}},
#  {'chapter': 'Chapter 12: A New Pattern',
#   'summary': "Elara rewrites fate and frees the world from the guild's control.",
#   'description': "Elara makes her final choice, using the loom one last time to rewrite the world's relationship with fate. The guild is disbanded, and Elara returns to her village to live a simpler life.",
#   'importance': 1.0,
#   'conflict': 0.67,
#   'scenes': 4,
#   'locations': {'The Hidden Loom Chamber': {'role': 'The final confrontation and resolution.',
#     'count': 2},
#    "Elara's Cottage": {'role': 'After the loom is destroyed, Elara returns to her home for a quiet life.',
#     'count': 2}},
#   'characters': {'Elara': {'role': 'Uses the loom one final time, shaping the future.',
#     'count': 4},
#    'Mistress Valeria': {'role': "Witnesses Elara's final choice and supports her decision.",
#     'count': 1},
#    'Maelis': {'role': "Defeated and leaves, realizing the guild's power is no more.",
#     'count': 1},
#    'Lysa': {'role': "Elara's sister, representing Elara's desire to return to a simpler life.",
#     'count': 2},
#    'Acolyte Sarin': {'role': "Chooses to follow Elara's path rather than the guild's control.",
#     'count': 1},
#    'Grandmaster Theron': {'role': "Accepts the end of the guild's reign and the rise of a new era.",
#     'count': 1}}}]

# %%
# update json file
with open('json/threads/story_outline.json', 'w') as file:
    new_outline = {}
    new_outline['chapters'] = chapters
    new_outline['scenes'] = scenes
    new_outline['characters'] = characters
    new_outline['locations'] = locations
    json.dump(new_outline, file, indent=4)

# %%
print(len(scenes))
print(len(characters))
print(len(locations))
print(len(chapters))
# Out:
# 42
# 17
# 10
# 12

# %% [markdown]
# ## rank by importance and conflict

# %%
# rank each scene by importance
# and within each scene, the characters

for i, chapter in enumerate(chapters):
    importances = []
    conflicts = []

    chap_name = chapter["chapter"].split(":")[0]
    
    # extract importance from each scene
    for j, scene in enumerate(scenes):
        if scene["chapter"] != chap_name:
            continue
        importances.append((j, scene["importance"]))
        conflicts.append((j, scene["conflict"]))
        # now extract character importances
        character_importances = []
        for k, character in enumerate(scene["characters"]):
            character_importances.append((k, character["importance"]))
        # sort character importances
        sorted_character_importances = sorted(character_importances, key=lambda x: x[1], reverse=True)
        # add importance_rank to each character
        for k, (l, _) in enumerate(sorted_character_importances):
            scenes[j]["characters"][l]["importance_rank"] = k+1
        # add number of each scene
        scenes[j]["number"] = j+1
    # sort importances
    sorted_importances = sorted(importances, key=lambda x: x[1], reverse=True)
    # add importance_rank to each scene
    for k, (j, _) in enumerate(sorted_importances):
        scenes[j]["importance_rank"] = k+1
    # sort conflicts
    sorted_conflicts = sorted(conflicts, key=lambda x: x[1], reverse=True)
    # add conflict_rank to each scene
    for k, (j, _) in enumerate(sorted_conflicts):
        scenes[j]["conflict_rank"] = k+1
    
    # print results
    # for j, scene in enumerate(scenes):
    #     print(scenes[j]["title"], scenes[j]["importance_rank"])
    #     print("--------------------------------")
    #     for k, character in enumerate(scene["characters"]):
    #         print(character["name"], character["importance_rank"])
    #     print()

# %%
scenes
# Out:
# [{'title': "Elara's Mysterious Weaving",
#   'number': 1,
#   'summary': 'Elara begins weaving a tapestry and discovers her power to weave fate.',
#   'chapter': 'Chapter 1',
#   'location': "Elara's Cottage",
#   'importance': 0.9,
#   'conflict': 0.3,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Curious, slightly overwhelmed',
#     'sentiment': 0.7,
#     'importance_rank': 1}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': 'A Visit from Grandmother Nira',
#   'number': 2,
#   'summary': 'Grandmother Nira checks on Elara, offering subtle advice and warnings.',
#   'chapter': 'Chapter 1',
#   'location': "Elara's Cottage",
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 0.8,
#     'emotion': 'Conflicted, curious',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Grandmother Nira',
#     'role': 'Mentor',
#     'importance': 0.7,
#     'emotion': 'Stern, concerned',
#     'sentiment': 0,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': 'The Village Market',
#   'number': 3,
#   'summary': 'Elara goes to the village market and interacts with villagers while selling her tapestries.',
#   'chapter': 'Chapter 1',
#   'location': 'The Village Market',
#   'importance': 0.5,
#   'conflict': 0.2,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 0.7,
#     'emotion': 'Neutral, thoughtful',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Tomis',
#     'role': 'Friend',
#     'importance': 0.5,
#     'emotion': 'Friendly, skeptical',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Adena',
#     'role': 'Customer',
#     'importance': 0.3,
#     'emotion': 'Pleasant, curious',
#     'sentiment': 0.6,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Arrival of the Mysterious Traveler',
#   'number': 4,
#   'summary': 'A mysterious traveler arrives in the village and creates curiosity among the villagers.',
#   'chapter': 'Chapter 2',
#   'location': 'The Tavern',
#   'importance': 0.7,
#   'conflict': 0.4,
#   'characters': [{'name': 'The Traveler (Iskra)',
#     'role': 'Antagonist',
#     'importance': 1,
#     'emotion': 'Mysterious, guarded',
#     'sentiment': 0,
#     'importance_rank': 1},
#    {'name': 'Tavern Keeper Edric',
#     'role': 'Villager',
#     'importance': 0.4,
#     'emotion': 'Curious, cautious',
#     'sentiment': 0.3,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'The Commission',
#   'number': 5,
#   'summary': 'The traveler commissions a tapestry from Elara, asking her to weave the future.',
#   'chapter': 'Chapter 2',
#   'location': "Elara's Cottage",
#   'importance': 0.9,
#   'conflict': 0.6,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Anxious, intrigued',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'The Traveler (Iskra)',
#     'role': 'Antagonist',
#     'importance': 0.8,
#     'emotion': 'Demanding, mysterious',
#     'sentiment': -0.1,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'The Prophecy Unfolds',
#   'number': 6,
#   'summary': "The nearby village of Glenth burns down, fulfilling the prophecy of Elara's tapestry.",
#   'chapter': 'Chapter 2',
#   'location': 'The Nearby Village (Glenth)',
#   'importance': 1,
#   'conflict': 0.8,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Shocked, fearful',
#     'sentiment': -0.3,
#     'importance_rank': 1},
#    {'name': 'The Traveler (Iskra)',
#     'role': 'Antagonist',
#     'importance': 0.6,
#     'emotion': 'Satisfied, secretive',
#     'sentiment': 0,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': "Grandmother's Revelation",
#   'number': 7,
#   'summary': "Elara's grandmother reveals the family's secret power of fate-weaving.",
#   'chapter': 'Chapter 3',
#   'location': "Elara's Cottage",
#   'importance': 1,
#   'conflict': 0.5,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Shocked, confused',
#     'sentiment': -0.1,
#     'importance_rank': 1},
#    {'name': 'Grandmother Nira',
#     'role': 'Mentor',
#     'importance': 0.9,
#     'emotion': 'Stern, resolved',
#     'sentiment': 0.2,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Burden of Destiny',
#   'number': 8,
#   'summary': 'Elara grapples with the weight of her newfound responsibility in shaping destinies.',
#   'chapter': 'Chapter 3',
#   'location': 'The Forest Shrine',
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Overwhelmed, contemplative',
#     'sentiment': -0.2,
#     'importance_rank': 1}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': "Lysa's Curiosity",
#   'number': 9,
#   'summary': "Elara's younger sister, Lysa, becomes curious about her family's secret.",
#   'chapter': 'Chapter 3',
#   'location': "Elara's Cottage",
#   'importance': 0.6,
#   'conflict': 0.2,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 0.7,
#     'emotion': 'Guarded, protective',
#     'sentiment': 0,
#     'importance_rank': 1},
#    {'name': 'Lysa',
#     'role': 'Sister',
#     'importance': 0.4,
#     'emotion': 'Curious, innocent',
#     'sentiment': 0.5,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Strange Events Unfold',
#   'number': 10,
#   'summary': 'Mysterious events begin to plague the village, causing unease among the villagers.',
#   'chapter': 'Chapter 4',
#   'location': 'Village Square',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Anxious, concerned',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Mayor Felin',
#     'role': 'Village Leader',
#     'importance': 0.5,
#     'emotion': 'Suspicious, wary',
#     'sentiment': -0.3,
#     'importance_rank': 2},
#    {'name': 'Liza',
#     'role': 'Healer',
#     'importance': 0.4,
#     'emotion': 'Cautious, observant',
#     'sentiment': -0.1,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'The Withering Fields',
#   'number': 11,
#   'summary': "The village's wheat fields wither, raising tensions and suspicion toward Elara's powers.",
#   'chapter': 'Chapter 4',
#   'location': 'The Wheat Fields',
#   'importance': 1,
#   'conflict': 0.7,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Defensive, frustrated',
#     'sentiment': -0.4,
#     'importance_rank': 1},
#    {'name': 'Rurik',
#     'role': 'Villager',
#     'importance': 0.6,
#     'emotion': 'Angry, distrustful',
#     'sentiment': -0.6,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': 'Confrontation in the Square',
#   'number': 12,
#   'summary': "Villagers openly confront Elara, blaming her magic for the village's troubles.",
#   'chapter': 'Chapter 4',
#   'location': 'Village Square',
#   'importance': 1,
#   'conflict': 0.9,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Hurt, defensive',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Mayor Felin',
#     'role': 'Village Leader',
#     'importance': 0.8,
#     'emotion': 'Suspicious, assertive',
#     'sentiment': -0.4,
#     'importance_rank': 3},
#    {'name': 'Rurik',
#     'role': 'Antagonist',
#     'importance': 0.9,
#     'emotion': 'Hostile, confrontational',
#     'sentiment': -0.7,
#     'importance_rank': 2},
#    {'name': 'Liza',
#     'role': 'Healer',
#     'importance': 0.5,
#     'emotion': 'Concerned, cautious',
#     'sentiment': -0.2,
#     'importance_rank': 4}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': "Elara's Experimentation",
#   'number': 13,
#   'summary': 'Elara begins experimenting with her powers by weaving small changes that affect her neighbors.',
#   'chapter': 'Chapter 5',
#   'location': "Elara's Cottage",
#   'importance': 1,
#   'conflict': 0.6,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Curious, determined',
#     'sentiment': 0.4,
#     'importance_rank': 1}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': "Galen's Recovery",
#   'number': 14,
#   'summary': "Elara's fate-weaving helps a sickly child, Galen, recover, bringing joy to his family but suspicion to others.",
#   'chapter': 'Chapter 5',
#   'location': "Elara's Cottage",
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Hopeful, cautious',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Galen',
#     'role': 'Sick Child',
#     'importance': 0.7,
#     'emotion': 'Grateful, weak',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'Daria',
#     'role': "Galen's Mother",
#     'importance': 0.6,
#     'emotion': 'Grateful, relieved',
#     'sentiment': 0.7,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Subtle Manipulations',
#   'number': 15,
#   'summary': 'Elara weaves small changes that ease tensions between villagers but faces unintended consequences.',
#   'chapter': 'Chapter 5',
#   'location': 'Village Square',
#   'importance': 0.9,
#   'conflict': 0.7,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Worried, conflicted',
#     'sentiment': 0.1,
#     'importance_rank': 1},
#    {'name': 'Jarek',
#     'role': 'Merchant',
#     'importance': 0.5,
#     'emotion': 'Surprised, relieved',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'Rurik',
#     'role': 'Villager',
#     'importance': 0.4,
#     'emotion': 'Suspicious, angry',
#     'sentiment': -0.5,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': 'The Arrival of Maelis',
#   'number': 16,
#   'summary': "Maelis, a member of the Weaver's Guild, arrives in the village to meet Elara and offer her a chance to train with the guild.",
#   'chapter': 'Chapter 6',
#   'location': 'Village Square',
#   'importance': 0.9,
#   'conflict': 0.6,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Curious, cautious',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Maelis',
#     'role': 'Guild Recruiter',
#     'importance': 0.9,
#     'emotion': 'Charming, persuasive',
#     'sentiment': 0.4,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': "The Guild's Invitation",
#   'number': 17,
#   'summary': "Maelis reveals that the Weaver's Guild has been watching Elara's family for generations and invites her to join them.",
#   'chapter': 'Chapter 6',
#   'location': "Elara's Cottage",
#   'importance': 1,
#   'conflict': 0.7,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Conflicted, intrigued',
#     'sentiment': 0,
#     'importance_rank': 1},
#    {'name': 'Maelis',
#     'role': 'Guild Recruiter',
#     'importance': 1,
#     'emotion': 'Confident, secretive',
#     'sentiment': 0.1,
#     'importance_rank': 2},
#    {'name': 'Grandmother Nira',
#     'role': 'Mentor',
#     'importance': 0.6,
#     'emotion': 'Worried, cautious',
#     'sentiment': -0.2,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': "The Guild's True Power",
#   'number': 18,
#   'summary': "Elara meets Grandmaster Theron and Acolyte Sarin, learning about the guild's influence and her potential role in it.",
#   'chapter': 'Chapter 6',
#   'location': 'The Guild Hall (Seren)',
#   'importance': 1,
#   'conflict': 0.8,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Awed, uncertain',
#     'sentiment': 0,
#     'importance_rank': 1},
#    {'name': 'Grandmaster Theron',
#     'role': 'Guild Leader',
#     'importance': 0.8,
#     'emotion': 'Authoritative, calculating',
#     'sentiment': -0.3,
#     'importance_rank': 2},
#    {'name': 'Acolyte Sarin',
#     'role': 'Supportive Ally',
#     'importance': 0.5,
#     'emotion': 'Friendly, eager',
#     'sentiment': 0.5,
#     'importance_rank': 4},
#    {'name': 'Maelis',
#     'role': 'Guild Recruiter',
#     'importance': 0.7,
#     'emotion': 'Secretive, persuasive',
#     'sentiment': 0,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': 'The Decision',
#   'number': 19,
#   'summary': "Elara contemplates the guild's offer, torn between her responsibilities to the village and the allure of learning more about her powers.",
#   'chapter': 'Chapter 6',
#   'location': 'The Forest Shrine',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Conflicted, thoughtful',
#     'sentiment': 0,
#     'importance_rank': 1}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Entering the Guild',
#   'number': 20,
#   'summary': "Elara officially joins the Weaver's Guild and begins her training under Maelis's guidance.",
#   'chapter': 'Chapter 7',
#   'location': 'The Guild Hall (Seren)',
#   'importance': 1,
#   'conflict': 0.6,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Eager, uncertain',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Maelis',
#     'role': 'Guild Mentor',
#     'importance': 0.8,
#     'emotion': 'Confident, controlling',
#     'sentiment': 0,
#     'importance_rank': 2},
#    {'name': 'Acolyte Sarin',
#     'role': 'Supportive Ally',
#     'importance': 0.5,
#     'emotion': 'Friendly, encouraging',
#     'sentiment': 0.6,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 3},
#  {'title': 'The Hall of Threads',
#   'number': 21,
#   'summary': 'Elara explores the Hall of Threads and discovers that the guild has been manipulating entire kingdoms through their fate-weaving.',
#   'chapter': 'Chapter 7',
#   'location': 'The Hall of Threads',
#   'importance': 1,
#   'conflict': 0.8,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Shocked, conflicted',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Grandmaster Theron',
#     'role': 'Guild Leader',
#     'importance': 0.7,
#     'emotion': 'Authoritative, secretive',
#     'sentiment': -0.3,
#     'importance_rank': 2},
#    {'name': 'Mistress Valeria',
#     'role': 'Secret Mentor',
#     'importance': 0.5,
#     'emotion': 'Cautious, subversive',
#     'sentiment': 0,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': 'Doubts and Mentorship',
#   'number': 22,
#   'summary': "Mistress Valeria privately reveals her opposition to the guild's methods and begins mentoring Elara in secret.",
#   'chapter': 'Chapter 7',
#   'location': 'The Guild Hall (Seren)',
#   'importance': 0.9,
#   'conflict': 0.7,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Conflicted, determined',
#     'sentiment': 0,
#     'importance_rank': 1},
#    {'name': 'Mistress Valeria',
#     'role': 'Secret Mentor',
#     'importance': 0.8,
#     'emotion': 'Supportive, rebellious',
#     'sentiment': 0.2,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 2},
#  {'title': 'Elara Returns to the Village',
#   'number': 23,
#   'summary': 'Elara returns to her village, attempting to use her powers to fix the growing unrest and strange events.',
#   'chapter': 'Chapter 8',
#   'location': 'Village Square',
#   'importance': 0.9,
#   'conflict': 0.6,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Determined, hopeful',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Mayor Felin',
#     'role': 'Village Leader',
#     'importance': 0.5,
#     'emotion': 'Suspicious, frustrated',
#     'sentiment': -0.3,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 4},
#  {'title': 'Chaos Spreads',
#   'number': 24,
#   'summary': "Elara's attempts to weave solutions backfire, causing chaos in the village as tensions and distrust rise.",
#   'chapter': 'Chapter 8',
#   'location': 'Village Square',
#   'importance': 1,
#   'conflict': 0.9,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Overwhelmed, desperate',
#     'sentiment': -0.4,
#     'importance_rank': 1},
#    {'name': 'Rurik',
#     'role': 'Antagonist',
#     'importance': 0.7,
#     'emotion': 'Angry, confrontational',
#     'sentiment': -0.6,
#     'importance_rank': 2},
#    {'name': 'Daria',
#     'role': 'Villager',
#     'importance': 0.5,
#     'emotion': 'Confused, worried',
#     'sentiment': -0.2,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Warning from Iskra',
#   'number': 25,
#   'summary': 'The Traveler (Iskra) reappears, warning Elara about the dangerous consequences of her actions.',
#   'chapter': 'Chapter 8',
#   'location': 'The Forest Shrine',
#   'importance': 0.8,
#   'conflict': 0.7,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Anxious, hesitant',
#     'sentiment': -0.3,
#     'importance_rank': 1},
#    {'name': 'The Traveler (Iskra)',
#     'role': 'Mysterious Mentor',
#     'importance': 0.6,
#     'emotion': 'Cautious, foreboding',
#     'sentiment': -0.1,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 3},
#  {'title': "The Guild's Warning",
#   'number': 26,
#   'summary': 'The guild sends a warning to Elara, cautioning her against further interference with fate.',
#   'chapter': 'Chapter 8',
#   'location': "Elara's Cottage",
#   'importance': 0.9,
#   'conflict': 0.8,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Frustrated, defiant',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Maelis',
#     'role': 'Guild Representative',
#     'importance': 0.7,
#     'emotion': 'Authoritative, threatening',
#     'sentiment': -0.3,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 2},
#  {'title': 'Power Out of Control',
#   'number': 27,
#   'summary': "Elara's fate-weaving spirals out of control as she tries to fix the village's growing disasters.",
#   'chapter': 'Chapter 9',
#   'location': "Elara's Cottage",
#   'importance': 1,
#   'conflict': 0.9,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Desperate, overwhelmed',
#     'sentiment': -0.6,
#     'importance_rank': 1},
#    {'name': 'Maelis',
#     'role': 'Guild Representative',
#     'importance': 0.7,
#     'emotion': 'Frustrated, disappointed',
#     'sentiment': -0.4,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 2},
#  {'title': 'Confrontation in the Wheat Fields',
#   'number': 28,
#   'summary': 'Elara faces a violent confrontation with the villagers as her powers continue to spiral, and crops fail.',
#   'chapter': 'Chapter 9',
#   'location': 'The Wheat Fields',
#   'importance': 1,
#   'conflict': 1,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Terrified, cornered',
#     'sentiment': -0.7,
#     'importance_rank': 1},
#    {'name': 'Rurik',
#     'role': 'Antagonist',
#     'importance': 0.9,
#     'emotion': 'Angry, violent',
#     'sentiment': -0.8,
#     'importance_rank': 2},
#    {'name': 'Daria',
#     'role': 'Villager',
#     'importance': 0.6,
#     'emotion': 'Confused, fearful',
#     'sentiment': -0.5,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': "Maelis's Confrontation",
#   'number': 29,
#   'summary': 'Maelis arrives to confront Elara, warning her that her powers are doing more harm than good and threatening the fabric of fate.',
#   'chapter': 'Chapter 9',
#   'location': 'The Wheat Fields',
#   'importance': 0.9,
#   'conflict': 0.9,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Defensive, defeated',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Maelis',
#     'role': 'Guild Representative',
#     'importance': 0.9,
#     'emotion': 'Authoritative, forceful',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Rurik',
#     'role': 'Antagonist',
#     'importance': 0.7,
#     'emotion': 'Vindictive, aggressive',
#     'sentiment': -0.7,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': "The Villagers' Accusation",
#   'number': 30,
#   'summary': 'The villagers accuse Elara of being the source of their misfortune, threatening to expel her from the village.',
#   'chapter': 'Chapter 9',
#   'location': 'Village Square',
#   'importance': 0.8,
#   'conflict': 0.9,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Betrayed, devastated',
#     'sentiment': -0.7,
#     'importance_rank': 1},
#    {'name': 'Mayor Felin',
#     'role': 'Village Leader',
#     'importance': 0.7,
#     'emotion': 'Suspicious, decisive',
#     'sentiment': -0.5,
#     'importance_rank': 2},
#    {'name': 'Rurik',
#     'role': 'Antagonist',
#     'importance': 0.6,
#     'emotion': 'Hostile, determined',
#     'sentiment': -0.8,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'The Guild Declares War',
#   'number': 31,
#   'summary': "The Weaver's Guild declares war on Elara, with Grandmaster Theron ordering Maelis to lead the charge to stop her.",
#   'chapter': 'Chapter 10',
#   'location': 'The Guild Hall (Seren)',
#   'importance': 1,
#   'conflict': 1,
#   'characters': [{'name': 'Grandmaster Theron',
#     'role': 'Guild Leader',
#     'importance': 0.9,
#     'emotion': 'Determined, cold',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Maelis',
#     'role': 'Guild Representative',
#     'importance': 0.8,
#     'emotion': 'Conflicted, forceful',
#     'sentiment': -0.3,
#     'importance_rank': 2},
#    {'name': 'Acolyte Sarin',
#     'role': 'Supportive Ally',
#     'importance': 0.4,
#     'emotion': 'Worried, loyal',
#     'sentiment': 0,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': "Valeria's Aid",
#   'number': 32,
#   'summary': "Mistress Valeria helps Elara escape the guild's enforcers, encouraging her to prepare for a final confrontation.",
#   'chapter': 'Chapter 10',
#   'location': 'The Wheat Fields',
#   'importance': 0.9,
#   'conflict': 0.8,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Determined, conflicted',
#     'sentiment': 0,
#     'importance_rank': 1},
#    {'name': 'Mistress Valeria',
#     'role': 'Secret Mentor',
#     'importance': 0.8,
#     'emotion': 'Supportive, rebellious',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Maelis',
#     'role': 'Guild Representative',
#     'importance': 0.6,
#     'emotion': 'Torn, authoritative',
#     'sentiment': -0.2,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'Battle in the Wheat Fields',
#   'number': 33,
#   'summary': "The guild's enforcers clash with the villagers and Elara as tensions erupt into open conflict.",
#   'chapter': 'Chapter 10',
#   'location': 'The Wheat Fields',
#   'importance': 1,
#   'conflict': 1,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Furious, desperate',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Maelis',
#     'role': 'Guild Representative',
#     'importance': 0.7,
#     'emotion': 'Determined, frustrated',
#     'sentiment': -0.3,
#     'importance_rank': 2},
#    {'name': 'Rurik',
#     'role': 'Antagonist',
#     'importance': 0.7,
#     'emotion': 'Angry, vengeful',
#     'sentiment': -0.8,
#     'importance_rank': 3},
#    {'name': 'Mistress Valeria',
#     'role': 'Secret Mentor',
#     'importance': 0.6,
#     'emotion': 'Resigned, supportive',
#     'sentiment': 0.1,
#     'importance_rank': 4},
#    {'name': 'Mayor Felin',
#     'role': 'Village Leader',
#     'importance': 0.6,
#     'emotion': 'Worried, conflicted',
#     'sentiment': -0.4,
#     'importance_rank': 5}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': "Elara's Decision",
#   'number': 34,
#   'summary': 'Elara makes a pivotal decision: to fight or flee as the conflict threatens to tear apart both the village and the guild.',
#   'chapter': 'Chapter 10',
#   'location': 'The Wheat Fields',
#   'importance': 1,
#   'conflict': 1,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Determined, resolute',
#     'sentiment': 0,
#     'importance_rank': 1},
#    {'name': 'Mistress Valeria',
#     'role': 'Secret Mentor',
#     'importance': 0.7,
#     'emotion': 'Supportive, solemn',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Maelis',
#     'role': 'Guild Representative',
#     'importance': 0.6,
#     'emotion': 'Conflicted, authoritative',
#     'sentiment': -0.3,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'The Loom is Revealed',
#   'number': 35,
#   'summary': "Elara discovers the ancient Loom of Creation beneath her village, capable of controlling the world's fate.",
#   'chapter': 'Chapter 11',
#   'location': 'The Hidden Loom Chamber',
#   'importance': 1,
#   'conflict': 0.8,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Awe, fear',
#     'sentiment': 0,
#     'importance_rank': 1},
#    {'name': 'Maelis',
#     'role': 'Guild Representative',
#     'importance': 0.7,
#     'emotion': 'Cautious, persuasive',
#     'sentiment': -0.3,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 3},
#  {'title': "The Guild's Final Plea",
#   'number': 36,
#   'summary': "Maelis and Grandmaster Theron try to convince Elara to use the Loom to maintain the guild's control over fate.",
#   'chapter': 'Chapter 11',
#   'location': 'The Hidden Loom Chamber',
#   'importance': 1,
#   'conflict': 0.9,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Defiant, conflicted',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Maelis',
#     'role': 'Guild Representative',
#     'importance': 0.8,
#     'emotion': 'Desperate, persuasive',
#     'sentiment': -0.4,
#     'importance_rank': 3},
#    {'name': 'Grandmaster Theron',
#     'role': 'Guild Leader',
#     'importance': 0.9,
#     'emotion': 'Cold, manipulative',
#     'sentiment': -0.5,
#     'importance_rank': 2},
#    {'name': 'Acolyte Sarin',
#     'role': 'Supportive Ally',
#     'importance': 0.6,
#     'emotion': 'Conflicted, hesitant',
#     'sentiment': 0,
#     'importance_rank': 4}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': "Valeria's Final Stand",
#   'number': 37,
#   'summary': "Mistress Valeria arrives and urges Elara to destroy the Loom and break the guild's control over fate.",
#   'chapter': 'Chapter 11',
#   'location': 'The Hidden Loom Chamber',
#   'importance': 0.9,
#   'conflict': 0.8,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Determined, resolute',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Mistress Valeria',
#     'role': 'Secret Mentor',
#     'importance': 0.7,
#     'emotion': 'Urgent, protective',
#     'sentiment': 0.4,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'The Final Decision',
#   'number': 38,
#   'summary': "Elara faces the ultimate choice: wield the Loom's power or destroy it to free the world from the guild's control.",
#   'chapter': 'Chapter 11',
#   'location': 'The Hidden Loom Chamber',
#   'importance': 1,
#   'conflict': 1,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Resigned, determined',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Maelis',
#     'role': 'Guild Representative',
#     'importance': 0.8,
#     'emotion': 'Desperate, pleading',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Grandmaster Theron',
#     'role': 'Guild Leader',
#     'importance': 0.8,
#     'emotion': 'Furious, panicked',
#     'sentiment': -0.6,
#     'importance_rank': 3},
#    {'name': 'Mistress Valeria',
#     'role': 'Secret Mentor',
#     'importance': 0.6,
#     'emotion': 'Hopeful, supportive',
#     'sentiment': 0.5,
#     'importance_rank': 4},
#    {'name': 'Acolyte Sarin',
#     'role': 'Supportive Ally',
#     'importance': 0.5,
#     'emotion': 'Nervous, conflicted',
#     'sentiment': 0,
#     'importance_rank': 5}],
#   'importance_rank': 3,
#   'conflict_rank': 1},
#  {'title': 'Rewriting Fate',
#   'number': 39,
#   'summary': "Elara uses the Loom one final time to rewrite the world's relationship with fate, freeing it from the guild's control.",
#   'chapter': 'Chapter 12',
#   'location': 'The Hidden Loom Chamber',
#   'importance': 1,
#   'conflict': 0.9,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Resolute, hopeful',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Mistress Valeria',
#     'role': 'Secret Mentor',
#     'importance': 0.7,
#     'emotion': 'Supportive, proud',
#     'sentiment': 0.6,
#     'importance_rank': 2},
#    {'name': 'Acolyte Sarin',
#     'role': 'Supportive Ally',
#     'importance': 0.5,
#     'emotion': 'Awed, relieved',
#     'sentiment': 0.3,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'The Disbanding of the Guild',
#   'number': 40,
#   'summary': 'With the Loom destroyed, the guild loses its power over fate, and Grandmaster Theron leaves in defeat.',
#   'chapter': 'Chapter 12',
#   'location': 'The Hidden Loom Chamber',
#   'importance': 1,
#   'conflict': 0.7,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Triumphant, reflective',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Grandmaster Theron',
#     'role': 'Guild Leader',
#     'importance': 0.8,
#     'emotion': 'Bitter, defeated',
#     'sentiment': -0.7,
#     'importance_rank': 2},
#    {'name': 'Maelis',
#     'role': 'Guild Representative',
#     'importance': 0.6,
#     'emotion': 'Resigned, contemplative',
#     'sentiment': -0.3,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'A Return to Simplicity',
#   'number': 41,
#   'summary': 'Elara returns to her cottage and village, leaving behind her powers and the responsibilities of fate-weaving.',
#   'chapter': 'Chapter 12',
#   'location': "Elara's Cottage",
#   'importance': 0.9,
#   'conflict': 0.3,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Peaceful, content',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Lysa',
#     'role': 'Sister',
#     'importance': 0.6,
#     'emotion': 'Curious, joyful',
#     'sentiment': 0.8,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 3},
#  {'title': 'A New Beginning',
#   'number': 42,
#   'summary': 'Elara embraces her new life, free from the burden of fate-weaving, with hope for the future.',
#   'chapter': 'Chapter 12',
#   'location': "Elara's Cottage",
#   'importance': 1,
#   'conflict': 0.1,
#   'characters': [{'name': 'Elara',
#     'role': 'Protagonist',
#     'importance': 1,
#     'emotion': 'Hopeful, fulfilled',
#     'sentiment': 0.9,
#     'importance_rank': 1},
#    {'name': 'Lysa',
#     'role': 'Sister',
#     'importance': 0.7,
#     'emotion': 'Happy, curious',
#     'sentiment': 0.8,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 4}]

# %%
# update json file
with open('json/threads/story_outline.json', 'w') as file:
    new_outline = {
        "title": "Threads of the Infinite",
        "type": "Book",
        "author": "ChatGPT",
        "year": 2024,
        "url": "https://www.gutenberg.org/ebooks/84",
        "image": "https://images.penguinrandomhouse.com/cover/9780143131847",
        "num_chapters": 12,
        "num_scenes": 60,
        "num_characters": 17,
        "num_locations": 13,
    }
    new_outline['chapters'] = chapters
    new_outline['scenes'] = scenes
    new_outline['characters'] = characters
    new_outline['locations'] = locations
    json.dump(new_outline, file, indent=4)
