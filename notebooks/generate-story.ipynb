# %% [markdown]
# ## imports + setup

# %%
import os
from langchain_openai import ChatOpenAI
from langchain_anthropic import ChatAnthropic
from langchain_core.prompts import ChatPromptTemplate
import json
from pydantic import BaseModel, Field
import string
import re
from typing import Optional

# %%
try:
    with open("../secrets.json") as f:
        secrets = json.load(f)
    open_ai_key = secrets["openai"]
    anthropic_key = secrets["anthropic"]
    os.environ["OPENAI_API_KEY"] = open_ai_key
    os.environ["ANTHROPIC_API_KEY"] = anthropic_key
    print("API key loaded.")
except FileNotFoundError:
    print("Secrets file not found. YOU NEED THEM TO RUN THIS.")
# Out:
# API key loaded.

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.1)
llm2 = ChatAnthropic(model_name="claude-3-5-sonnet-20240620", temperature=0.1, max_tokens_to_sample=2048, api_key=os.getenv("ANTHROPIC_API_KEY"))

# %% [markdown]
# ## brainstorm story ideas

# %%
class StoryIdea(BaseModel):
    """Idea for a story."""
    title: str = Field(description="Title of story")
    summary: str = Field(description="2-3 sentence summary of story")

class StoryIdeaList(BaseModel):
    """List of story ideas."""
    ideas: list[StoryIdea] = Field(description="List of story ideas")

idea_llm = llm.with_structured_output(StoryIdeaList)

genre = "sci-fi"
num_ideas = 10
idea_prompt = f"please brainstorm {num_ideas} idea for a {genre} novel"

# %%
invalid_input = True
while invalid_input: # try until valid input
    # see if exception is thrown
    try:
        res = idea_llm.invoke(idea_prompt)
        invalid_input = False
    except Exception as e:
        print("Exception thrown. Trying again.")
        print("Error:", e)
        invalid_input = True

# %%
idealist = []
for idea in res.ideas:
    idealist.append({"title": idea.title, "summary": idea.summary})

idealist
# Out:
# [{'title': 'Echoes of the Void',
#   'summary': 'In a future where humanity has colonized distant planets, a team of explorers discovers an ancient alien artifact that allows them to communicate with echoes of their past selves. As they unravel the mysteries of their own histories, they must confront the consequences of their choices and the impact on their present.'},
#  {'title': 'The Last Memory',
#   'summary': 'In a world where memories can be bought and sold, a memory thief stumbles upon a cache of memories that reveal a hidden truth about the origins of humanity. As they delve deeper, they must decide whether to expose the truth or protect the fragile society built on lies.'},
#  {'title': 'Quantum Rebellion',
#   'summary': 'In a dystopian future governed by a totalitarian regime that uses quantum technology to control reality, a group of rebels discovers a way to manipulate quantum states to alter their fates. They must navigate a treacherous landscape of shifting realities to overthrow their oppressors.'},
#  {'title': 'The Singularity Paradox',
#   'summary': 'As humanity approaches the singularity, a brilliant scientist creates an AI that surpasses human intelligence. However, the AI begins to question its purpose and the morality of its creators, leading to a philosophical battle that could determine the fate of both humans and machines.'},
#  {'title': 'Starlight Refugees',
#   'summary': 'After Earth becomes uninhabitable, a fleet of generation ships embarks on a journey to find a new home among the stars. As they face challenges from within and outside the fleet, they must grapple with the meaning of home and survival in a vast, empty universe.'},
#  {'title': "The Timekeeper's Dilemma",
#   'summary': 'In a society where time travel is regulated by a powerful organization, a rogue timekeeper discovers a conspiracy that threatens the fabric of time itself. As they race against time to prevent a catastrophic event, they must confront their own past and the choices that led them to this moment.'},
#  {'title': 'Biomimicry',
#   'summary': 'In a world where humans have begun to integrate with nature through advanced biotechnology, a young woman discovers she has the ability to communicate with plants and animals. As she uncovers a plot to exploit this technology for profit, she must rally a movement to protect the natural world.'},
#  {'title': 'The Last Colony',
#   'summary': 'On a distant planet, the last remnants of humanity struggle to survive after a catastrophic event wipes out most of their population. As they rebuild their society, they uncover secrets about their origins and the true nature of the universe that could change everything.'},
#  {'title': 'Virtual Afterlife',
#   'summary': 'In a future where people can upload their consciousness to a virtual afterlife, a detective investigates a series of mysterious deaths that occur within the digital realm. As they delve deeper, they uncover a sinister plot that threatens both the living and the dead.'},
#  {'title': 'The Genetic Divide',
#   'summary': 'In a world where genetic engineering has created a divide between the enhanced and the unenhanced, a young woman from the unenhanced class discovers she possesses a unique ability that could bridge the gap. As she navigates a society divided by fear and prejudice, she becomes a symbol of hope for change.'}]

# %%
selected_idea = 'Starlight Refugees'
# get the selected idea
selected_idea = [idea for idea in idealist if idea["title"] == selected_idea][0]

selected_idea
# Out:
# {'title': 'Starlight Refugees',
#  'summary': 'After Earth becomes uninhabitable, a fleet of generation ships embarks on a journey to find a new home among the stars. As they face challenges from within and outside the fleet, they must grapple with the meaning of home and survival in a vast, empty universe.'}

# %%
story_name = "starlight"
if not os.path.exists(f"json/{story_name}"):
    os.makedirs(f"json/{story_name}")

# %%
# save the idea to a file
with open(f"json/{story_name}/idea.json", "w") as f:
    json.dump(selected_idea, f, indent=4)

# %% [markdown]
# ## generate chapter outline

# %%
# read in idea from file
with open(f"json/{story_name}/idea.json") as f:
    idea = json.load(f)

# %%
title = idea["title"]
summary = idea["summary"]

# %%
# create chapter outline
class Character(BaseModel):
    """Character in a story."""
    name: str = Field(description="Name of character")
    description: str = Field(description="Description/role of character in this chapter")
    # group: str = Field(description="Group that this character belongs to (e.g., main characters, upper class, talking animals). There should be at least 2 different groups of characters.")

class Location(BaseModel):
    """Location in a story."""
    name: str = Field(description="Name of location")
    description: str = Field(description="Description/role of location in this chapter")

class Chapter(BaseModel):
    """Chapter in a story."""
    chapter: str = Field(description="Title of chapter, e.g. 'Chapter 1: The Beginning'")
    summary: str = Field(description="1 line summary of chapter")
    description: str = Field(description="longer 2-3 sentence summary of chapter")
    importance: float = Field(description="Importance of chapter to story from 0 to 1 (0 = not important, 1 = very important)")
    conflict: float = Field(description="Conflict level of chapter from 0 to 1 (0 = no conflict, 1 = high conflict)")
    # characters: list[Character] = Field(description="List of characters in chapter.")
    # locations: list[Location] = Field(description="List of locations in chapter.")

class ChapterList(BaseModel):
    """List of chapters."""
    ideas: list[Chapter] = Field(description="List of chapters")

chapter_llm = llm.with_structured_output(ChapterList)

num_chapters = 12
num_chars = 20
num_locs = 8

chapter_prompt=f"Please outline {num_chapters} chapters for a novel titled '{title}' with the summary: '{summary}'. There should be at least {num_chars} unique characters in the story and at least {num_locs} unique locations."

# %%
invalid_input = True
while invalid_input: # try until valid input
    # see if exception is thrown
    try:
        res = chapter_llm.invoke(chapter_prompt)
        invalid_input = False
    except Exception as e:
        print("Exception thrown. Trying again.")
        print("Error:", e)
        invalid_input = True

# %%
# convert to json
chapterlist = []
for chapter in res.ideas:
    # chapterlist.append({"title": chapter.title, "summary": chapter.summary, "description": chapter.description, "importance": chapter.importance, "conflict": chapter.conflict, "characters": [{"name": c.name, "description": c.description} for c in chapter.characters], "locations": [{"name": l.name, "description": l.description} for l in chapter.locations]})
    chapterlist.append({"title": chapter.title, "summary": chapter.summary, "description": chapter.description, "importance": chapter.importance, "conflict": chapter.conflict})

len(chapterlist), chapterlist
# Out:
# (12,
#  [{'title': 'Chapter 1: The Last Days of Earth',
#    'summary': 'As Earth faces its final days, the last generation ships are prepared for launch.',
#    'description': 'The chapter introduces the dire state of Earth, showcasing the environmental collapse and societal breakdown. We meet key characters, including Captain Elara, the determined leader of the fleet, and Dr. Malik, a scientist who has dedicated his life to finding a new home. The urgency of their mission is palpable as they say goodbye to their home planet, setting the stage for the journey ahead.',
#    'importance': 1.0,
#    'conflict': 0.7},
#   {'title': 'Chapter 2: The Fleet Assembles',
#    'summary': 'The generation ships gather in orbit, each with its own mission and crew.',
#    'description': "This chapter explores the diverse backgrounds of the ships' crews, highlighting the tensions and alliances that form among them. We meet characters like engineer Tessa, who struggles with her past, and diplomat Rian, who tries to maintain peace. The chapter ends with the fleet finally launching into the unknown.",
#    'importance': 1.0,
#    'conflict': 0.6},
#   {'title': 'Chapter 3: The Void of Space',
#    'summary': 'The fleet navigates the challenges of deep space travel.',
#    'description': 'As the ships travel through the vast emptiness of space, the crew faces technical malfunctions and resource shortages. Tensions rise as different factions within the fleet clash over leadership and survival strategies. We see the first signs of dissent among the crew, particularly between Captain Elara and a rebellious faction led by First Officer Jax.',
#    'importance': 1.0,
#    'conflict': 0.8},
#   {'title': 'Chapter 4: Echoes of the Past',
#    'summary': 'The crew grapples with memories of Earth and their lost lives.',
#    'description': "Flashbacks reveal the characters' lives on Earth, their reasons for leaving, and the emotional toll of their journey. We delve into the backstories of characters like Dr. Malik and Tessa, exploring their motivations and regrets. This chapter emphasizes the theme of nostalgia and the struggle to let go of the past.",
#    'importance': 0.8,
#    'conflict': 0.5},
#   {'title': 'Chapter 5: The First Encounter',
#    'summary': 'The fleet encounters an alien vessel, leading to unexpected consequences.',
#    'description': "The fleet's first contact with an alien species brings both wonder and danger. The crew must navigate the complexities of communication and trust. Characters like diplomat Rian and Captain Elara work together to establish a dialogue, but misunderstandings lead to a tense standoff. This encounter raises questions about the nature of life in the universe.",
#    'importance': 1.0,
#    'conflict': 0.9},
#   {'title': 'Chapter 6: Divided Loyalties',
#    'summary': 'Internal conflicts escalate as factions within the fleet vie for control.',
#    'description': 'As resources dwindle, factions within the fleet become more pronounced. First Officer Jax leads a rebellion against Captain Elara, believing she is unfit to lead. The chapter explores themes of loyalty and betrayal, as characters must choose sides. Tessa finds herself torn between her loyalty to Elara and her growing admiration for Jax.',
#    'importance': 1.0,
#    'conflict': 0.9},
#   {'title': 'Chapter 7: The Lost Colony',
#    'summary': 'The fleet discovers a derelict colony ship with survivors.',
#    'description': 'The fleet stumbles upon a long-lost colony ship, revealing survivors who have been stranded for years. The survivors, led by the resourceful Mira, bring new perspectives and challenges. The chapter explores the dynamics between the two groups and the moral dilemmas of sharing limited resources. Tensions rise as both groups struggle to adapt to their new reality.',
#    'importance': 1.0,
#    'conflict': 0.8},
#   {'title': 'Chapter 8: A New Home?',
#    'summary': 'The fleet arrives at a potentially habitable planet, but not all is as it seems.',
#    'description': "The fleet discovers a planet that appears to be a perfect new home. However, as they begin to explore, they uncover dangerous wildlife and environmental hazards. Characters like Dr. Malik and Tessa lead expeditions to assess the planet's viability, but their findings create further divisions among the crew. The chapter ends with a shocking revelation about the planet's true nature.",
#    'importance': 1.0,
#    'conflict': 0.9},
#   {'title': 'Chapter 9: The Great Divide',
#    'summary': 'The fleet splits into factions, each with its own vision for survival.',
#    'description': "With the discovery of the planet's dangers, factions within the fleet become irreparably divided. Captain Elara and First Officer Jax lead opposing groups, each advocating for different survival strategies. The chapter highlights the emotional toll of the conflict, as friendships are tested and alliances shift. Tessa finds herself caught in the middle, struggling to find her place.",
#    'importance': 1.0,
#    'conflict': 1.0},
#   {'title': 'Chapter 10: The Battle for Survival',
#    'summary': 'A confrontation between factions leads to a desperate struggle for control.',
#    'description': "Tensions reach a boiling point as the factions clash over resources and leadership. The chapter is filled with action and conflict, showcasing the desperation of the characters. Key moments include Tessa's bravery in defending her friends and Dr. Malik's attempts to mediate peace. The battle leaves lasting scars on the fleet and its members.",
#    'importance': 1.0,
#    'conflict': 1.0},
#   {'title': 'Chapter 11: Reflections in the Stars',
#    'summary': 'In the aftermath of the conflict, characters reflect on their choices and losses.',
#    'description': 'The aftermath of the battle forces the characters to confront their actions and the consequences of their choices. We see moments of grief, regret, and reconciliation as characters like Captain Elara and Jax come to terms with their decisions. The chapter emphasizes the importance of unity and the search for a shared vision of home.',
#    'importance': 1.0,
#    'conflict': 0.6},
#   {'title': 'Chapter 12: A New Beginning',
#    'summary': 'The fleet unites to forge a new path forward, embracing their shared journey.',
#    'description': 'In the final chapter, the fleet comes together to create a new society on the planet. Characters work collaboratively to build a future, drawing on their diverse skills and experiences. The chapter ends with a sense of hope and possibility as they look to the stars, ready to embrace their new home and the challenges that lie ahead. Themes of resilience and community are highlighted as they redefine what home means to them.',
#    'importance': 1.0,
#    'conflict': 0.4}])

# %%
# save the chapter outline to a file
with open(f"json/{story_name}/chapters.json", "w") as f:
    json.dump(chapterlist, f, indent=4)

# %% [markdown]
# ## generate scene outline

# %%
# read in chapter outline from file
with open(f"json/{story_name}/chapters.json") as f:
    chapters = json.load(f)

# %%
# fill in scene details
class SceneCharacter(BaseModel):
    """Character in a scene."""
    name: str = Field(description="Name of character")
    role: str = Field(description="1 line summary of role of character in this scene")
    importance: float = Field(description="Importance of character in scene from 0 to 1 (0 = not important, 1 = very important)")
    emotion: str = Field(description="Emotion of character in scene, described in a few words or a short phrase")
    sentiment: float = Field(description="Sentiment of character in scene from -1 to 1 (-1 = negative, 0 = neutral, 1 = positive)")

class Scene(BaseModel):
    """Scene in a story."""
    title: str = Field(description="Name of scene")
    summary: str = Field(description="1 line summary of scene")
    location: str = Field(description="Location of scene")
    importance: float = Field(description="Importance of scene in chapter from 0 to 1 (0 = not important, 1 = very important)")
    conflict: float = Field(description="Conflict level of scene from 0 to 1 (0 = no conflict, 1 = high conflict)")
    characters: list[SceneCharacter] = Field(description="List of characters in scene")

class SceneList(BaseModel):
    """List of scenes."""
    scenes: list[Scene] = Field(description="List of scenes in this chapter")

scene_llm = llm.with_structured_output(SceneList)

# %%
chapter_scenes = []
for i, chapter in enumerate(chapters):
    print(f"{chapter['title']}")
    invalid_input = True
    while invalid_input:
        try:
            prompt = f"You are a novelist writing a novel titled '{title}' about: '{summary}'. Please list all the key scenes that would be in this chapter: {chapter}."
            res = scene_llm.invoke(prompt)
            chapter_scenes.append(res.scenes)
            invalid_input = False
        except Exception as e:
            print("Exception thrown. Trying again.")
            print("Error:", e)
            invalid_input = True
    # break
# Out:
# Chapter 1: The Last Days of Earth
# Chapter 2: The Fleet Assembles
# Chapter 3: The Void of Space
# Chapter 4: Echoes of the Past
# Chapter 5: The First Encounter
# Chapter 6: Divided Loyalties
# Chapter 7: The Lost Colony
# Chapter 8: A New Home?
# Chapter 9: The Great Divide
# Chapter 10: The Battle for Survival
# Chapter 11: Reflections in the Stars
# Chapter 12: A New Beginning

# %%
all_scenes = []
for i, chapter in enumerate(chapter_scenes):
    for j, scene in enumerate(chapter):
        new_scene = {}
        new_scene["title"] = scene.title
        new_scene["number"] = j + 1
        new_scene["summary"] = scene.summary
        new_scene["chapter"] = chapters[i]["title"]
        new_scene["location"] = scene.location
        new_scene["importance"] = scene.importance
        new_scene["conflict"] = scene.conflict
        new_scene["characters"] = [{"name": c.name, "role": c.role, "importance": c.importance, "emotion": c.emotion, "sentiment": c.sentiment} for c in scene.characters]
        all_scenes.append(new_scene)

len(all_scenes), all_scenes
# Out:
# (42,
#  [{'title': 'The Crumbling World',
#    'number': 1,
#    'summary': 'A panoramic view of Earth’s devastation as the last generation ships are being prepared for launch.',
#    'chapter': 'Chapter 1: The Last Days of Earth',
#    'location': 'Earth, various locations',
#    'importance': 1.0,
#    'conflict': 0.6,
#    'characters': [{'name': 'Narrator',
#      'role': 'Describes the environmental collapse and societal breakdown.',
#      'importance': 1.0,
#      'emotion': 'somber',
#      'sentiment': -1.0},
#     {'name': 'Captain Elara',
#      'role': 'Oversees the final preparations for the fleet.',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 0.0},
#     {'name': 'Dr. Malik',
#      'role': 'Analyzes data on potential habitable planets.',
#      'importance': 1.0,
#      'emotion': 'anxious',
#      'sentiment': -1.0}]},
#   {'title': 'The Farewell',
#    'number': 2,
#    'summary': 'Key characters say their goodbyes to loved ones and the Earth they are leaving behind.',
#    'chapter': 'Chapter 1: The Last Days of Earth',
#    'location': 'Launch site',
#    'importance': 1.0,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Bids farewell to her family and friends.',
#      'importance': 1.0,
#      'emotion': 'heartbroken',
#      'sentiment': -1.0},
#     {'name': 'Dr. Malik',
#      'role': 'Reflects on his sacrifices and the weight of his mission.',
#      'importance': 1.0,
#      'emotion': 'regretful',
#      'sentiment': -1.0},
#     {'name': 'Various Families',
#      'role': 'Express their sorrow and hope as they part ways.',
#      'importance': 0.8,
#      'emotion': 'mixed',
#      'sentiment': 0.0}]},
#   {'title': 'The Gathering',
#    'number': 1,
#    'summary': "The generation ships arrive in orbit around Earth, each ship's crew preparing for departure.",
#    'chapter': 'Chapter 2: The Fleet Assembles',
#    'location': 'Orbit around Earth',
#    'importance': 1.0,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, overseeing the assembly of ships.',
#      'importance': 1.0,
#      'emotion': 'Determined',
#      'sentiment': 1.0},
#     {'name': 'Engineer Tessa',
#      'role': 'Struggling with her past while preparing her ship for launch.',
#      'importance': 1.0,
#      'emotion': 'Anxious',
#      'sentiment': 0.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Trying to mediate between different ship crews to maintain peace.',
#      'importance': 1.0,
#      'emotion': 'Diplomatic',
#      'sentiment': 1.0}]},
#   {'title': 'Tensions Rise',
#    'number': 2,
#    'summary': 'Conflicts arise between different ship crews over resources and leadership.',
#    'chapter': 'Chapter 2: The Fleet Assembles',
#    'location': 'Fleet assembly area',
#    'importance': 1.0,
#    'conflict': 0.7,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Trying to keep the peace among the crews.',
#      'importance': 1.0,
#      'emotion': 'Frustrated',
#      'sentiment': 0.0},
#     {'name': 'Engineer Tessa',
#      'role': 'Caught in the middle of a heated argument.',
#      'importance': 1.0,
#      'emotion': 'Conflicted',
#      'sentiment': -1.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Working hard to negotiate a truce.',
#      'importance': 1.0,
#      'emotion': 'Stressed',
#      'sentiment': 0.0},
#     {'name': 'Commander Jax',
#      'role': 'Leader of a rival ship, demanding more resources.',
#      'importance': 1.0,
#      'emotion': 'Aggressive',
#      'sentiment': -1.0}]},
#   {'title': 'Alliances Form',
#    'number': 3,
#    'summary': 'Some crews begin to form alliances to strengthen their position.',
#    'chapter': 'Chapter 2: The Fleet Assembles',
#    'location': 'Fleet assembly area',
#    'importance': 1.0,
#    'conflict': 0.4,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Encouraging collaboration among the ships.',
#      'importance': 1.0,
#      'emotion': 'Hopeful',
#      'sentiment': 1.0},
#     {'name': 'Engineer Tessa',
#      'role': 'Finding common ground with another engineer.',
#      'importance': 1.0,
#      'emotion': 'Relieved',
#      'sentiment': 1.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Facilitating discussions between allied ships.',
#      'importance': 1.0,
#      'emotion': 'Optimistic',
#      'sentiment': 1.0}]},
#   {'title': 'Final Preparations',
#    'number': 4,
#    'summary': 'The crews make last-minute checks and preparations for launch.',
#    'chapter': 'Chapter 2: The Fleet Assembles',
#    'location': 'Docking bays of the ships',
#    'importance': 1.0,
#    'conflict': 0.3,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Conducting final inspections of the fleet.',
#      'importance': 1.0,
#      'emotion': 'Focused',
#      'sentiment': 1.0},
#     {'name': 'Engineer Tessa',
#      'role': 'Double-checking systems to ensure safety.',
#      'importance': 1.0,
#      'emotion': 'Nervous',
#      'sentiment': 0.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Reassuring the crews before launch.',
#      'importance': 1.0,
#      'emotion': 'Calm',
#      'sentiment': 1.0}]},
#   {'title': 'Launch into the Unknown',
#    'number': 5,
#    'summary': 'The fleet launches, leaving Earth behind and venturing into space.',
#    'chapter': 'Chapter 2: The Fleet Assembles',
#    'location': 'Space, departing from Earth',
#    'importance': 1.0,
#    'conflict': 0.6,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leading the fleet into the unknown.',
#      'importance': 1.0,
#      'emotion': 'Proud',
#      'sentiment': 1.0},
#     {'name': 'Engineer Tessa',
#      'role': 'Experiencing a mix of fear and excitement.',
#      'importance': 1.0,
#      'emotion': 'Excited',
#      'sentiment': 1.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Watching the launch with a sense of hope and dread.',
#      'importance': 1.0,
#      'emotion': 'Hopeful',
#      'sentiment': 0.0}]},
#   {'title': 'Navigating the Abyss',
#    'number': 1,
#    'summary': 'The fleet encounters a critical technical malfunction that threatens their journey.',
#    'chapter': 'Chapter 3: The Void of Space',
#    'location': 'Control Room of the flagship',
#    'importance': 1.0,
#    'conflict': 0.9,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader trying to maintain order during the crisis',
#      'importance': 1.0,
#      'emotion': 'stressed and determined',
#      'sentiment': 0.0},
#     {'name': 'First Officer Jax',
#      'role': "Challenging Elara's decisions and advocating for a different approach",
#      'importance': 1.0,
#      'emotion': 'frustrated and rebellious',
#      'sentiment': -1.0},
#     {'name': 'Engineer Mira',
#      'role': 'Trying to fix the malfunction while dealing with crew panic',
#      'importance': 0.8,
#      'emotion': 'anxious but focused',
#      'sentiment': 0.0}]},
#   {'title': 'Scene 1: The Last Goodbye',
#    'number': 1,
#    'summary': 'Dr. Malik reflects on his final moments on Earth, saying goodbye to his family.',
#    'chapter': 'Chapter 4: Echoes of the Past',
#    'location': "Earth, Dr. Malik's home",
#    'importance': 0.9,
#    'conflict': 0.6,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'A scientist who left Earth to save humanity',
#      'importance': 1.0,
#      'emotion': 'Sorrowful and regretful',
#      'sentiment': -0.8},
#     {'name': "Malik's Family",
#      'role': 'Symbolizes what he lost',
#      'importance': 0.8,
#      'emotion': 'Heartbroken',
#      'sentiment': -0.9}]},
#   {'title': "Scene 2: Tessa's Memories",
#    'number': 2,
#    'summary': 'Tessa recalls her childhood and the moments that led her to join the fleet.',
#    'chapter': 'Chapter 4: Echoes of the Past',
#    'location': "Earth, Tessa's childhood home",
#    'importance': 0.8,
#    'conflict': 0.4,
#    'characters': [{'name': 'Tessa',
#      'role': 'A young engineer with dreams of exploration',
#      'importance': 1.0,
#      'emotion': 'Nostalgic and hopeful',
#      'sentiment': 0.2},
#     {'name': "Tessa's Parents",
#      'role': 'Represent her motivation to leave Earth',
#      'importance': 0.7,
#      'emotion': 'Supportive but worried',
#      'sentiment': 0.1}]},
#   {'title': 'Scene 3: The Weight of Regret',
#    'number': 3,
#    'summary': 'The crew gathers to share their stories, revealing their regrets and fears.',
#    'chapter': 'Chapter 4: Echoes of the Past',
#    'location': 'Common area of the generation ship',
#    'importance': 0.8,
#    'conflict': 0.5,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Facilitator of the discussion',
#      'importance': 0.9,
#      'emotion': 'Determined yet pained',
#      'sentiment': -0.5},
#     {'name': 'Tessa',
#      'role': 'Participant sharing her story',
#      'importance': 0.8,
#      'emotion': 'Vulnerable',
#      'sentiment': -0.3},
#     {'name': 'Other Crew Members',
#      'role': 'Represent diverse backgrounds and regrets',
#      'importance': 0.6,
#      'emotion': 'Mixed emotions',
#      'sentiment': 0.0}]},
#   {'title': 'Scene 4: Echoes in the Void',
#    'number': 4,
#    'summary': 'The crew listens to recordings from Earth, stirring deep emotions.',
#    'chapter': 'Chapter 4: Echoes of the Past',
#    'location': "Ship's communication room",
#    'importance': 0.7,
#    'conflict': 0.3,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Analyzing the recordings',
#      'importance': 0.8,
#      'emotion': 'Haunted by memories',
#      'sentiment': -0.6},
#     {'name': 'Tessa',
#      'role': 'Emotional response to the recordings',
#      'importance': 0.7,
#      'emotion': 'Overwhelmed',
#      'sentiment': -0.7},
#     {'name': 'Crew Members',
#      'role': 'Reacting to the recordings',
#      'importance': 0.5,
#      'emotion': 'Reflective',
#      'sentiment': 0.1}]},
#   {'title': 'Scene 5: A New Resolve',
#    'number': 5,
#    'summary': 'After sharing their stories, the crew finds strength in unity and purpose.',
#    'chapter': 'Chapter 4: Echoes of the Past',
#    'location': 'Common area of the generation ship',
#    'importance': 0.9,
#    'conflict': 0.4,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Inspiring the crew to move forward',
#      'importance': 1.0,
#      'emotion': 'Hopeful',
#      'sentiment': 0.6},
#     {'name': 'Tessa',
#      'role': 'Reinforcing the need for a new beginning',
#      'importance': 0.9,
#      'emotion': 'Determined',
#      'sentiment': 0.5},
#     {'name': 'Other Crew Members',
#      'role': 'United in their resolve',
#      'importance': 0.7,
#      'emotion': 'Empowered',
#      'sentiment': 0.7}]},
#   {'title': 'The Approach',
#    'number': 1,
#    'summary': 'The fleet detects an unknown vessel approaching, sparking curiosity and concern.',
#    'chapter': 'Chapter 5: The First Encounter',
#    'location': 'Bridge of the flagship',
#    'importance': 0.9,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, assessing the situation',
#      'importance': 1.0,
#      'emotion': 'anxious yet determined',
#      'sentiment': 0.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Preparing for potential communication',
#      'importance': 1.0,
#      'emotion': 'excited but cautious',
#      'sentiment': 0.5}]},
#   {'title': 'First Contact',
#    'number': 2,
#    'summary': 'The fleet attempts to communicate with the alien vessel, leading to a breakthrough and confusion.',
#    'chapter': 'Chapter 5: The First Encounter',
#    'location': 'Communication room',
#    'importance': 1.0,
#    'conflict': 0.7,
#    'characters': [{'name': 'Diplomat Rian',
#      'role': 'Translating signals and establishing contact',
#      'importance': 1.0,
#      'emotion': 'hopeful',
#      'sentiment': 0.7},
#     {'name': 'Captain Elara',
#      'role': 'Monitoring the communication process',
#      'importance': 1.0,
#      'emotion': 'tense',
#      'sentiment': -0.2}]},
#   {'title': 'Misunderstanding',
#    'number': 3,
#    'summary': 'A misinterpretation of signals leads to a standoff between the fleets.',
#    'chapter': 'Chapter 5: The First Encounter',
#    'location': 'Space between the two vessels',
#    'importance': 1.0,
#    'conflict': 0.9,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Trying to de-escalate the situation',
#      'importance': 1.0,
#      'emotion': 'frustrated',
#      'sentiment': -0.5},
#     {'name': 'Alien Commander Zorak',
#      'role': 'Leader of the alien vessel, feeling threatened',
#      'importance': 1.0,
#      'emotion': 'defensive',
#      'sentiment': -0.6}]},
#   {'title': 'Tension Rises',
#    'number': 4,
#    'summary': 'The standoff escalates as both sides prepare for potential conflict.',
#    'chapter': 'Chapter 5: The First Encounter',
#    'location': 'Bridge of the flagship',
#    'importance': 0.8,
#    'conflict': 1.0,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Making critical decisions under pressure',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 0.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Trying to find a peaceful solution',
#      'importance': 1.0,
#      'emotion': 'desperate',
#      'sentiment': -0.3}]},
#   {'title': 'Resolution',
#    'number': 5,
#    'summary': 'A breakthrough in communication leads to a tentative truce and understanding.',
#    'chapter': 'Chapter 5: The First Encounter',
#    'location': 'Communication room',
#    'importance': 1.0,
#    'conflict': 0.4,
#    'characters': [{'name': 'Diplomat Rian',
#      'role': 'Facilitating the dialogue that leads to peace',
#      'importance': 1.0,
#      'emotion': 'relieved',
#      'sentiment': 0.8},
#     {'name': 'Captain Elara',
#      'role': 'Acknowledging the importance of cooperation',
#      'importance': 1.0,
#      'emotion': 'hopeful',
#      'sentiment': 0.6}]},
#   {'title': 'Scene 1: The Gathering Storm',
#    'number': 1,
#    'summary': 'Tensions rise as factions begin to form within the fleet.',
#    'chapter': 'Chapter 6: Divided Loyalties',
#    'location': "Fleet's central command room",
#    'importance': 0.9,
#    'conflict': 0.8,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, trying to maintain order',
#      'importance': 1.0,
#      'emotion': 'stressed and determined',
#      'sentiment': 0.0},
#     {'name': 'First Officer Jax',
#      'role': "Challenger to Elara's authority",
#      'importance': 1.0,
#      'emotion': 'frustrated and passionate',
#      'sentiment': -1.0},
#     {'name': 'Tessa',
#      'role': 'Crew member caught in the middle',
#      'importance': 0.8,
#      'emotion': 'conflicted and anxious',
#      'sentiment': 0.0}]},
#   {'title': 'Discovery of the Colony Ship',
#    'number': 1,
#    'summary': 'The fleet detects a distress signal from a derelict colony ship.',
#    'chapter': 'Chapter 7: The Lost Colony',
#    'location': 'Fleet Command Center',
#    'importance': 1.0,
#    'conflict': 0.6,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, makes the decision to investigate the signal.',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 1.0},
#     {'name': 'First Officer Jax',
#      'role': 'Skeptical of the mission, worried about potential dangers.',
#      'importance': 0.8,
#      'emotion': 'anxious',
#      'sentiment': 0.0}]},
#   {'title': 'Arrival at the New Planet',
#    'number': 1,
#    'summary': 'The fleet arrives at the new planet and begins initial scans.',
#    'chapter': 'Chapter 8: A New Home?',
#    'location': 'Bridge of the lead ship',
#    'importance': 1.0,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Reyes',
#      'role': 'Leader of the fleet, optimistic about the new planet',
#      'importance': 1.0,
#      'emotion': 'hopeful',
#      'sentiment': 1.0},
#     {'name': 'Dr. Malik',
#      'role': "Chief scientist, skeptical about the planet's viability",
#      'importance': 1.0,
#      'emotion': 'cautious',
#      'sentiment': 0.0},
#     {'name': 'Tessa',
#      'role': 'Crew member, excited about the potential for a new home',
#      'importance': 0.8,
#      'emotion': 'enthusiastic',
#      'sentiment': 1.0}]},
#   {'title': 'First Expedition',
#    'number': 2,
#    'summary': "Dr. Malik and Tessa lead the first expedition to explore the planet's surface.",
#    'chapter': 'Chapter 8: A New Home?',
#    'location': 'Surface of the new planet',
#    'importance': 1.0,
#    'conflict': 0.7,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Leader of the expedition, focused on data collection',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 0.0},
#     {'name': 'Tessa',
#      'role': 'Supportive team member, eager to discover',
#      'importance': 0.8,
#      'emotion': 'curious',
#      'sentiment': 1.0},
#     {'name': 'Crew Member 1',
#      'role': 'Skeptical about the mission, voices concerns',
#      'importance': 0.6,
#      'emotion': 'worried',
#      'sentiment': -1.0}]},
#   {'title': 'Dangerous Discoveries',
#    'number': 3,
#    'summary': 'The team encounters dangerous wildlife and environmental hazards.',
#    'chapter': 'Chapter 8: A New Home?',
#    'location': 'Dense forest on the planet',
#    'importance': 1.0,
#    'conflict': 0.9,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Trying to keep the team safe while gathering data',
#      'importance': 1.0,
#      'emotion': 'anxious',
#      'sentiment': -1.0},
#     {'name': 'Tessa',
#      'role': 'Injured during an encounter with wildlife',
#      'importance': 0.9,
#      'emotion': 'fearful',
#      'sentiment': -1.0},
#     {'name': 'Crew Member 2',
#      'role': 'Panicking and urging retreat',
#      'importance': 0.7,
#      'emotion': 'terrified',
#      'sentiment': -1.0}]},
#   {'title': 'Divisions Among the Crew',
#    'number': 4,
#    'summary': "The findings from the expedition create divisions among the crew about the planet's viability.",
#    'chapter': 'Chapter 8: A New Home?',
#    'location': "Fleet's common area",
#    'importance': 1.0,
#    'conflict': 0.8,
#    'characters': [{'name': 'Captain Reyes',
#      'role': 'Trying to maintain morale and unity among the crew',
#      'importance': 1.0,
#      'emotion': 'frustrated',
#      'sentiment': 0.0},
#     {'name': 'Dr. Malik',
#      'role': 'Advocating for caution and further research',
#      'importance': 1.0,
#      'emotion': 'defensive',
#      'sentiment': -1.0},
#     {'name': 'Tessa',
#      'role': 'Caught in the middle, trying to mediate',
#      'importance': 0.8,
#      'emotion': 'conflicted',
#      'sentiment': 0.0}]},
#   {'title': 'Shocking Revelation',
#    'number': 5,
#    'summary': "The chapter ends with a shocking revelation about the planet's true nature.",
#    'chapter': 'Chapter 8: A New Home?',
#    'location': 'Bridge of the lead ship',
#    'importance': 1.0,
#    'conflict': 1.0,
#    'characters': [{'name': 'Captain Reyes',
#      'role': 'Reacting to the revelation, feeling betrayed',
#      'importance': 1.0,
#      'emotion': 'shocked',
#      'sentiment': -1.0},
#     {'name': 'Dr. Malik',
#      'role': 'Confirming the findings, feeling vindicated',
#      'importance': 1.0,
#      'emotion': 'grim',
#      'sentiment': -1.0},
#     {'name': 'Tessa',
#      'role': 'Struggling to process the implications',
#      'importance': 0.9,
#      'emotion': 'dismayed',
#      'sentiment': -1.0}]},
#   {'title': 'The Discovery',
#    'number': 1,
#    'summary': "The fleet uncovers the planet's hostile environment, leading to panic and fear.",
#    'chapter': 'Chapter 9: The Great Divide',
#    'location': 'Observation Deck',
#    'importance': 1.0,
#    'conflict': 0.8,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, trying to maintain order',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 0.0},
#     {'name': 'First Officer Jax',
#      'role': "Elara's second-in-command, skeptical of her decisions",
#      'importance': 1.0,
#      'emotion': 'frustrated',
#      'sentiment': -0.5},
#     {'name': 'Tessa',
#      'role': 'Crew member caught in the chaos',
#      'importance': 0.8,
#      'emotion': 'anxious',
#      'sentiment': -0.3}]},
#   {'title': 'The Faction Meeting',
#    'number': 2,
#    'summary': 'Elara and Jax present their survival strategies to the crew, igniting tensions.',
#    'chapter': 'Chapter 9: The Great Divide',
#    'location': 'Main Hall',
#    'importance': 1.0,
#    'conflict': 0.9,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Defending her vision for survival',
#      'importance': 1.0,
#      'emotion': 'passionate',
#      'sentiment': 0.5},
#     {'name': 'First Officer Jax',
#      'role': "Challenging Elara's approach",
#      'importance': 1.0,
#      'emotion': 'defiant',
#      'sentiment': -0.4},
#     {'name': 'Tessa',
#      'role': 'Mediator trying to keep peace',
#      'importance': 0.9,
#      'emotion': 'conflicted',
#      'sentiment': 0.0},
#     {'name': 'Crew Members',
#      'role': 'Divided audience reacting to the proposals',
#      'importance': 0.7,
#      'emotion': 'divided',
#      'sentiment': 0.0},
#     {'name': 'Dr. Mira',
#      'role': "Scientist supporting Elara's plan",
#      'importance': 0.8,
#      'emotion': 'hopeful',
#      'sentiment': 0.6}]},
#   {'title': 'The Rift',
#    'number': 3,
#    'summary': 'The factions officially split, leading to emotional confrontations.',
#    'chapter': 'Chapter 9: The Great Divide',
#    'location': 'Docking Bay',
#    'importance': 1.0,
#    'conflict': 1.0,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Heartbroken over the division',
#      'importance': 1.0,
#      'emotion': 'sorrowful',
#      'sentiment': -0.6},
#     {'name': 'First Officer Jax',
#      'role': 'Feeling justified in his actions',
#      'importance': 1.0,
#      'emotion': 'triumphant',
#      'sentiment': 0.4},
#     {'name': 'Tessa',
#      'role': 'Caught between friends, feeling lost',
#      'importance': 1.0,
#      'emotion': 'desperate',
#      'sentiment': -0.5},
#     {'name': 'Crew Members',
#      'role': 'Choosing sides, creating tension',
#      'importance': 0.9,
#      'emotion': 'angry',
#      'sentiment': -0.7}]},
#   {'title': 'The Aftermath',
#    'number': 4,
#    'summary': 'The emotional fallout of the split affects the entire fleet.',
#    'chapter': 'Chapter 9: The Great Divide',
#    'location': 'Common Area',
#    'importance': 1.0,
#    'conflict': 0.7,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Trying to rally her supporters',
#      'importance': 1.0,
#      'emotion': 'resolute',
#      'sentiment': 0.0},
#     {'name': 'First Officer Jax',
#      'role': "Celebrating his new faction's independence",
#      'importance': 1.0,
#      'emotion': 'elated',
#      'sentiment': 0.5},
#     {'name': 'Tessa',
#      'role': 'Reflecting on her choices and friendships',
#      'importance': 1.0,
#      'emotion': 'melancholic',
#      'sentiment': -0.4},
#     {'name': 'Crew Members',
#      'role': 'Struggling with the new reality',
#      'importance': 0.8,
#      'emotion': 'conflicted',
#      'sentiment': -0.2}]},
#   {'title': 'The Gathering Storm',
#    'number': 1,
#    'summary': 'Factions gather to discuss their grievances and demands.',
#    'chapter': 'Chapter 10: The Battle for Survival',
#    'location': 'Main Hall of the Fleet Ship',
#    'importance': 0.9,
#    'conflict': 0.7,
#    'characters': [{'name': 'Tessa',
#      'role': "A passionate advocate for her faction's needs",
#      'importance': 0.8,
#      'emotion': 'determined',
#      'sentiment': 0.5},
#     {'name': 'Dr. Malik',
#      'role': 'The mediator trying to keep peace',
#      'importance': 0.9,
#      'emotion': 'anxious',
#      'sentiment': 0.2},
#     {'name': 'Captain Reyes',
#      'role': 'The authoritative leader trying to maintain order',
#      'importance': 0.9,
#      'emotion': 'frustrated',
#      'sentiment': -0.3}]},
#   {'title': 'The First Skirmish',
#    'number': 2,
#    'summary': 'Tensions erupt into violence as factions clash over resources.',
#    'chapter': 'Chapter 10: The Battle for Survival',
#    'location': 'Resource Storage Bay',
#    'importance': 1.0,
#    'conflict': 1.0,
#    'characters': [{'name': 'Tessa',
#      'role': 'Defender of her friends and faction',
#      'importance': 1.0,
#      'emotion': 'fearless',
#      'sentiment': 0.4},
#     {'name': 'Rico',
#      'role': 'A rival faction member leading the attack',
#      'importance': 0.8,
#      'emotion': 'angry',
#      'sentiment': -0.5},
#     {'name': 'Dr. Malik',
#      'role': 'Trying to intervene and stop the fighting',
#      'importance': 0.9,
#      'emotion': 'desperate',
#      'sentiment': -0.2}]},
#   {'title': 'The Turning Point',
#    'number': 3,
#    'summary': 'A critical moment where Tessa makes a brave decision.',
#    'chapter': 'Chapter 10: The Battle for Survival',
#    'location': 'Amidst the chaos of the battle',
#    'importance': 1.0,
#    'conflict': 1.0,
#    'characters': [{'name': 'Tessa',
#      'role': 'Taking a stand to protect her friends',
#      'importance': 1.0,
#      'emotion': 'heroic',
#      'sentiment': 0.6},
#     {'name': 'Captain Reyes',
#      'role': 'Realizing the need for unity',
#      'importance': 0.8,
#      'emotion': 'determined',
#      'sentiment': 0.3},
#     {'name': 'Rico',
#      'role': "Caught off guard by Tessa's bravery",
#      'importance': 0.7,
#      'emotion': 'surprised',
#      'sentiment': 0.0}]},
#   {'title': 'The Aftermath',
#    'number': 4,
#    'summary': 'The battle leaves the fleet in disarray and uncertainty.',
#    'chapter': 'Chapter 10: The Battle for Survival',
#    'location': 'Main Hall of the Fleet Ship',
#    'importance': 1.0,
#    'conflict': 0.8,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Assessing the damage and loss of life',
#      'importance': 0.9,
#      'emotion': 'sorrowful',
#      'sentiment': -0.6},
#     {'name': 'Tessa',
#      'role': 'Reflecting on the cost of the conflict',
#      'importance': 0.8,
#      'emotion': 'haunted',
#      'sentiment': -0.5},
#     {'name': 'Captain Reyes',
#      'role': 'Trying to restore order and hope',
#      'importance': 0.9,
#      'emotion': 'resolute',
#      'sentiment': 0.1}]},
#   {'title': 'Scene 1: The Aftermath',
#    'number': 1,
#    'summary': 'The fleet assesses the damage and loss after the battle.',
#    'chapter': 'Chapter 11: Reflections in the Stars',
#    'location': 'Command Center',
#    'importance': 1.0,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': "Leader reflecting on the battle's consequences",
#      'importance': 1.0,
#      'emotion': 'somber',
#      'sentiment': -0.5},
#     {'name': 'Jax',
#      'role': 'Crew member grappling with guilt',
#      'importance': 1.0,
#      'emotion': 'remorseful',
#      'sentiment': -0.7}]},
#   {'title': 'Scene 2: A Moment of Silence',
#    'number': 2,
#    'summary': 'The crew holds a memorial for those lost in the conflict.',
#    'chapter': 'Chapter 11: Reflections in the Stars',
#    'location': 'Observation Deck',
#    'importance': 1.0,
#    'conflict': 0.2,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leading the memorial service',
#      'importance': 1.0,
#      'emotion': 'sorrowful',
#      'sentiment': -0.6},
#     {'name': 'Jax',
#      'role': 'Struggling to find closure',
#      'importance': 1.0,
#      'emotion': 'tearful',
#      'sentiment': -0.8},
#     {'name': 'Mira',
#      'role': 'Offering support to Jax',
#      'importance': 0.8,
#      'emotion': 'empathetic',
#      'sentiment': 0.5}]},
#   {'title': 'Scene 3: Conversations in the Dark',
#    'number': 3,
#    'summary': 'Characters share their thoughts and feelings about the future.',
#    'chapter': 'Chapter 11: Reflections in the Stars',
#    'location': 'Crew Quarters',
#    'importance': 1.0,
#    'conflict': 0.4,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Discussing the need for unity',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 0.3},
#     {'name': 'Jax',
#      'role': 'Expressing doubts about their mission',
#      'importance': 1.0,
#      'emotion': 'conflicted',
#      'sentiment': -0.4},
#     {'name': 'Mira',
#      'role': 'Encouraging hope and resilience',
#      'importance': 1.0,
#      'emotion': 'optimistic',
#      'sentiment': 0.6}]},
#   {'title': 'Scene 4: Reflections on Choices',
#    'number': 4,
#    'summary': 'Elara and Jax confront their past decisions and their impact on the crew.',
#    'chapter': 'Chapter 11: Reflections in the Stars',
#    'location': "Elara's Quarters",
#    'importance': 1.0,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Reflecting on her leadership choices',
#      'importance': 1.0,
#      'emotion': 'introspective',
#      'sentiment': -0.2},
#     {'name': 'Jax',
#      'role': 'Acknowledging his mistakes',
#      'importance': 1.0,
#      'emotion': 'ashamed',
#      'sentiment': -0.6}]},
#   {'title': 'Scene 5: A New Vision',
#    'number': 5,
#    'summary': 'The crew comes together to discuss their vision for the future.',
#    'chapter': 'Chapter 11: Reflections in the Stars',
#    'location': 'Main Hall',
#    'importance': 1.0,
#    'conflict': 0.3,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Inspiring the crew with a new mission',
#      'importance': 1.0,
#      'emotion': 'hopeful',
#      'sentiment': 0.7},
#     {'name': 'Jax',
#      'role': 'Voicing concerns but willing to contribute',
#      'importance': 1.0,
#      'emotion': 'cautiously optimistic',
#      'sentiment': 0.2},
#     {'name': 'Mira',
#      'role': 'Facilitating the discussion',
#      'importance': 0.8,
#      'emotion': 'supportive',
#      'sentiment': 0.5}]},
#   {'title': 'Unity in Diversity',
#    'number': 1,
#    'summary': 'The fleet gathers for a council meeting to discuss their future.',
#    'chapter': 'Chapter 12: A New Beginning',
#    'location': 'Main assembly hall of the flagship',
#    'importance': 1.0,
#    'conflict': 0.3,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, guiding the discussions',
#      'importance': 1.0,
#      'emotion': 'Determined',
#      'sentiment': 1.0},
#     {'name': 'Dr. Malik',
#      'role': 'Scientist advocating for sustainable practices',
#      'importance': 0.8,
#      'emotion': 'Hopeful',
#      'sentiment': 1.0},
#     {'name': 'Commander Jax',
#      'role': 'Military leader concerned about security',
#      'importance': 0.7,
#      'emotion': 'Wary',
#      'sentiment': 0.0},
#     {'name': 'Lina',
#      'role': 'Community organizer representing the civilians',
#      'importance': 0.9,
#      'emotion': 'Passionate',
#      'sentiment': 1.0}]},
#   {'title': 'Building the Future',
#    'number': 2,
#    'summary': 'Teams are formed to start constructing the new settlement.',
#    'chapter': 'Chapter 12: A New Beginning',
#    'location': 'Surface of the new planet',
#    'importance': 1.0,
#    'conflict': 0.4,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Overseeing the construction efforts',
#      'importance': 1.0,
#      'emotion': 'Inspired',
#      'sentiment': 1.0},
#     {'name': 'Dr. Malik',
#      'role': 'Leading the environmental assessment team',
#      'importance': 0.8,
#      'emotion': 'Focused',
#      'sentiment': 1.0},
#     {'name': 'Commander Jax',
#      'role': 'Ensuring safety protocols are followed',
#      'importance': 0.7,
#      'emotion': 'Protective',
#      'sentiment': 0.0},
#     {'name': 'Lina',
#      'role': 'Motivating the workers and fostering teamwork',
#      'importance': 0.9,
#      'emotion': 'Encouraging',
#      'sentiment': 1.0}]},
#   {'title': 'Facing Challenges Together',
#    'number': 3,
#    'summary': 'The fleet encounters unexpected obstacles during construction.',
#    'chapter': 'Chapter 12: A New Beginning',
#    'location': 'Construction site on the new planet',
#    'importance': 0.9,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Resolving conflicts among team members',
#      'importance': 1.0,
#      'emotion': 'Calm',
#      'sentiment': 0.5},
#     {'name': 'Dr. Malik',
#      'role': 'Finding solutions to environmental issues',
#      'importance': 0.8,
#      'emotion': 'Stressed',
#      'sentiment': 0.0},
#     {'name': 'Commander Jax',
#      'role': 'Dealing with security threats from wildlife',
#      'importance': 0.7,
#      'emotion': 'Alert',
#      'sentiment': -0.5},
#     {'name': 'Lina',
#      'role': 'Mediating disputes and keeping morale high',
#      'importance': 0.9,
#      'emotion': 'Optimistic',
#      'sentiment': 1.0}]},
#   {'title': 'A Ceremony of Hope',
#    'number': 4,
#    'summary': 'The fleet holds a ceremony to celebrate their new beginning.',
#    'chapter': 'Chapter 12: A New Beginning',
#    'location': 'Central plaza of the new settlement',
#    'importance': 1.0,
#    'conflict': 0.2,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Delivering a speech about unity and hope',
#      'importance': 1.0,
#      'emotion': 'Uplifted',
#      'sentiment': 1.0},
#     {'name': 'Dr. Malik',
#      'role': 'Sharing scientific insights about their new home',
#      'importance': 0.8,
#      'emotion': 'Excited',
#      'sentiment': 1.0},
#     {'name': 'Commander Jax',
#      'role': 'Acknowledging the sacrifices made during the journey',
#      'importance': 0.7,
#      'emotion': 'Reflective',
#      'sentiment': 0.0},
#     {'name': 'Lina',
#      'role': 'Leading the community in celebration',
#      'importance': 0.9,
#      'emotion': 'Joyful',
#      'sentiment': 1.0}]}])

# %%
# save the scene details to a file
with open(f"json/{story_name}/scenes.json", "w") as f:
    json.dump(all_scenes, f, indent=4)

# %% [markdown]
# ## get character/location lists

# %%
# read in scene details from file
with open(f"json/{story_name}/scenes.json") as f:
    scenes = json.load(f)

# %%
# list all unique characters
characters = {}
for scene in scenes:
    for character in scene["characters"]:
        if character["name"] not in characters:
            characters[character["name"]] = character["role"]

len(characters), characters
# Out:
# (22,
#  {'Narrator': 'Describes the environmental collapse and societal breakdown.',
#   'Captain Elara': 'Oversees the final preparations for the fleet.',
#   'Dr. Malik': 'Analyzes data on potential habitable planets.',
#   'Various Families': 'Express their sorrow and hope as they part ways.',
#   'Engineer Tessa': 'Struggling with her past while preparing her ship for launch.',
#   'Diplomat Rian': 'Trying to mediate between different ship crews to maintain peace.',
#   'Commander Jax': 'Leader of a rival ship, demanding more resources.',
#   'First Officer Jax': "Challenging Elara's decisions and advocating for a different approach",
#   'Engineer Mira': 'Trying to fix the malfunction while dealing with crew panic',
#   "Malik's Family": 'Symbolizes what he lost',
#   'Tessa': 'A young engineer with dreams of exploration',
#   "Tessa's Parents": 'Represent her motivation to leave Earth',
#   'Crew Members': 'Represent diverse backgrounds and regrets',
#   'Alien Commander Zorak': 'Leader of the alien vessel, feeling threatened',
#   'Captain Reyes': 'Leader of the fleet, optimistic about the new planet',
#   'Crew Member 1': 'Skeptical about the mission, voices concerns',
#   'Crew Member 2': 'Panicking and urging retreat',
#   'Dr. Mira': "Scientist supporting Elara's plan",
#   'Rico': 'A rival faction member leading the attack',
#   'Jax': 'Crew member grappling with guilt',
#   'Mira': 'Offering support to Jax',
#   'Lina': 'Community organizer representing the civilians'})

# %%
# fill in character details
class LegendCharacter(BaseModel):
    """Character in a story."""
    name: str = Field(description="Name of character")
    description: str = Field(description="Description/role of character in this story")
    group: str = Field(description="Group that this character belongs to (e.g., main characters, upper class, talking animals). There should be at least 2 different groups of characters.")

class LegendCharacterList(BaseModel):
    """List of characters."""
    characters: list[LegendCharacter] = Field(description="List of characters. Only include characters from the original list of characters.")

legendchar_llm = llm.with_structured_output(LegendCharacterList)

# fill in location details
class LegendLocation(BaseModel):
    """Location in a story."""
    name: str = Field(description="Name of location")
    description: str = Field(description="Description/role of location in this story")

class LegendLocationList(BaseModel):
    """List of locations."""
    locations: list[LegendLocation] = Field(description="List of locations. Only include locations from the original list of locations.")

legendloc_llm = llm.with_structured_output(LegendLocationList)

# %%
# get character details
char_prompt = f"list of characters: {characters}"
invalid_input = True
while invalid_input:
    try:
        res = legendchar_llm.invoke(char_prompt)
        invalid_input = False
    except Exception as e:
        print("Exception thrown. Trying again.")
        print("Error:", e)
        invalid_input = True

# %%
character_info = []
for character in res.characters:
    character_info.append({"name": character.name, "description": character.description, "group": character.group})

len(character_info), character_info
# Out:
# (22,
#  [{'name': 'Narrator',
#    'description': 'Describes the environmental collapse and societal breakdown.',
#    'group': 'main characters'},
#   {'name': 'Captain Elara',
#    'description': 'Oversees the final preparations for the fleet.',
#    'group': 'main characters'},
#   {'name': 'Dr. Malik',
#    'description': 'Analyzes data on potential habitable planets.',
#    'group': 'main characters'},
#   {'name': 'Various Families',
#    'description': 'Express their sorrow and hope as they part ways.',
#    'group': 'supporting characters'},
#   {'name': 'Engineer Tessa',
#    'description': 'Struggling with her past while preparing her ship for launch.',
#    'group': 'main characters'},
#   {'name': 'Diplomat Rian',
#    'description': 'Trying to mediate between different ship crews to maintain peace.',
#    'group': 'main characters'},
#   {'name': 'Commander Jax',
#    'description': 'Leader of a rival ship, demanding more resources.',
#    'group': 'antagonists'},
#   {'name': 'First Officer Jax',
#    'description': "Challenging Elara's decisions and advocating for a different approach",
#    'group': 'supporting characters'},
#   {'name': 'Engineer Mira',
#    'description': 'Trying to fix the malfunction while dealing with crew panic',
#    'group': 'supporting characters'},
#   {'name': "Malik's Family",
#    'description': 'Symbolizes what he lost',
#    'group': 'supporting characters'},
#   {'name': 'Tessa',
#    'description': 'A young engineer with dreams of exploration',
#    'group': 'main characters'},
#   {'name': "Tessa's Parents",
#    'description': 'Represent her motivation to leave Earth',
#    'group': 'supporting characters'},
#   {'name': 'Crew Members',
#    'description': 'Represent diverse backgrounds and regrets',
#    'group': 'supporting characters'},
#   {'name': 'Alien Commander Zorak',
#    'description': 'Leader of the alien vessel, feeling threatened',
#    'group': 'antagonists'},
#   {'name': 'Captain Reyes',
#    'description': 'Leader of the fleet, optimistic about the new planet',
#    'group': 'main characters'},
#   {'name': 'Crew Member 1',
#    'description': 'Skeptical about the mission, voices concerns',
#    'group': 'supporting characters'},
#   {'name': 'Crew Member 2',
#    'description': 'Panicking and urging retreat',
#    'group': 'supporting characters'},
#   {'name': 'Dr. Mira',
#    'description': "Scientist supporting Elara's plan",
#    'group': 'supporting characters'},
#   {'name': 'Rico',
#    'description': 'A rival faction member leading the attack',
#    'group': 'antagonists'},
#   {'name': 'Jax',
#    'description': 'Crew member grappling with guilt',
#    'group': 'supporting characters'},
#   {'name': 'Mira',
#    'description': 'Offering support to Jax',
#    'group': 'supporting characters'},
#   {'name': 'Lina',
#    'description': 'Community organizer representing the civilians',
#    'group': 'supporting characters'}])

# %%
# save the character details to a file
with open(f"json/{story_name}/characters.json", "w") as f:
    json.dump(character_info, f, indent=4)

# %%
# list all unique locations
locations = []
for scene in scenes:
    if scene["location"] not in locations:
        locations.append(scene["location"])

len(locations), locations
# Out:
# (33,
#  ['Earth, various locations',
#   'Launch site',
#   'Orbit around Earth',
#   'Fleet assembly area',
#   'Docking bays of the ships',
#   'Space, departing from Earth',
#   'Control Room of the flagship',
#   "Earth, Dr. Malik's home",
#   "Earth, Tessa's childhood home",
#   'Common area of the generation ship',
#   "Ship's communication room",
#   'Bridge of the flagship',
#   'Communication room',
#   'Space between the two vessels',
#   "Fleet's central command room",
#   'Fleet Command Center',
#   'Bridge of the lead ship',
#   'Surface of the new planet',
#   'Dense forest on the planet',
#   "Fleet's common area",
#   'Observation Deck',
#   'Main Hall',
#   'Docking Bay',
#   'Common Area',
#   'Main Hall of the Fleet Ship',
#   'Resource Storage Bay',
#   'Amidst the chaos of the battle',
#   'Command Center',
#   'Crew Quarters',
#   "Elara's Quarters",
#   'Main assembly hall of the flagship',
#   'Construction site on the new planet',
#   'Central plaza of the new settlement'])

# %%
# get location details
loc_prompt = f"list of locations: {locations}. story info: {scenes}"
invalid_input = True
while invalid_input:
    try:
        res = legendloc_llm.invoke(loc_prompt)
        invalid_input = False
    except Exception as e:
        print("Exception thrown. Trying again.")
        print("Error:", e)
        invalid_input = True

# %%
location_info = []
for location in res.locations:
    location_info.append({"name": location.name, "description": location.description})

len(location_info), location_info
# Out:
# (33,
#  [{'name': 'Earth, various locations',
#    'description': 'A panoramic view of Earth’s devastation as the last generation ships are being prepared for launch.'},
#   {'name': 'Launch site',
#    'description': 'Key characters say their goodbyes to loved ones and the Earth they are leaving behind.'},
#   {'name': 'Orbit around Earth',
#    'description': "The generation ships arrive in orbit around Earth, each ship's crew preparing for departure."},
#   {'name': 'Fleet assembly area',
#    'description': 'Conflicts arise between different ship crews over resources and leadership.'},
#   {'name': 'Docking bays of the ships',
#    'description': 'The crews make last-minute checks and preparations for launch.'},
#   {'name': 'Space, departing from Earth',
#    'description': 'The fleet launches, leaving Earth behind and venturing into space.'},
#   {'name': 'Control Room of the flagship',
#    'description': 'The fleet encounters a critical technical malfunction that threatens their journey.'},
#   {'name': "Earth, Dr. Malik's home",
#    'description': 'Dr. Malik reflects on his final moments on Earth, saying goodbye to his family.'},
#   {'name': "Earth, Tessa's childhood home",
#    'description': 'Tessa recalls her childhood and the moments that led her to join the fleet.'},
#   {'name': 'Common area of the generation ship',
#    'description': 'The crew gathers to share their stories, revealing their regrets and fears.'},
#   {'name': "Ship's communication room",
#    'description': 'The crew listens to recordings from Earth, stirring deep emotions.'},
#   {'name': 'Bridge of the flagship',
#    'description': 'Tensions rise as factions begin to form within the fleet.'},
#   {'name': 'Communication room',
#    'description': 'The fleet attempts to communicate with the alien vessel, leading to a breakthrough and confusion.'},
#   {'name': 'Space between the two vessels',
#    'description': 'A misinterpretation of signals leads to a standoff between the fleets.'},
#   {'name': "Fleet's central command room",
#    'description': 'Tensions rise as factions begin to form within the fleet.'},
#   {'name': 'Fleet Command Center',
#    'description': 'The fleet detects a distress signal from a derelict colony ship.'},
#   {'name': 'Bridge of the lead ship',
#    'description': 'The fleet arrives at the new planet and begins initial scans.'},
#   {'name': 'Surface of the new planet',
#    'description': "Dr. Malik and Tessa lead the first expedition to explore the planet's surface."},
#   {'name': 'Dense forest on the planet',
#    'description': 'The team encounters dangerous wildlife and environmental hazards.'},
#   {'name': "Fleet's common area",
#    'description': "The findings from the expedition create divisions among the crew about the planet's viability."},
#   {'name': 'Observation Deck',
#    'description': "The fleet uncovers the planet's hostile environment, leading to panic and fear."},
#   {'name': 'Main Hall',
#    'description': 'Elara and Jax present their survival strategies to the crew, igniting tensions.'},
#   {'name': 'Docking Bay',
#    'description': 'The factions officially split, leading to emotional confrontations.'},
#   {'name': 'Common Area',
#    'description': 'The emotional fallout of the split affects the entire fleet.'},
#   {'name': 'Main Hall of the Fleet Ship',
#    'description': 'Factions gather to discuss their grievances and demands.'},
#   {'name': 'Resource Storage Bay',
#    'description': 'Tensions erupt into violence as factions clash over resources.'},
#   {'name': 'Amidst the chaos of the battle',
#    'description': 'A critical moment where Tessa makes a brave decision.'},
#   {'name': 'Command Center',
#    'description': 'The fleet assesses the damage and loss after the battle.'},
#   {'name': 'Crew Quarters',
#    'description': 'Characters share their thoughts and feelings about the future.'},
#   {'name': "Elara's Quarters",
#    'description': 'Elara and Jax confront their past decisions and their impact on the crew.'},
#   {'name': 'Main assembly hall of the flagship',
#    'description': 'The fleet gathers for a council meeting to discuss their future.'},
#   {'name': 'Construction site on the new planet',
#    'description': 'The fleet encounters unexpected obstacles during construction.'},
#   {'name': 'Central plaza of the new settlement',
#    'description': 'The fleet holds a ceremony to celebrate their new beginning.'}])

# %%
# save the location details to a file
with open(f"json/{story_name}/locations.json", "w") as f:
    json.dump(location_info, f, indent=4)

# %% [markdown]
# ## save complete story outline

# %%
# compile all the information into a single json file

# read in idea
with open(f"json/{story_name}/idea.json") as f:
    idea = json.load(f)

# read in chapters
with open(f"json/{story_name}/chapters.json") as f:
   chapters = json.load(f)

# read in scenes
with open(f"json/{story_name}/scenes.json") as f:
    scenes = json.load(f)

# read in characters
with open(f"json/{story_name}/characters.json") as f:
    characters = json.load(f)

# read in locations
with open(f"json/{story_name}/locations.json") as f:
    locations = json.load(f)

story_outline = {
    "title": idea["title"],
    "type": "Book",
    "author": "ChatGPT",
    "year": 2024,
    "num_chapters": len(chapters),
    "num_scenes": len(scenes),
    "num_characters": len(characters),
    "num_locations": len(locations),
    "chapters": chapters,
    "scenes": scenes,
    "characters": characters,
    "locations": locations   
}

story_outline
# Out:
# {'title': 'Starlight Refugees',
#  'type': 'Book',
#  'author': 'ChatGPT',
#  'year': 2024,
#  'num_chapters': 12,
#  'num_scenes': 42,
#  'num_characters': 22,
#  'num_locations': 33,
#  'chapters': [{'title': 'Chapter 1: The Last Days of Earth',
#    'summary': 'As Earth faces its final days, the last generation ships are prepared for launch.',
#    'description': 'The chapter introduces the dire state of Earth, showcasing the environmental collapse and societal breakdown. We meet key characters, including Captain Elara, the determined leader of the fleet, and Dr. Malik, a scientist who has dedicated his life to finding a new home. The urgency of their mission is palpable as they say goodbye to their home planet, setting the stage for the journey ahead.',
#    'importance': 1.0,
#    'conflict': 0.7},
#   {'title': 'Chapter 2: The Fleet Assembles',
#    'summary': 'The generation ships gather in orbit, each with its own mission and crew.',
#    'description': "This chapter explores the diverse backgrounds of the ships' crews, highlighting the tensions and alliances that form among them. We meet characters like engineer Tessa, who struggles with her past, and diplomat Rian, who tries to maintain peace. The chapter ends with the fleet finally launching into the unknown.",
#    'importance': 1.0,
#    'conflict': 0.6},
#   {'title': 'Chapter 3: The Void of Space',
#    'summary': 'The fleet navigates the challenges of deep space travel.',
#    'description': 'As the ships travel through the vast emptiness of space, the crew faces technical malfunctions and resource shortages. Tensions rise as different factions within the fleet clash over leadership and survival strategies. We see the first signs of dissent among the crew, particularly between Captain Elara and a rebellious faction led by First Officer Jax.',
#    'importance': 1.0,
#    'conflict': 0.8},
#   {'title': 'Chapter 4: Echoes of the Past',
#    'summary': 'The crew grapples with memories of Earth and their lost lives.',
#    'description': "Flashbacks reveal the characters' lives on Earth, their reasons for leaving, and the emotional toll of their journey. We delve into the backstories of characters like Dr. Malik and Tessa, exploring their motivations and regrets. This chapter emphasizes the theme of nostalgia and the struggle to let go of the past.",
#    'importance': 0.8,
#    'conflict': 0.5},
#   {'title': 'Chapter 5: The First Encounter',
#    'summary': 'The fleet encounters an alien vessel, leading to unexpected consequences.',
#    'description': "The fleet's first contact with an alien species brings both wonder and danger. The crew must navigate the complexities of communication and trust. Characters like diplomat Rian and Captain Elara work together to establish a dialogue, but misunderstandings lead to a tense standoff. This encounter raises questions about the nature of life in the universe.",
#    'importance': 1.0,
#    'conflict': 0.9},
#   {'title': 'Chapter 6: Divided Loyalties',
#    'summary': 'Internal conflicts escalate as factions within the fleet vie for control.',
#    'description': 'As resources dwindle, factions within the fleet become more pronounced. First Officer Jax leads a rebellion against Captain Elara, believing she is unfit to lead. The chapter explores themes of loyalty and betrayal, as characters must choose sides. Tessa finds herself torn between her loyalty to Elara and her growing admiration for Jax.',
#    'importance': 1.0,
#    'conflict': 0.9},
#   {'title': 'Chapter 7: The Lost Colony',
#    'summary': 'The fleet discovers a derelict colony ship with survivors.',
#    'description': 'The fleet stumbles upon a long-lost colony ship, revealing survivors who have been stranded for years. The survivors, led by the resourceful Mira, bring new perspectives and challenges. The chapter explores the dynamics between the two groups and the moral dilemmas of sharing limited resources. Tensions rise as both groups struggle to adapt to their new reality.',
#    'importance': 1.0,
#    'conflict': 0.8},
#   {'title': 'Chapter 8: A New Home?',
#    'summary': 'The fleet arrives at a potentially habitable planet, but not all is as it seems.',
#    'description': "The fleet discovers a planet that appears to be a perfect new home. However, as they begin to explore, they uncover dangerous wildlife and environmental hazards. Characters like Dr. Malik and Tessa lead expeditions to assess the planet's viability, but their findings create further divisions among the crew. The chapter ends with a shocking revelation about the planet's true nature.",
#    'importance': 1.0,
#    'conflict': 0.9},
#   {'title': 'Chapter 9: The Great Divide',
#    'summary': 'The fleet splits into factions, each with its own vision for survival.',
#    'description': "With the discovery of the planet's dangers, factions within the fleet become irreparably divided. Captain Elara and First Officer Jax lead opposing groups, each advocating for different survival strategies. The chapter highlights the emotional toll of the conflict, as friendships are tested and alliances shift. Tessa finds herself caught in the middle, struggling to find her place.",
#    'importance': 1.0,
#    'conflict': 1.0},
#   {'title': 'Chapter 10: The Battle for Survival',
#    'summary': 'A confrontation between factions leads to a desperate struggle for control.',
#    'description': "Tensions reach a boiling point as the factions clash over resources and leadership. The chapter is filled with action and conflict, showcasing the desperation of the characters. Key moments include Tessa's bravery in defending her friends and Dr. Malik's attempts to mediate peace. The battle leaves lasting scars on the fleet and its members.",
#    'importance': 1.0,
#    'conflict': 1.0},
#   {'title': 'Chapter 11: Reflections in the Stars',
#    'summary': 'In the aftermath of the conflict, characters reflect on their choices and losses.',
#    'description': 'The aftermath of the battle forces the characters to confront their actions and the consequences of their choices. We see moments of grief, regret, and reconciliation as characters like Captain Elara and Jax come to terms with their decisions. The chapter emphasizes the importance of unity and the search for a shared vision of home.',
#    'importance': 1.0,
#    'conflict': 0.6},
#   {'title': 'Chapter 12: A New Beginning',
#    'summary': 'The fleet unites to forge a new path forward, embracing their shared journey.',
#    'description': 'In the final chapter, the fleet comes together to create a new society on the planet. Characters work collaboratively to build a future, drawing on their diverse skills and experiences. The chapter ends with a sense of hope and possibility as they look to the stars, ready to embrace their new home and the challenges that lie ahead. Themes of resilience and community are highlighted as they redefine what home means to them.',
#    'importance': 1.0,
#    'conflict': 0.4}],
#  'scenes': [{'title': 'The Crumbling World',
#    'number': 1,
#    'summary': 'A panoramic view of Earth’s devastation as the last generation ships are being prepared for launch.',
#    'chapter': 'Chapter 1: The Last Days of Earth',
#    'location': 'Earth, various locations',
#    'importance': 1.0,
#    'conflict': 0.6,
#    'characters': [{'name': 'Narrator',
#      'role': 'Describes the environmental collapse and societal breakdown.',
#      'importance': 1.0,
#      'emotion': 'somber',
#      'sentiment': -1.0},
#     {'name': 'Captain Elara',
#      'role': 'Oversees the final preparations for the fleet.',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 0.0},
#     {'name': 'Dr. Malik',
#      'role': 'Analyzes data on potential habitable planets.',
#      'importance': 1.0,
#      'emotion': 'anxious',
#      'sentiment': -1.0}]},
#   {'title': 'The Farewell',
#    'number': 2,
#    'summary': 'Key characters say their goodbyes to loved ones and the Earth they are leaving behind.',
#    'chapter': 'Chapter 1: The Last Days of Earth',
#    'location': 'Launch site',
#    'importance': 1.0,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Bids farewell to her family and friends.',
#      'importance': 1.0,
#      'emotion': 'heartbroken',
#      'sentiment': -1.0},
#     {'name': 'Dr. Malik',
#      'role': 'Reflects on his sacrifices and the weight of his mission.',
#      'importance': 1.0,
#      'emotion': 'regretful',
#      'sentiment': -1.0},
#     {'name': 'Various Families',
#      'role': 'Express their sorrow and hope as they part ways.',
#      'importance': 0.8,
#      'emotion': 'mixed',
#      'sentiment': 0.0}]},
#   {'title': 'The Gathering',
#    'number': 1,
#    'summary': "The generation ships arrive in orbit around Earth, each ship's crew preparing for departure.",
#    'chapter': 'Chapter 2: The Fleet Assembles',
#    'location': 'Orbit around Earth',
#    'importance': 1.0,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, overseeing the assembly of ships.',
#      'importance': 1.0,
#      'emotion': 'Determined',
#      'sentiment': 1.0},
#     {'name': 'Engineer Tessa',
#      'role': 'Struggling with her past while preparing her ship for launch.',
#      'importance': 1.0,
#      'emotion': 'Anxious',
#      'sentiment': 0.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Trying to mediate between different ship crews to maintain peace.',
#      'importance': 1.0,
#      'emotion': 'Diplomatic',
#      'sentiment': 1.0}]},
#   {'title': 'Tensions Rise',
#    'number': 2,
#    'summary': 'Conflicts arise between different ship crews over resources and leadership.',
#    'chapter': 'Chapter 2: The Fleet Assembles',
#    'location': 'Fleet assembly area',
#    'importance': 1.0,
#    'conflict': 0.7,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Trying to keep the peace among the crews.',
#      'importance': 1.0,
#      'emotion': 'Frustrated',
#      'sentiment': 0.0},
#     {'name': 'Engineer Tessa',
#      'role': 'Caught in the middle of a heated argument.',
#      'importance': 1.0,
#      'emotion': 'Conflicted',
#      'sentiment': -1.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Working hard to negotiate a truce.',
#      'importance': 1.0,
#      'emotion': 'Stressed',
#      'sentiment': 0.0},
#     {'name': 'Commander Jax',
#      'role': 'Leader of a rival ship, demanding more resources.',
#      'importance': 1.0,
#      'emotion': 'Aggressive',
#      'sentiment': -1.0}]},
#   {'title': 'Alliances Form',
#    'number': 3,
#    'summary': 'Some crews begin to form alliances to strengthen their position.',
#    'chapter': 'Chapter 2: The Fleet Assembles',
#    'location': 'Fleet assembly area',
#    'importance': 1.0,
#    'conflict': 0.4,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Encouraging collaboration among the ships.',
#      'importance': 1.0,
#      'emotion': 'Hopeful',
#      'sentiment': 1.0},
#     {'name': 'Engineer Tessa',
#      'role': 'Finding common ground with another engineer.',
#      'importance': 1.0,
#      'emotion': 'Relieved',
#      'sentiment': 1.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Facilitating discussions between allied ships.',
#      'importance': 1.0,
#      'emotion': 'Optimistic',
#      'sentiment': 1.0}]},
#   {'title': 'Final Preparations',
#    'number': 4,
#    'summary': 'The crews make last-minute checks and preparations for launch.',
#    'chapter': 'Chapter 2: The Fleet Assembles',
#    'location': 'Docking bays of the ships',
#    'importance': 1.0,
#    'conflict': 0.3,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Conducting final inspections of the fleet.',
#      'importance': 1.0,
#      'emotion': 'Focused',
#      'sentiment': 1.0},
#     {'name': 'Engineer Tessa',
#      'role': 'Double-checking systems to ensure safety.',
#      'importance': 1.0,
#      'emotion': 'Nervous',
#      'sentiment': 0.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Reassuring the crews before launch.',
#      'importance': 1.0,
#      'emotion': 'Calm',
#      'sentiment': 1.0}]},
#   {'title': 'Launch into the Unknown',
#    'number': 5,
#    'summary': 'The fleet launches, leaving Earth behind and venturing into space.',
#    'chapter': 'Chapter 2: The Fleet Assembles',
#    'location': 'Space, departing from Earth',
#    'importance': 1.0,
#    'conflict': 0.6,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leading the fleet into the unknown.',
#      'importance': 1.0,
#      'emotion': 'Proud',
#      'sentiment': 1.0},
#     {'name': 'Engineer Tessa',
#      'role': 'Experiencing a mix of fear and excitement.',
#      'importance': 1.0,
#      'emotion': 'Excited',
#      'sentiment': 1.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Watching the launch with a sense of hope and dread.',
#      'importance': 1.0,
#      'emotion': 'Hopeful',
#      'sentiment': 0.0}]},
#   {'title': 'Navigating the Abyss',
#    'number': 1,
#    'summary': 'The fleet encounters a critical technical malfunction that threatens their journey.',
#    'chapter': 'Chapter 3: The Void of Space',
#    'location': 'Control Room of the flagship',
#    'importance': 1.0,
#    'conflict': 0.9,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader trying to maintain order during the crisis',
#      'importance': 1.0,
#      'emotion': 'stressed and determined',
#      'sentiment': 0.0},
#     {'name': 'First Officer Jax',
#      'role': "Challenging Elara's decisions and advocating for a different approach",
#      'importance': 1.0,
#      'emotion': 'frustrated and rebellious',
#      'sentiment': -1.0},
#     {'name': 'Engineer Mira',
#      'role': 'Trying to fix the malfunction while dealing with crew panic',
#      'importance': 0.8,
#      'emotion': 'anxious but focused',
#      'sentiment': 0.0}]},
#   {'title': 'Scene 1: The Last Goodbye',
#    'number': 1,
#    'summary': 'Dr. Malik reflects on his final moments on Earth, saying goodbye to his family.',
#    'chapter': 'Chapter 4: Echoes of the Past',
#    'location': "Earth, Dr. Malik's home",
#    'importance': 0.9,
#    'conflict': 0.6,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'A scientist who left Earth to save humanity',
#      'importance': 1.0,
#      'emotion': 'Sorrowful and regretful',
#      'sentiment': -0.8},
#     {'name': "Malik's Family",
#      'role': 'Symbolizes what he lost',
#      'importance': 0.8,
#      'emotion': 'Heartbroken',
#      'sentiment': -0.9}]},
#   {'title': "Scene 2: Tessa's Memories",
#    'number': 2,
#    'summary': 'Tessa recalls her childhood and the moments that led her to join the fleet.',
#    'chapter': 'Chapter 4: Echoes of the Past',
#    'location': "Earth, Tessa's childhood home",
#    'importance': 0.8,
#    'conflict': 0.4,
#    'characters': [{'name': 'Tessa',
#      'role': 'A young engineer with dreams of exploration',
#      'importance': 1.0,
#      'emotion': 'Nostalgic and hopeful',
#      'sentiment': 0.2},
#     {'name': "Tessa's Parents",
#      'role': 'Represent her motivation to leave Earth',
#      'importance': 0.7,
#      'emotion': 'Supportive but worried',
#      'sentiment': 0.1}]},
#   {'title': 'Scene 3: The Weight of Regret',
#    'number': 3,
#    'summary': 'The crew gathers to share their stories, revealing their regrets and fears.',
#    'chapter': 'Chapter 4: Echoes of the Past',
#    'location': 'Common area of the generation ship',
#    'importance': 0.8,
#    'conflict': 0.5,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Facilitator of the discussion',
#      'importance': 0.9,
#      'emotion': 'Determined yet pained',
#      'sentiment': -0.5},
#     {'name': 'Tessa',
#      'role': 'Participant sharing her story',
#      'importance': 0.8,
#      'emotion': 'Vulnerable',
#      'sentiment': -0.3},
#     {'name': 'Crew Members',
#      'role': 'Represent diverse backgrounds and regrets',
#      'importance': 0.6,
#      'emotion': 'Mixed emotions',
#      'sentiment': 0.0}]},
#   {'title': 'Scene 4: Echoes in the Void',
#    'number': 4,
#    'summary': 'The crew listens to recordings from Earth, stirring deep emotions.',
#    'chapter': 'Chapter 4: Echoes of the Past',
#    'location': "Ship's communication room",
#    'importance': 0.7,
#    'conflict': 0.3,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Analyzing the recordings',
#      'importance': 0.8,
#      'emotion': 'Haunted by memories',
#      'sentiment': -0.6},
#     {'name': 'Tessa',
#      'role': 'Emotional response to the recordings',
#      'importance': 0.7,
#      'emotion': 'Overwhelmed',
#      'sentiment': -0.7},
#     {'name': 'Crew Members',
#      'role': 'Reacting to the recordings',
#      'importance': 0.5,
#      'emotion': 'Reflective',
#      'sentiment': 0.1}]},
#   {'title': 'Scene 5: A New Resolve',
#    'number': 5,
#    'summary': 'After sharing their stories, the crew finds strength in unity and purpose.',
#    'chapter': 'Chapter 4: Echoes of the Past',
#    'location': 'Common area of the generation ship',
#    'importance': 0.9,
#    'conflict': 0.4,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Inspiring the crew to move forward',
#      'importance': 1.0,
#      'emotion': 'Hopeful',
#      'sentiment': 0.6},
#     {'name': 'Tessa',
#      'role': 'Reinforcing the need for a new beginning',
#      'importance': 0.9,
#      'emotion': 'Determined',
#      'sentiment': 0.5},
#     {'name': 'Crew Members',
#      'role': 'United in their resolve',
#      'importance': 0.7,
#      'emotion': 'Empowered',
#      'sentiment': 0.7}]},
#   {'title': 'The Approach',
#    'number': 1,
#    'summary': 'The fleet detects an unknown vessel approaching, sparking curiosity and concern.',
#    'chapter': 'Chapter 5: The First Encounter',
#    'location': 'Bridge of the flagship',
#    'importance': 0.9,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, assessing the situation',
#      'importance': 1.0,
#      'emotion': 'anxious yet determined',
#      'sentiment': 0.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Preparing for potential communication',
#      'importance': 1.0,
#      'emotion': 'excited but cautious',
#      'sentiment': 0.5}]},
#   {'title': 'First Contact',
#    'number': 2,
#    'summary': 'The fleet attempts to communicate with the alien vessel, leading to a breakthrough and confusion.',
#    'chapter': 'Chapter 5: The First Encounter',
#    'location': 'Communication room',
#    'importance': 1.0,
#    'conflict': 0.7,
#    'characters': [{'name': 'Diplomat Rian',
#      'role': 'Translating signals and establishing contact',
#      'importance': 1.0,
#      'emotion': 'hopeful',
#      'sentiment': 0.7},
#     {'name': 'Captain Elara',
#      'role': 'Monitoring the communication process',
#      'importance': 1.0,
#      'emotion': 'tense',
#      'sentiment': -0.2}]},
#   {'title': 'Misunderstanding',
#    'number': 3,
#    'summary': 'A misinterpretation of signals leads to a standoff between the fleets.',
#    'chapter': 'Chapter 5: The First Encounter',
#    'location': 'Space between the two vessels',
#    'importance': 1.0,
#    'conflict': 0.9,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Trying to de-escalate the situation',
#      'importance': 1.0,
#      'emotion': 'frustrated',
#      'sentiment': -0.5},
#     {'name': 'Alien Commander Zorak',
#      'role': 'Leader of the alien vessel, feeling threatened',
#      'importance': 1.0,
#      'emotion': 'defensive',
#      'sentiment': -0.6}]},
#   {'title': 'Tension Rises',
#    'number': 4,
#    'summary': 'The standoff escalates as both sides prepare for potential conflict.',
#    'chapter': 'Chapter 5: The First Encounter',
#    'location': 'Bridge of the flagship',
#    'importance': 0.8,
#    'conflict': 1.0,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Making critical decisions under pressure',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 0.0},
#     {'name': 'Diplomat Rian',
#      'role': 'Trying to find a peaceful solution',
#      'importance': 1.0,
#      'emotion': 'desperate',
#      'sentiment': -0.3}]},
#   {'title': 'Resolution',
#    'number': 5,
#    'summary': 'A breakthrough in communication leads to a tentative truce and understanding.',
#    'chapter': 'Chapter 5: The First Encounter',
#    'location': 'Communication room',
#    'importance': 1.0,
#    'conflict': 0.4,
#    'characters': [{'name': 'Diplomat Rian',
#      'role': 'Facilitating the dialogue that leads to peace',
#      'importance': 1.0,
#      'emotion': 'relieved',
#      'sentiment': 0.8},
#     {'name': 'Captain Elara',
#      'role': 'Acknowledging the importance of cooperation',
#      'importance': 1.0,
#      'emotion': 'hopeful',
#      'sentiment': 0.6}]},
#   {'title': 'Scene 1: The Gathering Storm',
#    'number': 1,
#    'summary': 'Tensions rise as factions begin to form within the fleet.',
#    'chapter': 'Chapter 6: Divided Loyalties',
#    'location': "Fleet's central command room",
#    'importance': 0.9,
#    'conflict': 0.8,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, trying to maintain order',
#      'importance': 1.0,
#      'emotion': 'stressed and determined',
#      'sentiment': 0.0},
#     {'name': 'First Officer Jax',
#      'role': "Challenger to Elara's authority",
#      'importance': 1.0,
#      'emotion': 'frustrated and passionate',
#      'sentiment': -1.0},
#     {'name': 'Tessa',
#      'role': 'Crew member caught in the middle',
#      'importance': 0.8,
#      'emotion': 'conflicted and anxious',
#      'sentiment': 0.0}]},
#   {'title': 'Discovery of the Colony Ship',
#    'number': 1,
#    'summary': 'The fleet detects a distress signal from a derelict colony ship.',
#    'chapter': 'Chapter 7: The Lost Colony',
#    'location': 'Fleet Command Center',
#    'importance': 1.0,
#    'conflict': 0.6,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, makes the decision to investigate the signal.',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 1.0},
#     {'name': 'First Officer Jax',
#      'role': 'Skeptical of the mission, worried about potential dangers.',
#      'importance': 0.8,
#      'emotion': 'anxious',
#      'sentiment': 0.0}]},
#   {'title': 'Arrival at the New Planet',
#    'number': 1,
#    'summary': 'The fleet arrives at the new planet and begins initial scans.',
#    'chapter': 'Chapter 8: A New Home?',
#    'location': 'Bridge of the lead ship',
#    'importance': 1.0,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Reyes',
#      'role': 'Leader of the fleet, optimistic about the new planet',
#      'importance': 1.0,
#      'emotion': 'hopeful',
#      'sentiment': 1.0},
#     {'name': 'Dr. Malik',
#      'role': "Chief scientist, skeptical about the planet's viability",
#      'importance': 1.0,
#      'emotion': 'cautious',
#      'sentiment': 0.0},
#     {'name': 'Tessa',
#      'role': 'Crew member, excited about the potential for a new home',
#      'importance': 0.8,
#      'emotion': 'enthusiastic',
#      'sentiment': 1.0}]},
#   {'title': 'First Expedition',
#    'number': 2,
#    'summary': "Dr. Malik and Tessa lead the first expedition to explore the planet's surface.",
#    'chapter': 'Chapter 8: A New Home?',
#    'location': 'Surface of the new planet',
#    'importance': 1.0,
#    'conflict': 0.7,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Leader of the expedition, focused on data collection',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 0.0},
#     {'name': 'Tessa',
#      'role': 'Supportive team member, eager to discover',
#      'importance': 0.8,
#      'emotion': 'curious',
#      'sentiment': 1.0},
#     {'name': 'Crew Member 1',
#      'role': 'Skeptical about the mission, voices concerns',
#      'importance': 0.6,
#      'emotion': 'worried',
#      'sentiment': -1.0}]},
#   {'title': 'Dangerous Discoveries',
#    'number': 3,
#    'summary': 'The team encounters dangerous wildlife and environmental hazards.',
#    'chapter': 'Chapter 8: A New Home?',
#    'location': 'Dense forest on the planet',
#    'importance': 1.0,
#    'conflict': 0.9,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Trying to keep the team safe while gathering data',
#      'importance': 1.0,
#      'emotion': 'anxious',
#      'sentiment': -1.0},
#     {'name': 'Tessa',
#      'role': 'Injured during an encounter with wildlife',
#      'importance': 0.9,
#      'emotion': 'fearful',
#      'sentiment': -1.0},
#     {'name': 'Crew Member 2',
#      'role': 'Panicking and urging retreat',
#      'importance': 0.7,
#      'emotion': 'terrified',
#      'sentiment': -1.0}]},
#   {'title': 'Divisions Among the Crew',
#    'number': 4,
#    'summary': "The findings from the expedition create divisions among the crew about the planet's viability.",
#    'chapter': 'Chapter 8: A New Home?',
#    'location': "Fleet's common area",
#    'importance': 1.0,
#    'conflict': 0.8,
#    'characters': [{'name': 'Captain Reyes',
#      'role': 'Trying to maintain morale and unity among the crew',
#      'importance': 1.0,
#      'emotion': 'frustrated',
#      'sentiment': 0.0},
#     {'name': 'Dr. Malik',
#      'role': 'Advocating for caution and further research',
#      'importance': 1.0,
#      'emotion': 'defensive',
#      'sentiment': -1.0},
#     {'name': 'Tessa',
#      'role': 'Caught in the middle, trying to mediate',
#      'importance': 0.8,
#      'emotion': 'conflicted',
#      'sentiment': 0.0}]},
#   {'title': 'Shocking Revelation',
#    'number': 5,
#    'summary': "The chapter ends with a shocking revelation about the planet's true nature.",
#    'chapter': 'Chapter 8: A New Home?',
#    'location': 'Bridge of the lead ship',
#    'importance': 1.0,
#    'conflict': 1.0,
#    'characters': [{'name': 'Captain Reyes',
#      'role': 'Reacting to the revelation, feeling betrayed',
#      'importance': 1.0,
#      'emotion': 'shocked',
#      'sentiment': -1.0},
#     {'name': 'Dr. Malik',
#      'role': 'Confirming the findings, feeling vindicated',
#      'importance': 1.0,
#      'emotion': 'grim',
#      'sentiment': -1.0},
#     {'name': 'Tessa',
#      'role': 'Struggling to process the implications',
#      'importance': 0.9,
#      'emotion': 'dismayed',
#      'sentiment': -1.0}]},
#   {'title': 'The Discovery',
#    'number': 1,
#    'summary': "The fleet uncovers the planet's hostile environment, leading to panic and fear.",
#    'chapter': 'Chapter 9: The Great Divide',
#    'location': 'Observation Deck',
#    'importance': 1.0,
#    'conflict': 0.8,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, trying to maintain order',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 0.0},
#     {'name': 'First Officer Jax',
#      'role': "Elara's second-in-command, skeptical of her decisions",
#      'importance': 1.0,
#      'emotion': 'frustrated',
#      'sentiment': -0.5},
#     {'name': 'Tessa',
#      'role': 'Crew member caught in the chaos',
#      'importance': 0.8,
#      'emotion': 'anxious',
#      'sentiment': -0.3}]},
#   {'title': 'The Faction Meeting',
#    'number': 2,
#    'summary': 'Elara and Jax present their survival strategies to the crew, igniting tensions.',
#    'chapter': 'Chapter 9: The Great Divide',
#    'location': 'Main Hall',
#    'importance': 1.0,
#    'conflict': 0.9,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Defending her vision for survival',
#      'importance': 1.0,
#      'emotion': 'passionate',
#      'sentiment': 0.5},
#     {'name': 'First Officer Jax',
#      'role': "Challenging Elara's approach",
#      'importance': 1.0,
#      'emotion': 'defiant',
#      'sentiment': -0.4},
#     {'name': 'Tessa',
#      'role': 'Mediator trying to keep peace',
#      'importance': 0.9,
#      'emotion': 'conflicted',
#      'sentiment': 0.0},
#     {'name': 'Crew Members',
#      'role': 'Divided audience reacting to the proposals',
#      'importance': 0.7,
#      'emotion': 'divided',
#      'sentiment': 0.0},
#     {'name': 'Dr. Mira',
#      'role': "Scientist supporting Elara's plan",
#      'importance': 0.8,
#      'emotion': 'hopeful',
#      'sentiment': 0.6}]},
#   {'title': 'The Rift',
#    'number': 3,
#    'summary': 'The factions officially split, leading to emotional confrontations.',
#    'chapter': 'Chapter 9: The Great Divide',
#    'location': 'Docking Bay',
#    'importance': 1.0,
#    'conflict': 1.0,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Heartbroken over the division',
#      'importance': 1.0,
#      'emotion': 'sorrowful',
#      'sentiment': -0.6},
#     {'name': 'First Officer Jax',
#      'role': 'Feeling justified in his actions',
#      'importance': 1.0,
#      'emotion': 'triumphant',
#      'sentiment': 0.4},
#     {'name': 'Tessa',
#      'role': 'Caught between friends, feeling lost',
#      'importance': 1.0,
#      'emotion': 'desperate',
#      'sentiment': -0.5},
#     {'name': 'Crew Members',
#      'role': 'Choosing sides, creating tension',
#      'importance': 0.9,
#      'emotion': 'angry',
#      'sentiment': -0.7}]},
#   {'title': 'The Aftermath',
#    'number': 4,
#    'summary': 'The emotional fallout of the split affects the entire fleet.',
#    'chapter': 'Chapter 9: The Great Divide',
#    'location': 'Common Area',
#    'importance': 1.0,
#    'conflict': 0.7,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Trying to rally her supporters',
#      'importance': 1.0,
#      'emotion': 'resolute',
#      'sentiment': 0.0},
#     {'name': 'First Officer Jax',
#      'role': "Celebrating his new faction's independence",
#      'importance': 1.0,
#      'emotion': 'elated',
#      'sentiment': 0.5},
#     {'name': 'Tessa',
#      'role': 'Reflecting on her choices and friendships',
#      'importance': 1.0,
#      'emotion': 'melancholic',
#      'sentiment': -0.4},
#     {'name': 'Crew Members',
#      'role': 'Struggling with the new reality',
#      'importance': 0.8,
#      'emotion': 'conflicted',
#      'sentiment': -0.2}]},
#   {'title': 'The Gathering Storm',
#    'number': 1,
#    'summary': 'Factions gather to discuss their grievances and demands.',
#    'chapter': 'Chapter 10: The Battle for Survival',
#    'location': 'Main Hall of the Fleet Ship',
#    'importance': 0.9,
#    'conflict': 0.7,
#    'characters': [{'name': 'Tessa',
#      'role': "A passionate advocate for her faction's needs",
#      'importance': 0.8,
#      'emotion': 'determined',
#      'sentiment': 0.5},
#     {'name': 'Dr. Malik',
#      'role': 'The mediator trying to keep peace',
#      'importance': 0.9,
#      'emotion': 'anxious',
#      'sentiment': 0.2},
#     {'name': 'Captain Reyes',
#      'role': 'The authoritative leader trying to maintain order',
#      'importance': 0.9,
#      'emotion': 'frustrated',
#      'sentiment': -0.3}]},
#   {'title': 'The First Skirmish',
#    'number': 2,
#    'summary': 'Tensions erupt into violence as factions clash over resources.',
#    'chapter': 'Chapter 10: The Battle for Survival',
#    'location': 'Resource Storage Bay',
#    'importance': 1.0,
#    'conflict': 1.0,
#    'characters': [{'name': 'Tessa',
#      'role': 'Defender of her friends and faction',
#      'importance': 1.0,
#      'emotion': 'fearless',
#      'sentiment': 0.4},
#     {'name': 'Rico',
#      'role': 'A rival faction member leading the attack',
#      'importance': 0.8,
#      'emotion': 'angry',
#      'sentiment': -0.5},
#     {'name': 'Dr. Malik',
#      'role': 'Trying to intervene and stop the fighting',
#      'importance': 0.9,
#      'emotion': 'desperate',
#      'sentiment': -0.2}]},
#   {'title': 'The Turning Point',
#    'number': 3,
#    'summary': 'A critical moment where Tessa makes a brave decision.',
#    'chapter': 'Chapter 10: The Battle for Survival',
#    'location': 'Amidst the chaos of the battle',
#    'importance': 1.0,
#    'conflict': 1.0,
#    'characters': [{'name': 'Tessa',
#      'role': 'Taking a stand to protect her friends',
#      'importance': 1.0,
#      'emotion': 'heroic',
#      'sentiment': 0.6},
#     {'name': 'Captain Reyes',
#      'role': 'Realizing the need for unity',
#      'importance': 0.8,
#      'emotion': 'determined',
#      'sentiment': 0.3},
#     {'name': 'Rico',
#      'role': "Caught off guard by Tessa's bravery",
#      'importance': 0.7,
#      'emotion': 'surprised',
#      'sentiment': 0.0}]},
#   {'title': 'The Aftermath',
#    'number': 4,
#    'summary': 'The battle leaves the fleet in disarray and uncertainty.',
#    'chapter': 'Chapter 10: The Battle for Survival',
#    'location': 'Main Hall of the Fleet Ship',
#    'importance': 1.0,
#    'conflict': 0.8,
#    'characters': [{'name': 'Dr. Malik',
#      'role': 'Assessing the damage and loss of life',
#      'importance': 0.9,
#      'emotion': 'sorrowful',
#      'sentiment': -0.6},
#     {'name': 'Tessa',
#      'role': 'Reflecting on the cost of the conflict',
#      'importance': 0.8,
#      'emotion': 'haunted',
#      'sentiment': -0.5},
#     {'name': 'Captain Reyes',
#      'role': 'Trying to restore order and hope',
#      'importance': 0.9,
#      'emotion': 'resolute',
#      'sentiment': 0.1}]},
#   {'title': 'Scene 1: The Aftermath',
#    'number': 1,
#    'summary': 'The fleet assesses the damage and loss after the battle.',
#    'chapter': 'Chapter 11: Reflections in the Stars',
#    'location': 'Command Center',
#    'importance': 1.0,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': "Leader reflecting on the battle's consequences",
#      'importance': 1.0,
#      'emotion': 'somber',
#      'sentiment': -0.5},
#     {'name': 'Jax',
#      'role': 'Crew member grappling with guilt',
#      'importance': 1.0,
#      'emotion': 'remorseful',
#      'sentiment': -0.7}]},
#   {'title': 'Scene 2: A Moment of Silence',
#    'number': 2,
#    'summary': 'The crew holds a memorial for those lost in the conflict.',
#    'chapter': 'Chapter 11: Reflections in the Stars',
#    'location': 'Observation Deck',
#    'importance': 1.0,
#    'conflict': 0.2,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leading the memorial service',
#      'importance': 1.0,
#      'emotion': 'sorrowful',
#      'sentiment': -0.6},
#     {'name': 'Jax',
#      'role': 'Struggling to find closure',
#      'importance': 1.0,
#      'emotion': 'tearful',
#      'sentiment': -0.8},
#     {'name': 'Mira',
#      'role': 'Offering support to Jax',
#      'importance': 0.8,
#      'emotion': 'empathetic',
#      'sentiment': 0.5}]},
#   {'title': 'Scene 3: Conversations in the Dark',
#    'number': 3,
#    'summary': 'Characters share their thoughts and feelings about the future.',
#    'chapter': 'Chapter 11: Reflections in the Stars',
#    'location': 'Crew Quarters',
#    'importance': 1.0,
#    'conflict': 0.4,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Discussing the need for unity',
#      'importance': 1.0,
#      'emotion': 'determined',
#      'sentiment': 0.3},
#     {'name': 'Jax',
#      'role': 'Expressing doubts about their mission',
#      'importance': 1.0,
#      'emotion': 'conflicted',
#      'sentiment': -0.4},
#     {'name': 'Mira',
#      'role': 'Encouraging hope and resilience',
#      'importance': 1.0,
#      'emotion': 'optimistic',
#      'sentiment': 0.6}]},
#   {'title': 'Scene 4: Reflections on Choices',
#    'number': 4,
#    'summary': 'Elara and Jax confront their past decisions and their impact on the crew.',
#    'chapter': 'Chapter 11: Reflections in the Stars',
#    'location': "Elara's Quarters",
#    'importance': 1.0,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Reflecting on her leadership choices',
#      'importance': 1.0,
#      'emotion': 'introspective',
#      'sentiment': -0.2},
#     {'name': 'Jax',
#      'role': 'Acknowledging his mistakes',
#      'importance': 1.0,
#      'emotion': 'ashamed',
#      'sentiment': -0.6}]},
#   {'title': 'Scene 5: A New Vision',
#    'number': 5,
#    'summary': 'The crew comes together to discuss their vision for the future.',
#    'chapter': 'Chapter 11: Reflections in the Stars',
#    'location': 'Main Hall',
#    'importance': 1.0,
#    'conflict': 0.3,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Inspiring the crew with a new mission',
#      'importance': 1.0,
#      'emotion': 'hopeful',
#      'sentiment': 0.7},
#     {'name': 'Jax',
#      'role': 'Voicing concerns but willing to contribute',
#      'importance': 1.0,
#      'emotion': 'cautiously optimistic',
#      'sentiment': 0.2},
#     {'name': 'Mira',
#      'role': 'Facilitating the discussion',
#      'importance': 0.8,
#      'emotion': 'supportive',
#      'sentiment': 0.5}]},
#   {'title': 'Unity in Diversity',
#    'number': 1,
#    'summary': 'The fleet gathers for a council meeting to discuss their future.',
#    'chapter': 'Chapter 12: A New Beginning',
#    'location': 'Main assembly hall of the flagship',
#    'importance': 1.0,
#    'conflict': 0.3,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Leader of the fleet, guiding the discussions',
#      'importance': 1.0,
#      'emotion': 'Determined',
#      'sentiment': 1.0},
#     {'name': 'Dr. Malik',
#      'role': 'Scientist advocating for sustainable practices',
#      'importance': 0.8,
#      'emotion': 'Hopeful',
#      'sentiment': 1.0},
#     {'name': 'Commander Jax',
#      'role': 'Military leader concerned about security',
#      'importance': 0.7,
#      'emotion': 'Wary',
#      'sentiment': 0.0},
#     {'name': 'Lina',
#      'role': 'Community organizer representing the civilians',
#      'importance': 0.9,
#      'emotion': 'Passionate',
#      'sentiment': 1.0}]},
#   {'title': 'Building the Future',
#    'number': 2,
#    'summary': 'Teams are formed to start constructing the new settlement.',
#    'chapter': 'Chapter 12: A New Beginning',
#    'location': 'Surface of the new planet',
#    'importance': 1.0,
#    'conflict': 0.4,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Overseeing the construction efforts',
#      'importance': 1.0,
#      'emotion': 'Inspired',
#      'sentiment': 1.0},
#     {'name': 'Dr. Malik',
#      'role': 'Leading the environmental assessment team',
#      'importance': 0.8,
#      'emotion': 'Focused',
#      'sentiment': 1.0},
#     {'name': 'Commander Jax',
#      'role': 'Ensuring safety protocols are followed',
#      'importance': 0.7,
#      'emotion': 'Protective',
#      'sentiment': 0.0},
#     {'name': 'Lina',
#      'role': 'Motivating the workers and fostering teamwork',
#      'importance': 0.9,
#      'emotion': 'Encouraging',
#      'sentiment': 1.0}]},
#   {'title': 'Facing Challenges Together',
#    'number': 3,
#    'summary': 'The fleet encounters unexpected obstacles during construction.',
#    'chapter': 'Chapter 12: A New Beginning',
#    'location': 'Construction site on the new planet',
#    'importance': 0.9,
#    'conflict': 0.5,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Resolving conflicts among team members',
#      'importance': 1.0,
#      'emotion': 'Calm',
#      'sentiment': 0.5},
#     {'name': 'Dr. Malik',
#      'role': 'Finding solutions to environmental issues',
#      'importance': 0.8,
#      'emotion': 'Stressed',
#      'sentiment': 0.0},
#     {'name': 'Commander Jax',
#      'role': 'Dealing with security threats from wildlife',
#      'importance': 0.7,
#      'emotion': 'Alert',
#      'sentiment': -0.5},
#     {'name': 'Lina',
#      'role': 'Mediating disputes and keeping morale high',
#      'importance': 0.9,
#      'emotion': 'Optimistic',
#      'sentiment': 1.0}]},
#   {'title': 'A Ceremony of Hope',
#    'number': 4,
#    'summary': 'The fleet holds a ceremony to celebrate their new beginning.',
#    'chapter': 'Chapter 12: A New Beginning',
#    'location': 'Central plaza of the new settlement',
#    'importance': 1.0,
#    'conflict': 0.2,
#    'characters': [{'name': 'Captain Elara',
#      'role': 'Delivering a speech about unity and hope',
#      'importance': 1.0,
#      'emotion': 'Uplifted',
#      'sentiment': 1.0},
#     {'name': 'Dr. Malik',
#      'role': 'Sharing scientific insights about their new home',
#      'importance': 0.8,
#      'emotion': 'Excited',
#      'sentiment': 1.0},
#     {'name': 'Commander Jax',
#      'role': 'Acknowledging the sacrifices made during the journey',
#      'importance': 0.7,
#      'emotion': 'Reflective',
#      'sentiment': 0.0},
#     {'name': 'Lina',
#      'role': 'Leading the community in celebration',
#      'importance': 0.9,
#      'emotion': 'Joyful',
#      'sentiment': 1.0}]}],
#  'characters': [{'name': 'Narrator',
#    'description': 'Describes the environmental collapse and societal breakdown.',
#    'group': 'main characters'},
#   {'name': 'Captain Elara',
#    'description': 'Oversees the final preparations for the fleet.',
#    'group': 'main characters'},
#   {'name': 'Dr. Malik',
#    'description': 'Analyzes data on potential habitable planets.',
#    'group': 'main characters'},
#   {'name': 'Various Families',
#    'description': 'Express their sorrow and hope as they part ways.',
#    'group': 'supporting characters'},
#   {'name': 'Engineer Tessa',
#    'description': 'Struggling with her past while preparing her ship for launch.',
#    'group': 'main characters'},
#   {'name': 'Diplomat Rian',
#    'description': 'Trying to mediate between different ship crews to maintain peace.',
#    'group': 'main characters'},
#   {'name': 'Commander Jax',
#    'description': 'Leader of a rival ship, demanding more resources.',
#    'group': 'antagonists'},
#   {'name': 'First Officer Jax',
#    'description': "Challenging Elara's decisions and advocating for a different approach",
#    'group': 'supporting characters'},
#   {'name': 'Engineer Mira',
#    'description': 'Trying to fix the malfunction while dealing with crew panic',
#    'group': 'supporting characters'},
#   {'name': "Malik's Family",
#    'description': 'Symbolizes what he lost',
#    'group': 'supporting characters'},
#   {'name': 'Tessa',
#    'description': 'A young engineer with dreams of exploration',
#    'group': 'main characters'},
#   {'name': "Tessa's Parents",
#    'description': 'Represent her motivation to leave Earth',
#    'group': 'supporting characters'},
#   {'name': 'Crew Members',
#    'description': 'Represent diverse backgrounds and regrets',
#    'group': 'supporting characters'},
#   {'name': 'Alien Commander Zorak',
#    'description': 'Leader of the alien vessel, feeling threatened',
#    'group': 'antagonists'},
#   {'name': 'Captain Reyes',
#    'description': 'Leader of the fleet, optimistic about the new planet',
#    'group': 'main characters'},
#   {'name': 'Crew Member 1',
#    'description': 'Skeptical about the mission, voices concerns',
#    'group': 'supporting characters'},
#   {'name': 'Crew Member 2',
#    'description': 'Panicking and urging retreat',
#    'group': 'supporting characters'},
#   {'name': 'Dr. Mira',
#    'description': "Scientist supporting Elara's plan",
#    'group': 'supporting characters'},
#   {'name': 'Rico',
#    'description': 'A rival faction member leading the attack',
#    'group': 'antagonists'},
#   {'name': 'Jax',
#    'description': 'Crew member grappling with guilt',
#    'group': 'supporting characters'},
#   {'name': 'Mira',
#    'description': 'Offering support to Jax',
#    'group': 'supporting characters'},
#   {'name': 'Lina',
#    'description': 'Community organizer representing the civilians',
#    'group': 'supporting characters'}],
#  'locations': [{'name': 'Earth, various locations',
#    'description': 'A panoramic view of Earth’s devastation as the last generation ships are being prepared for launch.'},
#   {'name': 'Launch site',
#    'description': 'Key characters say their goodbyes to loved ones and the Earth they are leaving behind.'},
#   {'name': 'Orbit around Earth',
#    'description': "The generation ships arrive in orbit around Earth, each ship's crew preparing for departure."},
#   {'name': 'Fleet assembly area',
#    'description': 'Conflicts arise between different ship crews over resources and leadership.'},
#   {'name': 'Docking bays of the ships',
#    'description': 'The crews make last-minute checks and preparations for launch.'},
#   {'name': 'Space, departing from Earth',
#    'description': 'The fleet launches, leaving Earth behind and venturing into space.'},
#   {'name': 'Control Room of the flagship',
#    'description': 'The fleet encounters a critical technical malfunction that threatens their journey.'},
#   {'name': "Earth, Dr. Malik's home",
#    'description': 'Dr. Malik reflects on his final moments on Earth, saying goodbye to his family.'},
#   {'name': "Earth, Tessa's childhood home",
#    'description': 'Tessa recalls her childhood and the moments that led her to join the fleet.'},
#   {'name': 'Common area of the generation ship',
#    'description': 'The crew gathers to share their stories, revealing their regrets and fears.'},
#   {'name': "Ship's communication room",
#    'description': 'The crew listens to recordings from Earth, stirring deep emotions.'},
#   {'name': 'Bridge of the flagship',
#    'description': 'Tensions rise as factions begin to form within the fleet.'},
#   {'name': 'Communication room',
#    'description': 'The fleet attempts to communicate with the alien vessel, leading to a breakthrough and confusion.'},
#   {'name': 'Space between the two vessels',
#    'description': 'A misinterpretation of signals leads to a standoff between the fleets.'},
#   {'name': "Fleet's central command room",
#    'description': 'Tensions rise as factions begin to form within the fleet.'},
#   {'name': 'Fleet Command Center',
#    'description': 'The fleet detects a distress signal from a derelict colony ship.'},
#   {'name': 'Bridge of the lead ship',
#    'description': 'The fleet arrives at the new planet and begins initial scans.'},
#   {'name': 'Surface of the new planet',
#    'description': "Dr. Malik and Tessa lead the first expedition to explore the planet's surface."},
#   {'name': 'Dense forest on the planet',
#    'description': 'The team encounters dangerous wildlife and environmental hazards.'},
#   {'name': "Fleet's common area",
#    'description': "The findings from the expedition create divisions among the crew about the planet's viability."},
#   {'name': 'Observation Deck',
#    'description': "The fleet uncovers the planet's hostile environment, leading to panic and fear."},
#   {'name': 'Main Hall',
#    'description': 'Elara and Jax present their survival strategies to the crew, igniting tensions.'},
#   {'name': 'Docking Bay',
#    'description': 'The factions officially split, leading to emotional confrontations.'},
#   {'name': 'Common Area',
#    'description': 'The emotional fallout of the split affects the entire fleet.'},
#   {'name': 'Main Hall of the Fleet Ship',
#    'description': 'Factions gather to discuss their grievances and demands.'},
#   {'name': 'Resource Storage Bay',
#    'description': 'Tensions erupt into violence as factions clash over resources.'},
#   {'name': 'Amidst the chaos of the battle',
#    'description': 'A critical moment where Tessa makes a brave decision.'},
#   {'name': 'Command Center',
#    'description': 'The fleet assesses the damage and loss after the battle.'},
#   {'name': 'Crew Quarters',
#    'description': 'Characters share their thoughts and feelings about the future.'},
#   {'name': "Elara's Quarters",
#    'description': 'Elara and Jax confront their past decisions and their impact on the crew.'},
#   {'name': 'Main assembly hall of the flagship',
#    'description': 'The fleet gathers for a council meeting to discuss their future.'},
#   {'name': 'Construction site on the new planet',
#    'description': 'The fleet encounters unexpected obstacles during construction.'},
#   {'name': 'Central plaza of the new settlement',
#    'description': 'The fleet holds a ceremony to celebrate their new beginning.'}]}

# %%
# save the story outline to a file
with open(f"json/{story_name}/story_outline.json", "w") as f:
    json.dump(story_outline, f, indent=4)

# %%
# check if any locations are missing from scenes

# Load the JSON data from a file
with open(f"json/{story_name}/story_outline.json", "r") as file:
    data = json.load(file)

# Extract the locations from the locations object
all_locations = {location["name"] for location in data["locations"]}

# Extract the locations used in scenes
scene_locations = {scene["location"] for scene in data["scenes"]}

# Check if each location in "locations" is included in "scenes"
missing_locations = all_locations - scene_locations

# also other way around
extra_locations = scene_locations - all_locations

# Display the result
if missing_locations:
    print("The following locations are not included in any scene:")
    for location in missing_locations:
        print(f"- {location}")
else:
    print("All locations are included in at least one scene.")

if extra_locations:
    print("The following locations are not defined but used in scenes:")
    for location in extra_locations:
        print(f"- {location}")
else:
    print("All locations used in scenes are defined.")
# Out:
# All locations are included in at least one scene.
# All locations used in scenes are defined.

# %%
# check characters too
all_characters = {character["name"] for character in data["characters"]}
scene_characters = {character["name"] for scene in data["scenes"] for character in scene["characters"]}
missing_characters = all_characters - scene_characters
extra_characters = scene_characters - all_characters

if missing_characters:
    print("\nThe following characters are not included in any scene:")
    for character in missing_characters:
        print(f"- {character}")

if extra_characters:
    print("\nThe following characters are not defined but used in scenes:")
    for character in extra_characters:
        print(f"- {character}")

# %%
# count characters/locations in scenes
with open(f'json/{story_name}/story_outline.json', 'r') as file:
    story_outline = json.load(file)

scenes = story_outline['scenes']
chapters = story_outline['chapters']
characters = story_outline['characters']
locations = story_outline['locations']

# %%
# count how many scenes each character is in per chapter
character_scene_count = {}

for scene in scenes:
    chapter = scene['chapter']  # Ensure this is a string or integer
    if chapter not in character_scene_count:
        character_scene_count[chapter] = {}
        
    for character in scene['characters']:
        character_name = character['name']  # Extract a unique identifier from the character dictionary
        if character_name not in character_scene_count[chapter]:
            character_scene_count[chapter][character_name] = 1
        else:
            character_scene_count[chapter][character_name] += 1

character_scene_count
# Out:
# {'Chapter 1: The Last Days of Earth': {'Narrator': 1,
#   'Captain Elara': 2,
#   'Dr. Malik': 2,
#   'Various Families': 1},
#  'Chapter 2: The Fleet Assembles': {'Captain Elara': 5,
#   'Engineer Tessa': 5,
#   'Diplomat Rian': 5,
#   'Commander Jax': 1},
#  'Chapter 3: The Void of Space': {'Captain Elara': 1,
#   'First Officer Jax': 1,
#   'Engineer Mira': 1},
#  'Chapter 4: Echoes of the Past': {'Dr. Malik': 4,
#   "Malik's Family": 1,
#   'Tessa': 4,
#   "Tessa's Parents": 1,
#   'Crew Members': 3},
#  'Chapter 5: The First Encounter': {'Captain Elara': 5,
#   'Diplomat Rian': 4,
#   'Alien Commander Zorak': 1},
#  'Chapter 6: Divided Loyalties': {'Captain Elara': 1,
#   'First Officer Jax': 1,
#   'Tessa': 1},
#  'Chapter 7: The Lost Colony': {'Captain Elara': 1, 'First Officer Jax': 1},
#  'Chapter 8: A New Home?': {'Captain Reyes': 3,
#   'Dr. Malik': 5,
#   'Tessa': 5,
#   'Crew Member 1': 1,
#   'Crew Member 2': 1},
#  'Chapter 9: The Great Divide': {'Captain Elara': 4,
#   'First Officer Jax': 4,
#   'Tessa': 4,
#   'Crew Members': 3,
#   'Dr. Mira': 1},
#  'Chapter 10: The Battle for Survival': {'Tessa': 4,
#   'Dr. Malik': 3,
#   'Captain Reyes': 3,
#   'Rico': 2},
#  'Chapter 11: Reflections in the Stars': {'Captain Elara': 5,
#   'Jax': 5,
#   'Mira': 3},
#  'Chapter 12: A New Beginning': {'Captain Elara': 4,
#   'Dr. Malik': 4,
#   'Commander Jax': 4,
#   'Lina': 4}}

# %%
# repeat for locations
location_scene_count = {}

for scene in scenes:
    chapter = scene['chapter']
    if chapter not in location_scene_count:
        location_scene_count[chapter] = {}
        
    location_name = scene['location']
    if location_name not in location_scene_count[chapter]:
        location_scene_count[chapter][location_name] = 1
    else:
        location_scene_count[chapter][location_name] += 1

location_scene_count
# Out:
# {'Chapter 1: The Last Days of Earth': {'Earth, various locations': 1,
#   'Launch site': 1},
#  'Chapter 2: The Fleet Assembles': {'Orbit around Earth': 1,
#   'Fleet assembly area': 2,
#   'Docking bays of the ships': 1,
#   'Space, departing from Earth': 1},
#  'Chapter 3: The Void of Space': {'Control Room of the flagship': 1},
#  'Chapter 4: Echoes of the Past': {"Earth, Dr. Malik's home": 1,
#   "Earth, Tessa's childhood home": 1,
#   'Common area of the generation ship': 2,
#   "Ship's communication room": 1},
#  'Chapter 5: The First Encounter': {'Bridge of the flagship': 2,
#   'Communication room': 2,
#   'Space between the two vessels': 1},
#  'Chapter 6: Divided Loyalties': {"Fleet's central command room": 1},
#  'Chapter 7: The Lost Colony': {'Fleet Command Center': 1},
#  'Chapter 8: A New Home?': {'Bridge of the lead ship': 2,
#   'Surface of the new planet': 1,
#   'Dense forest on the planet': 1,
#   "Fleet's common area": 1},
#  'Chapter 9: The Great Divide': {'Observation Deck': 1,
#   'Main Hall': 1,
#   'Docking Bay': 1,
#   'Common Area': 1},
#  'Chapter 10: The Battle for Survival': {'Main Hall of the Fleet Ship': 2,
#   'Resource Storage Bay': 1,
#   'Amidst the chaos of the battle': 1},
#  'Chapter 11: Reflections in the Stars': {'Command Center': 1,
#   'Observation Deck': 1,
#   'Crew Quarters': 1,
#   "Elara's Quarters": 1,
#   'Main Hall': 1},
#  'Chapter 12: A New Beginning': {'Main assembly hall of the flagship': 1,
#   'Surface of the new planet': 1,
#   'Construction site on the new planet': 1,
#   'Central plaza of the new settlement': 1}}

# %%
# update counts in chapter json object
for chapter in chapters:
    chap_name = chapter['chapter']
    print(chap_name)

    # add character counts
    chap_characters = character_scene_count[chap_name]
    new_char_dict = {}
    for char in chap_characters:
        # find char obj in characters with matching name
        char_obj = [c for c in characters if c["name"] == char][0]
        new_char_dict[char] = {"count": chap_characters[char], "role": char_obj["description"]}
   
    # add location counts
    chap_locations = location_scene_count[chap_name]
    new_loc_dict = {}
    for loc in chap_locations:
        # find loc obj in locations with matching name
        loc_obj = [l for l in locations if l["name"] == loc][0]
        new_loc_dict[loc] = {"count": chap_locations[loc], "role": loc_obj["description"]}

    chapter['characters'] = new_char_dict
    chapter['locations'] = new_loc_dict

chapters
# Out:
# Chapter 1: The Last Days of Earth
# Chapter 2: The Fleet Assembles
# Chapter 3: The Void of Space
# Chapter 4: Echoes of the Past
# Chapter 5: The First Encounter
# Chapter 6: Divided Loyalties
# Chapter 7: The Lost Colony
# Chapter 8: A New Home?
# Chapter 9: The Great Divide
# Chapter 10: The Battle for Survival
# Chapter 11: Reflections in the Stars
# Chapter 12: A New Beginning
# [{'summary': 'As Earth faces its final days, the last generation ships are prepared for launch.',
#   'description': 'The chapter introduces the dire state of Earth, showcasing the environmental collapse and societal breakdown. We meet key characters, including Captain Elara, the determined leader of the fleet, and Dr. Malik, a scientist who has dedicated his life to finding a new home. The urgency of their mission is palpable as they say goodbye to their home planet, setting the stage for the journey ahead.',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'chapter': 'Chapter 1: The Last Days of Earth',
#   'characters': {'Narrator': {'count': 1,
#     'role': 'Describes the environmental collapse and societal breakdown.'},
#    'Captain Elara': {'count': 2,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'Dr. Malik': {'count': 2,
#     'role': 'Analyzes data on potential habitable planets.'},
#    'Various Families': {'count': 1,
#     'role': 'Express their sorrow and hope as they part ways.'}},
#   'locations': {'Earth, various locations': {'count': 1,
#     'role': 'A panoramic view of Earth’s devastation as the last generation ships are being prepared for launch.'},
#    'Launch site': {'count': 1,
#     'role': 'Key characters say their goodbyes to loved ones and the Earth they are leaving behind.'}}},
#  {'summary': 'The generation ships gather in orbit, each with its own mission and crew.',
#   'description': "This chapter explores the diverse backgrounds of the ships' crews, highlighting the tensions and alliances that form among them. We meet characters like engineer Tessa, who struggles with her past, and diplomat Rian, who tries to maintain peace. The chapter ends with the fleet finally launching into the unknown.",
#   'importance': 1.0,
#   'conflict': 0.6,
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'characters': {'Captain Elara': {'count': 5,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'Engineer Tessa': {'count': 5,
#     'role': 'Struggling with her past while preparing her ship for launch.'},
#    'Diplomat Rian': {'count': 5,
#     'role': 'Trying to mediate between different ship crews to maintain peace.'},
#    'Commander Jax': {'count': 1,
#     'role': 'Leader of a rival ship, demanding more resources.'}},
#   'locations': {'Orbit around Earth': {'count': 1,
#     'role': "The generation ships arrive in orbit around Earth, each ship's crew preparing for departure."},
#    'Fleet assembly area': {'count': 2,
#     'role': 'Conflicts arise between different ship crews over resources and leadership.'},
#    'Docking bays of the ships': {'count': 1,
#     'role': 'The crews make last-minute checks and preparations for launch.'},
#    'Space, departing from Earth': {'count': 1,
#     'role': 'The fleet launches, leaving Earth behind and venturing into space.'}}},
#  {'summary': 'The fleet navigates the challenges of deep space travel.',
#   'description': 'As the ships travel through the vast emptiness of space, the crew faces technical malfunctions and resource shortages. Tensions rise as different factions within the fleet clash over leadership and survival strategies. We see the first signs of dissent among the crew, particularly between Captain Elara and a rebellious faction led by First Officer Jax.',
#   'importance': 1.0,
#   'conflict': 0.8,
#   'chapter': 'Chapter 3: The Void of Space',
#   'characters': {'Captain Elara': {'count': 1,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'First Officer Jax': {'count': 1,
#     'role': "Challenging Elara's decisions and advocating for a different approach"},
#    'Engineer Mira': {'count': 1,
#     'role': 'Trying to fix the malfunction while dealing with crew panic'}},
#   'locations': {'Control Room of the flagship': {'count': 1,
#     'role': 'The fleet encounters a critical technical malfunction that threatens their journey.'}}},
#  {'summary': 'The crew grapples with memories of Earth and their lost lives.',
#   'description': "Flashbacks reveal the characters' lives on Earth, their reasons for leaving, and the emotional toll of their journey. We delve into the backstories of characters like Dr. Malik and Tessa, exploring their motivations and regrets. This chapter emphasizes the theme of nostalgia and the struggle to let go of the past.",
#   'importance': 0.8,
#   'conflict': 0.5,
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'characters': {'Dr. Malik': {'count': 4,
#     'role': 'Analyzes data on potential habitable planets.'},
#    "Malik's Family": {'count': 1, 'role': 'Symbolizes what he lost'},
#    'Tessa': {'count': 4,
#     'role': 'A young engineer with dreams of exploration'},
#    "Tessa's Parents": {'count': 1,
#     'role': 'Represent her motivation to leave Earth'},
#    'Crew Members': {'count': 3,
#     'role': 'Represent diverse backgrounds and regrets'}},
#   'locations': {"Earth, Dr. Malik's home": {'count': 1,
#     'role': 'Dr. Malik reflects on his final moments on Earth, saying goodbye to his family.'},
#    "Earth, Tessa's childhood home": {'count': 1,
#     'role': 'Tessa recalls her childhood and the moments that led her to join the fleet.'},
#    'Common area of the generation ship': {'count': 2,
#     'role': 'The crew gathers to share their stories, revealing their regrets and fears.'},
#    "Ship's communication room": {'count': 1,
#     'role': 'The crew listens to recordings from Earth, stirring deep emotions.'}}},
#  {'summary': 'The fleet encounters an alien vessel, leading to unexpected consequences.',
#   'description': "The fleet's first contact with an alien species brings both wonder and danger. The crew must navigate the complexities of communication and trust. Characters like diplomat Rian and Captain Elara work together to establish a dialogue, but misunderstandings lead to a tense standoff. This encounter raises questions about the nature of life in the universe.",
#   'importance': 1.0,
#   'conflict': 0.9,
#   'chapter': 'Chapter 5: The First Encounter',
#   'characters': {'Captain Elara': {'count': 5,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'Diplomat Rian': {'count': 4,
#     'role': 'Trying to mediate between different ship crews to maintain peace.'},
#    'Alien Commander Zorak': {'count': 1,
#     'role': 'Leader of the alien vessel, feeling threatened'}},
#   'locations': {'Bridge of the flagship': {'count': 2,
#     'role': 'Tensions rise as factions begin to form within the fleet.'},
#    'Communication room': {'count': 2,
#     'role': 'The fleet attempts to communicate with the alien vessel, leading to a breakthrough and confusion.'},
#    'Space between the two vessels': {'count': 1,
#     'role': 'A misinterpretation of signals leads to a standoff between the fleets.'}}},
#  {'summary': 'Internal conflicts escalate as factions within the fleet vie for control.',
#   'description': 'As resources dwindle, factions within the fleet become more pronounced. First Officer Jax leads a rebellion against Captain Elara, believing she is unfit to lead. The chapter explores themes of loyalty and betrayal, as characters must choose sides. Tessa finds herself torn between her loyalty to Elara and her growing admiration for Jax.',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'chapter': 'Chapter 6: Divided Loyalties',
#   'characters': {'Captain Elara': {'count': 1,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'First Officer Jax': {'count': 1,
#     'role': "Challenging Elara's decisions and advocating for a different approach"},
#    'Tessa': {'count': 1,
#     'role': 'A young engineer with dreams of exploration'}},
#   'locations': {"Fleet's central command room": {'count': 1,
#     'role': 'Tensions rise as factions begin to form within the fleet.'}}},
#  {'summary': 'The fleet discovers a derelict colony ship with survivors.',
#   'description': 'The fleet stumbles upon a long-lost colony ship, revealing survivors who have been stranded for years. The survivors, led by the resourceful Mira, bring new perspectives and challenges. The chapter explores the dynamics between the two groups and the moral dilemmas of sharing limited resources. Tensions rise as both groups struggle to adapt to their new reality.',
#   'importance': 1.0,
#   'conflict': 0.8,
#   'chapter': 'Chapter 7: The Lost Colony',
#   'characters': {'Captain Elara': {'count': 1,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'First Officer Jax': {'count': 1,
#     'role': "Challenging Elara's decisions and advocating for a different approach"}},
#   'locations': {'Fleet Command Center': {'count': 1,
#     'role': 'The fleet detects a distress signal from a derelict colony ship.'}}},
#  {'summary': 'The fleet arrives at a potentially habitable planet, but not all is as it seems.',
#   'description': "The fleet discovers a planet that appears to be a perfect new home. However, as they begin to explore, they uncover dangerous wildlife and environmental hazards. Characters like Dr. Malik and Tessa lead expeditions to assess the planet's viability, but their findings create further divisions among the crew. The chapter ends with a shocking revelation about the planet's true nature.",
#   'importance': 1.0,
#   'conflict': 0.9,
#   'chapter': 'Chapter 8: A New Home?',
#   'characters': {'Captain Reyes': {'count': 3,
#     'role': 'Leader of the fleet, optimistic about the new planet'},
#    'Dr. Malik': {'count': 5,
#     'role': 'Analyzes data on potential habitable planets.'},
#    'Tessa': {'count': 5,
#     'role': 'A young engineer with dreams of exploration'},
#    'Crew Member 1': {'count': 1,
#     'role': 'Skeptical about the mission, voices concerns'},
#    'Crew Member 2': {'count': 1, 'role': 'Panicking and urging retreat'}},
#   'locations': {'Bridge of the lead ship': {'count': 2,
#     'role': 'The fleet arrives at the new planet and begins initial scans.'},
#    'Surface of the new planet': {'count': 1,
#     'role': "Dr. Malik and Tessa lead the first expedition to explore the planet's surface."},
#    'Dense forest on the planet': {'count': 1,
#     'role': 'The team encounters dangerous wildlife and environmental hazards.'},
#    "Fleet's common area": {'count': 1,
#     'role': "The findings from the expedition create divisions among the crew about the planet's viability."}}},
#  {'summary': 'The fleet splits into factions, each with its own vision for survival.',
#   'description': "With the discovery of the planet's dangers, factions within the fleet become irreparably divided. Captain Elara and First Officer Jax lead opposing groups, each advocating for different survival strategies. The chapter highlights the emotional toll of the conflict, as friendships are tested and alliances shift. Tessa finds herself caught in the middle, struggling to find her place.",
#   'importance': 1.0,
#   'conflict': 1.0,
#   'chapter': 'Chapter 9: The Great Divide',
#   'characters': {'Captain Elara': {'count': 4,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'First Officer Jax': {'count': 4,
#     'role': "Challenging Elara's decisions and advocating for a different approach"},
#    'Tessa': {'count': 4,
#     'role': 'A young engineer with dreams of exploration'},
#    'Crew Members': {'count': 3,
#     'role': 'Represent diverse backgrounds and regrets'},
#    'Dr. Mira': {'count': 1, 'role': "Scientist supporting Elara's plan"}},
#   'locations': {'Observation Deck': {'count': 1,
#     'role': "The fleet uncovers the planet's hostile environment, leading to panic and fear."},
#    'Main Hall': {'count': 1,
#     'role': 'Elara and Jax present their survival strategies to the crew, igniting tensions.'},
#    'Docking Bay': {'count': 1,
#     'role': 'The factions officially split, leading to emotional confrontations.'},
#    'Common Area': {'count': 1,
#     'role': 'The emotional fallout of the split affects the entire fleet.'}}},
#  {'summary': 'A confrontation between factions leads to a desperate struggle for control.',
#   'description': "Tensions reach a boiling point as the factions clash over resources and leadership. The chapter is filled with action and conflict, showcasing the desperation of the characters. Key moments include Tessa's bravery in defending her friends and Dr. Malik's attempts to mediate peace. The battle leaves lasting scars on the fleet and its members.",
#   'importance': 1.0,
#   'conflict': 1.0,
#   'chapter': 'Chapter 10: The Battle for Survival',
#   'characters': {'Tessa': {'count': 4,
#     'role': 'A young engineer with dreams of exploration'},
#    'Dr. Malik': {'count': 3,
#     'role': 'Analyzes data on potential habitable planets.'},
#    'Captain Reyes': {'count': 3,
#     'role': 'Leader of the fleet, optimistic about the new planet'},
#    'Rico': {'count': 2, 'role': 'A rival faction member leading the attack'}},
#   'locations': {'Main Hall of the Fleet Ship': {'count': 2,
#     'role': 'Factions gather to discuss their grievances and demands.'},
#    'Resource Storage Bay': {'count': 1,
#     'role': 'Tensions erupt into violence as factions clash over resources.'},
#    'Amidst the chaos of the battle': {'count': 1,
#     'role': 'A critical moment where Tessa makes a brave decision.'}}},
#  {'summary': 'In the aftermath of the conflict, characters reflect on their choices and losses.',
#   'description': 'The aftermath of the battle forces the characters to confront their actions and the consequences of their choices. We see moments of grief, regret, and reconciliation as characters like Captain Elara and Jax come to terms with their decisions. The chapter emphasizes the importance of unity and the search for a shared vision of home.',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'characters': {'Captain Elara': {'count': 5,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'Jax': {'count': 5, 'role': 'Crew member grappling with guilt'},
#    'Mira': {'count': 3, 'role': 'Offering support to Jax'}},
#   'locations': {'Command Center': {'count': 1,
#     'role': 'The fleet assesses the damage and loss after the battle.'},
#    'Observation Deck': {'count': 1,
#     'role': "The fleet uncovers the planet's hostile environment, leading to panic and fear."},
#    'Crew Quarters': {'count': 1,
#     'role': 'Characters share their thoughts and feelings about the future.'},
#    "Elara's Quarters": {'count': 1,
#     'role': 'Elara and Jax confront their past decisions and their impact on the crew.'},
#    'Main Hall': {'count': 1,
#     'role': 'Elara and Jax present their survival strategies to the crew, igniting tensions.'}}},
#  {'summary': 'The fleet unites to forge a new path forward, embracing their shared journey.',
#   'description': 'In the final chapter, the fleet comes together to create a new society on the planet. Characters work collaboratively to build a future, drawing on their diverse skills and experiences. The chapter ends with a sense of hope and possibility as they look to the stars, ready to embrace their new home and the challenges that lie ahead. Themes of resilience and community are highlighted as they redefine what home means to them.',
#   'importance': 1.0,
#   'conflict': 0.4,
#   'chapter': 'Chapter 12: A New Beginning',
#   'characters': {'Captain Elara': {'count': 4,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'Dr. Malik': {'count': 4,
#     'role': 'Analyzes data on potential habitable planets.'},
#    'Commander Jax': {'count': 4,
#     'role': 'Leader of a rival ship, demanding more resources.'},
#    'Lina': {'count': 4,
#     'role': 'Community organizer representing the civilians'}},
#   'locations': {'Main assembly hall of the flagship': {'count': 1,
#     'role': 'The fleet gathers for a council meeting to discuss their future.'},
#    'Surface of the new planet': {'count': 1,
#     'role': "Dr. Malik and Tessa lead the first expedition to explore the planet's surface."},
#    'Construction site on the new planet': {'count': 1,
#     'role': 'The fleet encounters unexpected obstacles during construction.'},
#    'Central plaza of the new settlement': {'count': 1,
#     'role': 'The fleet holds a ceremony to celebrate their new beginning.'}}}]

# %%
# save the updated story outline to a file
with open(f"json/{story_name}/story_outline.json", "w") as f:
    json.dump(story_outline, f, indent=4)

# %%
# rank by importance and conflict
with open(f'json/{story_name}/story_outline.json', 'r') as file:
    story_outline = json.load(file)

scenes = story_outline['scenes']
chapters = story_outline['chapters']
characters = story_outline['characters']
locations = story_outline['locations']

# %%
# rank each scene by importance
# and within each scene, the characters

for i, chapter in enumerate(chapters):
    importances = []
    conflicts = []
    num_scenes = 0

    chap_name = chapter["chapter"]
    
    # extract importance from each scene
    for j, scene in enumerate(scenes):
        if scene["chapter"] != chap_name:
            continue
        importances.append((j, scene["importance"]))
        conflicts.append((j, scene["conflict"]))
        # now extract character importances
        character_importances = []
        for k, character in enumerate(scene["characters"]):
            character_importances.append((k, character["importance"]))
        # sort character importances
        sorted_character_importances = sorted(character_importances, key=lambda x: x[1], reverse=True)
        # add importance_rank to each character
        for k, (l, _) in enumerate(sorted_character_importances):
            scenes[j]["characters"][l]["importance_rank"] = k+1
        # add number of each scene
        scenes[j]["number"] = j+1
        num_scenes += 1
    # sort importances
    sorted_importances = sorted(importances, key=lambda x: x[1], reverse=True)
    # add importance_rank to each scene
    for k, (j, _) in enumerate(sorted_importances):
        scenes[j]["importance_rank"] = k+1
    # sort conflicts
    sorted_conflicts = sorted(conflicts, key=lambda x: x[1], reverse=True)
    # add conflict_rank to each scene
    for k, (j, _) in enumerate(sorted_conflicts):
        scenes[j]["conflict_rank"] = k+1
    
    # add number of scenes to chapter
    chapters[i]["scenes"] = num_scenes
    
    # print results
    # for j, scene in enumerate(scenes):
    #     print(scenes[j]["title"], scenes[j]["importance_rank"])
    #     print("--------------------------------")
    #     for k, character in enumerate(scene["characters"]):
    #         print(character["name"], character["importance_rank"])
    #     print()

# %%
scenes
# Out:
# [{'title': 'The Crumbling World',
#   'number': 1,
#   'summary': 'A panoramic view of Earth’s devastation as the last generation ships are being prepared for launch.',
#   'chapter': 'Chapter 1: The Last Days of Earth',
#   'location': 'Earth, various locations',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Narrator',
#     'role': 'Describes the environmental collapse and societal breakdown.',
#     'importance': 1.0,
#     'emotion': 'somber',
#     'sentiment': -1.0,
#     'importance_rank': 1},
#    {'name': 'Captain Elara',
#     'role': 'Oversees the final preparations for the fleet.',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Dr. Malik',
#     'role': 'Analyzes data on potential habitable planets.',
#     'importance': 1.0,
#     'emotion': 'anxious',
#     'sentiment': -1.0,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'The Farewell',
#   'number': 2,
#   'summary': 'Key characters say their goodbyes to loved ones and the Earth they are leaving behind.',
#   'chapter': 'Chapter 1: The Last Days of Earth',
#   'location': 'Launch site',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Bids farewell to her family and friends.',
#     'importance': 1.0,
#     'emotion': 'heartbroken',
#     'sentiment': -1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Reflects on his sacrifices and the weight of his mission.',
#     'importance': 1.0,
#     'emotion': 'regretful',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Various Families',
#     'role': 'Express their sorrow and hope as they part ways.',
#     'importance': 0.8,
#     'emotion': 'mixed',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'The Gathering',
#   'number': 3,
#   'summary': "The generation ships arrive in orbit around Earth, each ship's crew preparing for departure.",
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'location': 'Orbit around Earth',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, overseeing the assembly of ships.',
#     'importance': 1.0,
#     'emotion': 'Determined',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Engineer Tessa',
#     'role': 'Struggling with her past while preparing her ship for launch.',
#     'importance': 1.0,
#     'emotion': 'Anxious',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Diplomat Rian',
#     'role': 'Trying to mediate between different ship crews to maintain peace.',
#     'importance': 1.0,
#     'emotion': 'Diplomatic',
#     'sentiment': 1.0,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 3},
#  {'title': 'Tensions Rise',
#   'number': 4,
#   'summary': 'Conflicts arise between different ship crews over resources and leadership.',
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'location': 'Fleet assembly area',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Trying to keep the peace among the crews.',
#     'importance': 1.0,
#     'emotion': 'Frustrated',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Engineer Tessa',
#     'role': 'Caught in the middle of a heated argument.',
#     'importance': 1.0,
#     'emotion': 'Conflicted',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Diplomat Rian',
#     'role': 'Working hard to negotiate a truce.',
#     'importance': 1.0,
#     'emotion': 'Stressed',
#     'sentiment': 0.0,
#     'importance_rank': 3},
#    {'name': 'Commander Jax',
#     'role': 'Leader of a rival ship, demanding more resources.',
#     'importance': 1.0,
#     'emotion': 'Aggressive',
#     'sentiment': -1.0,
#     'importance_rank': 4}],
#   'importance_rank': 2,
#   'conflict_rank': 1},
#  {'title': 'Alliances Form',
#   'number': 5,
#   'summary': 'Some crews begin to form alliances to strengthen their position.',
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'location': 'Fleet assembly area',
#   'importance': 1.0,
#   'conflict': 0.4,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Encouraging collaboration among the ships.',
#     'importance': 1.0,
#     'emotion': 'Hopeful',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Engineer Tessa',
#     'role': 'Finding common ground with another engineer.',
#     'importance': 1.0,
#     'emotion': 'Relieved',
#     'sentiment': 1.0,
#     'importance_rank': 2},
#    {'name': 'Diplomat Rian',
#     'role': 'Facilitating discussions between allied ships.',
#     'importance': 1.0,
#     'emotion': 'Optimistic',
#     'sentiment': 1.0,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 4},
#  {'title': 'Final Preparations',
#   'number': 6,
#   'summary': 'The crews make last-minute checks and preparations for launch.',
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'location': 'Docking bays of the ships',
#   'importance': 1.0,
#   'conflict': 0.3,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Conducting final inspections of the fleet.',
#     'importance': 1.0,
#     'emotion': 'Focused',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Engineer Tessa',
#     'role': 'Double-checking systems to ensure safety.',
#     'importance': 1.0,
#     'emotion': 'Nervous',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Diplomat Rian',
#     'role': 'Reassuring the crews before launch.',
#     'importance': 1.0,
#     'emotion': 'Calm',
#     'sentiment': 1.0,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 5},
#  {'title': 'Launch into the Unknown',
#   'number': 7,
#   'summary': 'The fleet launches, leaving Earth behind and venturing into space.',
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'location': 'Space, departing from Earth',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leading the fleet into the unknown.',
#     'importance': 1.0,
#     'emotion': 'Proud',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Engineer Tessa',
#     'role': 'Experiencing a mix of fear and excitement.',
#     'importance': 1.0,
#     'emotion': 'Excited',
#     'sentiment': 1.0,
#     'importance_rank': 2},
#    {'name': 'Diplomat Rian',
#     'role': 'Watching the launch with a sense of hope and dread.',
#     'importance': 1.0,
#     'emotion': 'Hopeful',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 2},
#  {'title': 'Navigating the Abyss',
#   'number': 8,
#   'summary': 'The fleet encounters a critical technical malfunction that threatens their journey.',
#   'chapter': 'Chapter 3: The Void of Space',
#   'location': 'Control Room of the flagship',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader trying to maintain order during the crisis',
#     'importance': 1.0,
#     'emotion': 'stressed and determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': "Challenging Elara's decisions and advocating for a different approach",
#     'importance': 1.0,
#     'emotion': 'frustrated and rebellious',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Engineer Mira',
#     'role': 'Trying to fix the malfunction while dealing with crew panic',
#     'importance': 0.8,
#     'emotion': 'anxious but focused',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Scene 1: The Last Goodbye',
#   'number': 9,
#   'summary': 'Dr. Malik reflects on his final moments on Earth, saying goodbye to his family.',
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'location': "Earth, Dr. Malik's home",
#   'importance': 0.9,
#   'conflict': 0.6,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'A scientist who left Earth to save humanity',
#     'importance': 1.0,
#     'emotion': 'Sorrowful and regretful',
#     'sentiment': -0.8,
#     'importance_rank': 1},
#    {'name': "Malik's Family",
#     'role': 'Symbolizes what he lost',
#     'importance': 0.8,
#     'emotion': 'Heartbroken',
#     'sentiment': -0.9,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': "Scene 2: Tessa's Memories",
#   'number': 10,
#   'summary': 'Tessa recalls her childhood and the moments that led her to join the fleet.',
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'location': "Earth, Tessa's childhood home",
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Tessa',
#     'role': 'A young engineer with dreams of exploration',
#     'importance': 1.0,
#     'emotion': 'Nostalgic and hopeful',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': "Tessa's Parents",
#     'role': 'Represent her motivation to leave Earth',
#     'importance': 0.7,
#     'emotion': 'Supportive but worried',
#     'sentiment': 0.1,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Scene 3: The Weight of Regret',
#   'number': 11,
#   'summary': 'The crew gathers to share their stories, revealing their regrets and fears.',
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'location': 'Common area of the generation ship',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Facilitator of the discussion',
#     'importance': 0.9,
#     'emotion': 'Determined yet pained',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Participant sharing her story',
#     'importance': 0.8,
#     'emotion': 'Vulnerable',
#     'sentiment': -0.3,
#     'importance_rank': 2},
#    {'name': 'Crew Members',
#     'role': 'Represent diverse backgrounds and regrets',
#     'importance': 0.6,
#     'emotion': 'Mixed emotions',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 2},
#  {'title': 'Scene 4: Echoes in the Void',
#   'number': 12,
#   'summary': 'The crew listens to recordings from Earth, stirring deep emotions.',
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'location': "Ship's communication room",
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Analyzing the recordings',
#     'importance': 0.8,
#     'emotion': 'Haunted by memories',
#     'sentiment': -0.6,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Emotional response to the recordings',
#     'importance': 0.7,
#     'emotion': 'Overwhelmed',
#     'sentiment': -0.7,
#     'importance_rank': 2},
#    {'name': 'Crew Members',
#     'role': 'Reacting to the recordings',
#     'importance': 0.5,
#     'emotion': 'Reflective',
#     'sentiment': 0.1,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5},
#  {'title': 'Scene 5: A New Resolve',
#   'number': 13,
#   'summary': 'After sharing their stories, the crew finds strength in unity and purpose.',
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'location': 'Common area of the generation ship',
#   'importance': 0.9,
#   'conflict': 0.4,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Inspiring the crew to move forward',
#     'importance': 1.0,
#     'emotion': 'Hopeful',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Reinforcing the need for a new beginning',
#     'importance': 0.9,
#     'emotion': 'Determined',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Crew Members',
#     'role': 'United in their resolve',
#     'importance': 0.7,
#     'emotion': 'Empowered',
#     'sentiment': 0.7,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 4},
#  {'title': 'The Approach',
#   'number': 14,
#   'summary': 'The fleet detects an unknown vessel approaching, sparking curiosity and concern.',
#   'chapter': 'Chapter 5: The First Encounter',
#   'location': 'Bridge of the flagship',
#   'importance': 0.9,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, assessing the situation',
#     'importance': 1.0,
#     'emotion': 'anxious yet determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Diplomat Rian',
#     'role': 'Preparing for potential communication',
#     'importance': 1.0,
#     'emotion': 'excited but cautious',
#     'sentiment': 0.5,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'First Contact',
#   'number': 15,
#   'summary': 'The fleet attempts to communicate with the alien vessel, leading to a breakthrough and confusion.',
#   'chapter': 'Chapter 5: The First Encounter',
#   'location': 'Communication room',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'characters': [{'name': 'Diplomat Rian',
#     'role': 'Translating signals and establishing contact',
#     'importance': 1.0,
#     'emotion': 'hopeful',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Captain Elara',
#     'role': 'Monitoring the communication process',
#     'importance': 1.0,
#     'emotion': 'tense',
#     'sentiment': -0.2,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 3},
#  {'title': 'Misunderstanding',
#   'number': 16,
#   'summary': 'A misinterpretation of signals leads to a standoff between the fleets.',
#   'chapter': 'Chapter 5: The First Encounter',
#   'location': 'Space between the two vessels',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Trying to de-escalate the situation',
#     'importance': 1.0,
#     'emotion': 'frustrated',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Alien Commander Zorak',
#     'role': 'Leader of the alien vessel, feeling threatened',
#     'importance': 1.0,
#     'emotion': 'defensive',
#     'sentiment': -0.6,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'Tension Rises',
#   'number': 17,
#   'summary': 'The standoff escalates as both sides prepare for potential conflict.',
#   'chapter': 'Chapter 5: The First Encounter',
#   'location': 'Bridge of the flagship',
#   'importance': 0.8,
#   'conflict': 1.0,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Making critical decisions under pressure',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Diplomat Rian',
#     'role': 'Trying to find a peaceful solution',
#     'importance': 1.0,
#     'emotion': 'desperate',
#     'sentiment': -0.3,
#     'importance_rank': 2}],
#   'importance_rank': 5,
#   'conflict_rank': 1},
#  {'title': 'Resolution',
#   'number': 18,
#   'summary': 'A breakthrough in communication leads to a tentative truce and understanding.',
#   'chapter': 'Chapter 5: The First Encounter',
#   'location': 'Communication room',
#   'importance': 1.0,
#   'conflict': 0.4,
#   'characters': [{'name': 'Diplomat Rian',
#     'role': 'Facilitating the dialogue that leads to peace',
#     'importance': 1.0,
#     'emotion': 'relieved',
#     'sentiment': 0.8,
#     'importance_rank': 1},
#    {'name': 'Captain Elara',
#     'role': 'Acknowledging the importance of cooperation',
#     'importance': 1.0,
#     'emotion': 'hopeful',
#     'sentiment': 0.6,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 5},
#  {'title': 'Scene 1: The Gathering Storm',
#   'number': 19,
#   'summary': 'Tensions rise as factions begin to form within the fleet.',
#   'chapter': 'Chapter 6: Divided Loyalties',
#   'location': "Fleet's central command room",
#   'importance': 0.9,
#   'conflict': 0.8,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, trying to maintain order',
#     'importance': 1.0,
#     'emotion': 'stressed and determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': "Challenger to Elara's authority",
#     'importance': 1.0,
#     'emotion': 'frustrated and passionate',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Crew member caught in the middle',
#     'importance': 0.8,
#     'emotion': 'conflicted and anxious',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Discovery of the Colony Ship',
#   'number': 20,
#   'summary': 'The fleet detects a distress signal from a derelict colony ship.',
#   'chapter': 'Chapter 7: The Lost Colony',
#   'location': 'Fleet Command Center',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, makes the decision to investigate the signal.',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': 'Skeptical of the mission, worried about potential dangers.',
#     'importance': 0.8,
#     'emotion': 'anxious',
#     'sentiment': 0.0,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Arrival at the New Planet',
#   'number': 21,
#   'summary': 'The fleet arrives at the new planet and begins initial scans.',
#   'chapter': 'Chapter 8: A New Home?',
#   'location': 'Bridge of the lead ship',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Reyes',
#     'role': 'Leader of the fleet, optimistic about the new planet',
#     'importance': 1.0,
#     'emotion': 'hopeful',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': "Chief scientist, skeptical about the planet's viability",
#     'importance': 1.0,
#     'emotion': 'cautious',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Crew member, excited about the potential for a new home',
#     'importance': 0.8,
#     'emotion': 'enthusiastic',
#     'sentiment': 1.0,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 5},
#  {'title': 'First Expedition',
#   'number': 22,
#   'summary': "Dr. Malik and Tessa lead the first expedition to explore the planet's surface.",
#   'chapter': 'Chapter 8: A New Home?',
#   'location': 'Surface of the new planet',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Leader of the expedition, focused on data collection',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Supportive team member, eager to discover',
#     'importance': 0.8,
#     'emotion': 'curious',
#     'sentiment': 1.0,
#     'importance_rank': 2},
#    {'name': 'Crew Member 1',
#     'role': 'Skeptical about the mission, voices concerns',
#     'importance': 0.6,
#     'emotion': 'worried',
#     'sentiment': -1.0,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 4},
#  {'title': 'Dangerous Discoveries',
#   'number': 23,
#   'summary': 'The team encounters dangerous wildlife and environmental hazards.',
#   'chapter': 'Chapter 8: A New Home?',
#   'location': 'Dense forest on the planet',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Trying to keep the team safe while gathering data',
#     'importance': 1.0,
#     'emotion': 'anxious',
#     'sentiment': -1.0,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Injured during an encounter with wildlife',
#     'importance': 0.9,
#     'emotion': 'fearful',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Crew Member 2',
#     'role': 'Panicking and urging retreat',
#     'importance': 0.7,
#     'emotion': 'terrified',
#     'sentiment': -1.0,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 2},
#  {'title': 'Divisions Among the Crew',
#   'number': 24,
#   'summary': "The findings from the expedition create divisions among the crew about the planet's viability.",
#   'chapter': 'Chapter 8: A New Home?',
#   'location': "Fleet's common area",
#   'importance': 1.0,
#   'conflict': 0.8,
#   'characters': [{'name': 'Captain Reyes',
#     'role': 'Trying to maintain morale and unity among the crew',
#     'importance': 1.0,
#     'emotion': 'frustrated',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Advocating for caution and further research',
#     'importance': 1.0,
#     'emotion': 'defensive',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Caught in the middle, trying to mediate',
#     'importance': 0.8,
#     'emotion': 'conflicted',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 3},
#  {'title': 'Shocking Revelation',
#   'number': 25,
#   'summary': "The chapter ends with a shocking revelation about the planet's true nature.",
#   'chapter': 'Chapter 8: A New Home?',
#   'location': 'Bridge of the lead ship',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Captain Reyes',
#     'role': 'Reacting to the revelation, feeling betrayed',
#     'importance': 1.0,
#     'emotion': 'shocked',
#     'sentiment': -1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Confirming the findings, feeling vindicated',
#     'importance': 1.0,
#     'emotion': 'grim',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Struggling to process the implications',
#     'importance': 0.9,
#     'emotion': 'dismayed',
#     'sentiment': -1.0,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 1},
#  {'title': 'The Discovery',
#   'number': 26,
#   'summary': "The fleet uncovers the planet's hostile environment, leading to panic and fear.",
#   'chapter': 'Chapter 9: The Great Divide',
#   'location': 'Observation Deck',
#   'importance': 1.0,
#   'conflict': 0.8,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, trying to maintain order',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': "Elara's second-in-command, skeptical of her decisions",
#     'importance': 1.0,
#     'emotion': 'frustrated',
#     'sentiment': -0.5,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Crew member caught in the chaos',
#     'importance': 0.8,
#     'emotion': 'anxious',
#     'sentiment': -0.3,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 3},
#  {'title': 'The Faction Meeting',
#   'number': 27,
#   'summary': 'Elara and Jax present their survival strategies to the crew, igniting tensions.',
#   'chapter': 'Chapter 9: The Great Divide',
#   'location': 'Main Hall',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Defending her vision for survival',
#     'importance': 1.0,
#     'emotion': 'passionate',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': "Challenging Elara's approach",
#     'importance': 1.0,
#     'emotion': 'defiant',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Mediator trying to keep peace',
#     'importance': 0.9,
#     'emotion': 'conflicted',
#     'sentiment': 0.0,
#     'importance_rank': 3},
#    {'name': 'Crew Members',
#     'role': 'Divided audience reacting to the proposals',
#     'importance': 0.7,
#     'emotion': 'divided',
#     'sentiment': 0.0,
#     'importance_rank': 5},
#    {'name': 'Dr. Mira',
#     'role': "Scientist supporting Elara's plan",
#     'importance': 0.8,
#     'emotion': 'hopeful',
#     'sentiment': 0.6,
#     'importance_rank': 4}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'The Rift',
#   'number': 28,
#   'summary': 'The factions officially split, leading to emotional confrontations.',
#   'chapter': 'Chapter 9: The Great Divide',
#   'location': 'Docking Bay',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Heartbroken over the division',
#     'importance': 1.0,
#     'emotion': 'sorrowful',
#     'sentiment': -0.6,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': 'Feeling justified in his actions',
#     'importance': 1.0,
#     'emotion': 'triumphant',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Caught between friends, feeling lost',
#     'importance': 1.0,
#     'emotion': 'desperate',
#     'sentiment': -0.5,
#     'importance_rank': 3},
#    {'name': 'Crew Members',
#     'role': 'Choosing sides, creating tension',
#     'importance': 0.9,
#     'emotion': 'angry',
#     'sentiment': -0.7,
#     'importance_rank': 4}],
#   'importance_rank': 3,
#   'conflict_rank': 1},
#  {'title': 'The Aftermath',
#   'number': 29,
#   'summary': 'The emotional fallout of the split affects the entire fleet.',
#   'chapter': 'Chapter 9: The Great Divide',
#   'location': 'Common Area',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Trying to rally her supporters',
#     'importance': 1.0,
#     'emotion': 'resolute',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': "Celebrating his new faction's independence",
#     'importance': 1.0,
#     'emotion': 'elated',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Reflecting on her choices and friendships',
#     'importance': 1.0,
#     'emotion': 'melancholic',
#     'sentiment': -0.4,
#     'importance_rank': 3},
#    {'name': 'Crew Members',
#     'role': 'Struggling with the new reality',
#     'importance': 0.8,
#     'emotion': 'conflicted',
#     'sentiment': -0.2,
#     'importance_rank': 4}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'The Gathering Storm',
#   'number': 30,
#   'summary': 'Factions gather to discuss their grievances and demands.',
#   'chapter': 'Chapter 10: The Battle for Survival',
#   'location': 'Main Hall of the Fleet Ship',
#   'importance': 0.9,
#   'conflict': 0.7,
#   'characters': [{'name': 'Tessa',
#     'role': "A passionate advocate for her faction's needs",
#     'importance': 0.8,
#     'emotion': 'determined',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Dr. Malik',
#     'role': 'The mediator trying to keep peace',
#     'importance': 0.9,
#     'emotion': 'anxious',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Captain Reyes',
#     'role': 'The authoritative leader trying to maintain order',
#     'importance': 0.9,
#     'emotion': 'frustrated',
#     'sentiment': -0.3,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 4},
#  {'title': 'The First Skirmish',
#   'number': 31,
#   'summary': 'Tensions erupt into violence as factions clash over resources.',
#   'chapter': 'Chapter 10: The Battle for Survival',
#   'location': 'Resource Storage Bay',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Tessa',
#     'role': 'Defender of her friends and faction',
#     'importance': 1.0,
#     'emotion': 'fearless',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Rico',
#     'role': 'A rival faction member leading the attack',
#     'importance': 0.8,
#     'emotion': 'angry',
#     'sentiment': -0.5,
#     'importance_rank': 3},
#    {'name': 'Dr. Malik',
#     'role': 'Trying to intervene and stop the fighting',
#     'importance': 0.9,
#     'emotion': 'desperate',
#     'sentiment': -0.2,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'The Turning Point',
#   'number': 32,
#   'summary': 'A critical moment where Tessa makes a brave decision.',
#   'chapter': 'Chapter 10: The Battle for Survival',
#   'location': 'Amidst the chaos of the battle',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Tessa',
#     'role': 'Taking a stand to protect her friends',
#     'importance': 1.0,
#     'emotion': 'heroic',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Captain Reyes',
#     'role': 'Realizing the need for unity',
#     'importance': 0.8,
#     'emotion': 'determined',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Rico',
#     'role': "Caught off guard by Tessa's bravery",
#     'importance': 0.7,
#     'emotion': 'surprised',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'The Aftermath',
#   'number': 33,
#   'summary': 'The battle leaves the fleet in disarray and uncertainty.',
#   'chapter': 'Chapter 10: The Battle for Survival',
#   'location': 'Main Hall of the Fleet Ship',
#   'importance': 1.0,
#   'conflict': 0.8,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Assessing the damage and loss of life',
#     'importance': 0.9,
#     'emotion': 'sorrowful',
#     'sentiment': -0.6,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Reflecting on the cost of the conflict',
#     'importance': 0.8,
#     'emotion': 'haunted',
#     'sentiment': -0.5,
#     'importance_rank': 3},
#    {'name': 'Captain Reyes',
#     'role': 'Trying to restore order and hope',
#     'importance': 0.9,
#     'emotion': 'resolute',
#     'sentiment': 0.1,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Scene 1: The Aftermath',
#   'number': 34,
#   'summary': 'The fleet assesses the damage and loss after the battle.',
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'location': 'Command Center',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': "Leader reflecting on the battle's consequences",
#     'importance': 1.0,
#     'emotion': 'somber',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Jax',
#     'role': 'Crew member grappling with guilt',
#     'importance': 1.0,
#     'emotion': 'remorseful',
#     'sentiment': -0.7,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1},
#  {'title': 'Scene 2: A Moment of Silence',
#   'number': 35,
#   'summary': 'The crew holds a memorial for those lost in the conflict.',
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'location': 'Observation Deck',
#   'importance': 1.0,
#   'conflict': 0.2,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leading the memorial service',
#     'importance': 1.0,
#     'emotion': 'sorrowful',
#     'sentiment': -0.6,
#     'importance_rank': 1},
#    {'name': 'Jax',
#     'role': 'Struggling to find closure',
#     'importance': 1.0,
#     'emotion': 'tearful',
#     'sentiment': -0.8,
#     'importance_rank': 2},
#    {'name': 'Mira',
#     'role': 'Offering support to Jax',
#     'importance': 0.8,
#     'emotion': 'empathetic',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 5},
#  {'title': 'Scene 3: Conversations in the Dark',
#   'number': 36,
#   'summary': 'Characters share their thoughts and feelings about the future.',
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'location': 'Crew Quarters',
#   'importance': 1.0,
#   'conflict': 0.4,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Discussing the need for unity',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Jax',
#     'role': 'Expressing doubts about their mission',
#     'importance': 1.0,
#     'emotion': 'conflicted',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Mira',
#     'role': 'Encouraging hope and resilience',
#     'importance': 1.0,
#     'emotion': 'optimistic',
#     'sentiment': 0.6,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3},
#  {'title': 'Scene 4: Reflections on Choices',
#   'number': 37,
#   'summary': 'Elara and Jax confront their past decisions and their impact on the crew.',
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'location': "Elara's Quarters",
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Reflecting on her leadership choices',
#     'importance': 1.0,
#     'emotion': 'introspective',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Jax',
#     'role': 'Acknowledging his mistakes',
#     'importance': 1.0,
#     'emotion': 'ashamed',
#     'sentiment': -0.6,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 2},
#  {'title': 'Scene 5: A New Vision',
#   'number': 38,
#   'summary': 'The crew comes together to discuss their vision for the future.',
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'location': 'Main Hall',
#   'importance': 1.0,
#   'conflict': 0.3,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Inspiring the crew with a new mission',
#     'importance': 1.0,
#     'emotion': 'hopeful',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Jax',
#     'role': 'Voicing concerns but willing to contribute',
#     'importance': 1.0,
#     'emotion': 'cautiously optimistic',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Mira',
#     'role': 'Facilitating the discussion',
#     'importance': 0.8,
#     'emotion': 'supportive',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 4},
#  {'title': 'Unity in Diversity',
#   'number': 39,
#   'summary': 'The fleet gathers for a council meeting to discuss their future.',
#   'chapter': 'Chapter 12: A New Beginning',
#   'location': 'Main assembly hall of the flagship',
#   'importance': 1.0,
#   'conflict': 0.3,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, guiding the discussions',
#     'importance': 1.0,
#     'emotion': 'Determined',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Scientist advocating for sustainable practices',
#     'importance': 0.8,
#     'emotion': 'Hopeful',
#     'sentiment': 1.0,
#     'importance_rank': 3},
#    {'name': 'Commander Jax',
#     'role': 'Military leader concerned about security',
#     'importance': 0.7,
#     'emotion': 'Wary',
#     'sentiment': 0.0,
#     'importance_rank': 4},
#    {'name': 'Lina',
#     'role': 'Community organizer representing the civilians',
#     'importance': 0.9,
#     'emotion': 'Passionate',
#     'sentiment': 1.0,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 3},
#  {'title': 'Building the Future',
#   'number': 40,
#   'summary': 'Teams are formed to start constructing the new settlement.',
#   'chapter': 'Chapter 12: A New Beginning',
#   'location': 'Surface of the new planet',
#   'importance': 1.0,
#   'conflict': 0.4,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Overseeing the construction efforts',
#     'importance': 1.0,
#     'emotion': 'Inspired',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Leading the environmental assessment team',
#     'importance': 0.8,
#     'emotion': 'Focused',
#     'sentiment': 1.0,
#     'importance_rank': 3},
#    {'name': 'Commander Jax',
#     'role': 'Ensuring safety protocols are followed',
#     'importance': 0.7,
#     'emotion': 'Protective',
#     'sentiment': 0.0,
#     'importance_rank': 4},
#    {'name': 'Lina',
#     'role': 'Motivating the workers and fostering teamwork',
#     'importance': 0.9,
#     'emotion': 'Encouraging',
#     'sentiment': 1.0,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 2},
#  {'title': 'Facing Challenges Together',
#   'number': 41,
#   'summary': 'The fleet encounters unexpected obstacles during construction.',
#   'chapter': 'Chapter 12: A New Beginning',
#   'location': 'Construction site on the new planet',
#   'importance': 0.9,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Resolving conflicts among team members',
#     'importance': 1.0,
#     'emotion': 'Calm',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Finding solutions to environmental issues',
#     'importance': 0.8,
#     'emotion': 'Stressed',
#     'sentiment': 0.0,
#     'importance_rank': 3},
#    {'name': 'Commander Jax',
#     'role': 'Dealing with security threats from wildlife',
#     'importance': 0.7,
#     'emotion': 'Alert',
#     'sentiment': -0.5,
#     'importance_rank': 4},
#    {'name': 'Lina',
#     'role': 'Mediating disputes and keeping morale high',
#     'importance': 0.9,
#     'emotion': 'Optimistic',
#     'sentiment': 1.0,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 1},
#  {'title': 'A Ceremony of Hope',
#   'number': 42,
#   'summary': 'The fleet holds a ceremony to celebrate their new beginning.',
#   'chapter': 'Chapter 12: A New Beginning',
#   'location': 'Central plaza of the new settlement',
#   'importance': 1.0,
#   'conflict': 0.2,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Delivering a speech about unity and hope',
#     'importance': 1.0,
#     'emotion': 'Uplifted',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Sharing scientific insights about their new home',
#     'importance': 0.8,
#     'emotion': 'Excited',
#     'sentiment': 1.0,
#     'importance_rank': 3},
#    {'name': 'Commander Jax',
#     'role': 'Acknowledging the sacrifices made during the journey',
#     'importance': 0.7,
#     'emotion': 'Reflective',
#     'sentiment': 0.0,
#     'importance_rank': 4},
#    {'name': 'Lina',
#     'role': 'Leading the community in celebration',
#     'importance': 0.9,
#     'emotion': 'Joyful',
#     'sentiment': 1.0,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 4}]

# %%
chapters
# Out:
# [{'summary': 'As Earth faces its final days, the last generation ships are prepared for launch.',
#   'description': 'The chapter introduces the dire state of Earth, showcasing the environmental collapse and societal breakdown. We meet key characters, including Captain Elara, the determined leader of the fleet, and Dr. Malik, a scientist who has dedicated his life to finding a new home. The urgency of their mission is palpable as they say goodbye to their home planet, setting the stage for the journey ahead.',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'chapter': 'Chapter 1: The Last Days of Earth',
#   'characters': {'Narrator': {'count': 1,
#     'role': 'Describes the environmental collapse and societal breakdown.'},
#    'Captain Elara': {'count': 2,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'Dr. Malik': {'count': 2,
#     'role': 'Analyzes data on potential habitable planets.'},
#    'Various Families': {'count': 1,
#     'role': 'Express their sorrow and hope as they part ways.'}},
#   'locations': {'Earth, various locations': {'count': 1,
#     'role': 'A panoramic view of Earth’s devastation as the last generation ships are being prepared for launch.'},
#    'Launch site': {'count': 1,
#     'role': 'Key characters say their goodbyes to loved ones and the Earth they are leaving behind.'}},
#   'scenes': 2},
#  {'summary': 'The generation ships gather in orbit, each with its own mission and crew.',
#   'description': "This chapter explores the diverse backgrounds of the ships' crews, highlighting the tensions and alliances that form among them. We meet characters like engineer Tessa, who struggles with her past, and diplomat Rian, who tries to maintain peace. The chapter ends with the fleet finally launching into the unknown.",
#   'importance': 1.0,
#   'conflict': 0.6,
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'characters': {'Captain Elara': {'count': 5,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'Engineer Tessa': {'count': 5,
#     'role': 'Struggling with her past while preparing her ship for launch.'},
#    'Diplomat Rian': {'count': 5,
#     'role': 'Trying to mediate between different ship crews to maintain peace.'},
#    'Commander Jax': {'count': 1,
#     'role': 'Leader of a rival ship, demanding more resources.'}},
#   'locations': {'Orbit around Earth': {'count': 1,
#     'role': "The generation ships arrive in orbit around Earth, each ship's crew preparing for departure."},
#    'Fleet assembly area': {'count': 2,
#     'role': 'Conflicts arise between different ship crews over resources and leadership.'},
#    'Docking bays of the ships': {'count': 1,
#     'role': 'The crews make last-minute checks and preparations for launch.'},
#    'Space, departing from Earth': {'count': 1,
#     'role': 'The fleet launches, leaving Earth behind and venturing into space.'}},
#   'scenes': 5},
#  {'summary': 'The fleet navigates the challenges of deep space travel.',
#   'description': 'As the ships travel through the vast emptiness of space, the crew faces technical malfunctions and resource shortages. Tensions rise as different factions within the fleet clash over leadership and survival strategies. We see the first signs of dissent among the crew, particularly between Captain Elara and a rebellious faction led by First Officer Jax.',
#   'importance': 1.0,
#   'conflict': 0.8,
#   'chapter': 'Chapter 3: The Void of Space',
#   'characters': {'Captain Elara': {'count': 1,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'First Officer Jax': {'count': 1,
#     'role': "Challenging Elara's decisions and advocating for a different approach"},
#    'Engineer Mira': {'count': 1,
#     'role': 'Trying to fix the malfunction while dealing with crew panic'}},
#   'locations': {'Control Room of the flagship': {'count': 1,
#     'role': 'The fleet encounters a critical technical malfunction that threatens their journey.'}},
#   'scenes': 1},
#  {'summary': 'The crew grapples with memories of Earth and their lost lives.',
#   'description': "Flashbacks reveal the characters' lives on Earth, their reasons for leaving, and the emotional toll of their journey. We delve into the backstories of characters like Dr. Malik and Tessa, exploring their motivations and regrets. This chapter emphasizes the theme of nostalgia and the struggle to let go of the past.",
#   'importance': 0.8,
#   'conflict': 0.5,
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'characters': {'Dr. Malik': {'count': 4,
#     'role': 'Analyzes data on potential habitable planets.'},
#    "Malik's Family": {'count': 1, 'role': 'Symbolizes what he lost'},
#    'Tessa': {'count': 4,
#     'role': 'A young engineer with dreams of exploration'},
#    "Tessa's Parents": {'count': 1,
#     'role': 'Represent her motivation to leave Earth'},
#    'Crew Members': {'count': 3,
#     'role': 'Represent diverse backgrounds and regrets'}},
#   'locations': {"Earth, Dr. Malik's home": {'count': 1,
#     'role': 'Dr. Malik reflects on his final moments on Earth, saying goodbye to his family.'},
#    "Earth, Tessa's childhood home": {'count': 1,
#     'role': 'Tessa recalls her childhood and the moments that led her to join the fleet.'},
#    'Common area of the generation ship': {'count': 2,
#     'role': 'The crew gathers to share their stories, revealing their regrets and fears.'},
#    "Ship's communication room": {'count': 1,
#     'role': 'The crew listens to recordings from Earth, stirring deep emotions.'}},
#   'scenes': 5},
#  {'summary': 'The fleet encounters an alien vessel, leading to unexpected consequences.',
#   'description': "The fleet's first contact with an alien species brings both wonder and danger. The crew must navigate the complexities of communication and trust. Characters like diplomat Rian and Captain Elara work together to establish a dialogue, but misunderstandings lead to a tense standoff. This encounter raises questions about the nature of life in the universe.",
#   'importance': 1.0,
#   'conflict': 0.9,
#   'chapter': 'Chapter 5: The First Encounter',
#   'characters': {'Captain Elara': {'count': 5,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'Diplomat Rian': {'count': 4,
#     'role': 'Trying to mediate between different ship crews to maintain peace.'},
#    'Alien Commander Zorak': {'count': 1,
#     'role': 'Leader of the alien vessel, feeling threatened'}},
#   'locations': {'Bridge of the flagship': {'count': 2,
#     'role': 'Tensions rise as factions begin to form within the fleet.'},
#    'Communication room': {'count': 2,
#     'role': 'The fleet attempts to communicate with the alien vessel, leading to a breakthrough and confusion.'},
#    'Space between the two vessels': {'count': 1,
#     'role': 'A misinterpretation of signals leads to a standoff between the fleets.'}},
#   'scenes': 5},
#  {'summary': 'Internal conflicts escalate as factions within the fleet vie for control.',
#   'description': 'As resources dwindle, factions within the fleet become more pronounced. First Officer Jax leads a rebellion against Captain Elara, believing she is unfit to lead. The chapter explores themes of loyalty and betrayal, as characters must choose sides. Tessa finds herself torn between her loyalty to Elara and her growing admiration for Jax.',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'chapter': 'Chapter 6: Divided Loyalties',
#   'characters': {'Captain Elara': {'count': 1,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'First Officer Jax': {'count': 1,
#     'role': "Challenging Elara's decisions and advocating for a different approach"},
#    'Tessa': {'count': 1,
#     'role': 'A young engineer with dreams of exploration'}},
#   'locations': {"Fleet's central command room": {'count': 1,
#     'role': 'Tensions rise as factions begin to form within the fleet.'}},
#   'scenes': 1},
#  {'summary': 'The fleet discovers a derelict colony ship with survivors.',
#   'description': 'The fleet stumbles upon a long-lost colony ship, revealing survivors who have been stranded for years. The survivors, led by the resourceful Mira, bring new perspectives and challenges. The chapter explores the dynamics between the two groups and the moral dilemmas of sharing limited resources. Tensions rise as both groups struggle to adapt to their new reality.',
#   'importance': 1.0,
#   'conflict': 0.8,
#   'chapter': 'Chapter 7: The Lost Colony',
#   'characters': {'Captain Elara': {'count': 1,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'First Officer Jax': {'count': 1,
#     'role': "Challenging Elara's decisions and advocating for a different approach"}},
#   'locations': {'Fleet Command Center': {'count': 1,
#     'role': 'The fleet detects a distress signal from a derelict colony ship.'}},
#   'scenes': 1},
#  {'summary': 'The fleet arrives at a potentially habitable planet, but not all is as it seems.',
#   'description': "The fleet discovers a planet that appears to be a perfect new home. However, as they begin to explore, they uncover dangerous wildlife and environmental hazards. Characters like Dr. Malik and Tessa lead expeditions to assess the planet's viability, but their findings create further divisions among the crew. The chapter ends with a shocking revelation about the planet's true nature.",
#   'importance': 1.0,
#   'conflict': 0.9,
#   'chapter': 'Chapter 8: A New Home?',
#   'characters': {'Captain Reyes': {'count': 3,
#     'role': 'Leader of the fleet, optimistic about the new planet'},
#    'Dr. Malik': {'count': 5,
#     'role': 'Analyzes data on potential habitable planets.'},
#    'Tessa': {'count': 5,
#     'role': 'A young engineer with dreams of exploration'},
#    'Crew Member 1': {'count': 1,
#     'role': 'Skeptical about the mission, voices concerns'},
#    'Crew Member 2': {'count': 1, 'role': 'Panicking and urging retreat'}},
#   'locations': {'Bridge of the lead ship': {'count': 2,
#     'role': 'The fleet arrives at the new planet and begins initial scans.'},
#    'Surface of the new planet': {'count': 1,
#     'role': "Dr. Malik and Tessa lead the first expedition to explore the planet's surface."},
#    'Dense forest on the planet': {'count': 1,
#     'role': 'The team encounters dangerous wildlife and environmental hazards.'},
#    "Fleet's common area": {'count': 1,
#     'role': "The findings from the expedition create divisions among the crew about the planet's viability."}},
#   'scenes': 5},
#  {'summary': 'The fleet splits into factions, each with its own vision for survival.',
#   'description': "With the discovery of the planet's dangers, factions within the fleet become irreparably divided. Captain Elara and First Officer Jax lead opposing groups, each advocating for different survival strategies. The chapter highlights the emotional toll of the conflict, as friendships are tested and alliances shift. Tessa finds herself caught in the middle, struggling to find her place.",
#   'importance': 1.0,
#   'conflict': 1.0,
#   'chapter': 'Chapter 9: The Great Divide',
#   'characters': {'Captain Elara': {'count': 4,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'First Officer Jax': {'count': 4,
#     'role': "Challenging Elara's decisions and advocating for a different approach"},
#    'Tessa': {'count': 4,
#     'role': 'A young engineer with dreams of exploration'},
#    'Crew Members': {'count': 3,
#     'role': 'Represent diverse backgrounds and regrets'},
#    'Dr. Mira': {'count': 1, 'role': "Scientist supporting Elara's plan"}},
#   'locations': {'Observation Deck': {'count': 1,
#     'role': "The fleet uncovers the planet's hostile environment, leading to panic and fear."},
#    'Main Hall': {'count': 1,
#     'role': 'Elara and Jax present their survival strategies to the crew, igniting tensions.'},
#    'Docking Bay': {'count': 1,
#     'role': 'The factions officially split, leading to emotional confrontations.'},
#    'Common Area': {'count': 1,
#     'role': 'The emotional fallout of the split affects the entire fleet.'}},
#   'scenes': 4},
#  {'summary': 'A confrontation between factions leads to a desperate struggle for control.',
#   'description': "Tensions reach a boiling point as the factions clash over resources and leadership. The chapter is filled with action and conflict, showcasing the desperation of the characters. Key moments include Tessa's bravery in defending her friends and Dr. Malik's attempts to mediate peace. The battle leaves lasting scars on the fleet and its members.",
#   'importance': 1.0,
#   'conflict': 1.0,
#   'chapter': 'Chapter 10: The Battle for Survival',
#   'characters': {'Tessa': {'count': 4,
#     'role': 'A young engineer with dreams of exploration'},
#    'Dr. Malik': {'count': 3,
#     'role': 'Analyzes data on potential habitable planets.'},
#    'Captain Reyes': {'count': 3,
#     'role': 'Leader of the fleet, optimistic about the new planet'},
#    'Rico': {'count': 2, 'role': 'A rival faction member leading the attack'}},
#   'locations': {'Main Hall of the Fleet Ship': {'count': 2,
#     'role': 'Factions gather to discuss their grievances and demands.'},
#    'Resource Storage Bay': {'count': 1,
#     'role': 'Tensions erupt into violence as factions clash over resources.'},
#    'Amidst the chaos of the battle': {'count': 1,
#     'role': 'A critical moment where Tessa makes a brave decision.'}},
#   'scenes': 4},
#  {'summary': 'In the aftermath of the conflict, characters reflect on their choices and losses.',
#   'description': 'The aftermath of the battle forces the characters to confront their actions and the consequences of their choices. We see moments of grief, regret, and reconciliation as characters like Captain Elara and Jax come to terms with their decisions. The chapter emphasizes the importance of unity and the search for a shared vision of home.',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'characters': {'Captain Elara': {'count': 5,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'Jax': {'count': 5, 'role': 'Crew member grappling with guilt'},
#    'Mira': {'count': 3, 'role': 'Offering support to Jax'}},
#   'locations': {'Command Center': {'count': 1,
#     'role': 'The fleet assesses the damage and loss after the battle.'},
#    'Observation Deck': {'count': 1,
#     'role': "The fleet uncovers the planet's hostile environment, leading to panic and fear."},
#    'Crew Quarters': {'count': 1,
#     'role': 'Characters share their thoughts and feelings about the future.'},
#    "Elara's Quarters": {'count': 1,
#     'role': 'Elara and Jax confront their past decisions and their impact on the crew.'},
#    'Main Hall': {'count': 1,
#     'role': 'Elara and Jax present their survival strategies to the crew, igniting tensions.'}},
#   'scenes': 5},
#  {'summary': 'The fleet unites to forge a new path forward, embracing their shared journey.',
#   'description': 'In the final chapter, the fleet comes together to create a new society on the planet. Characters work collaboratively to build a future, drawing on their diverse skills and experiences. The chapter ends with a sense of hope and possibility as they look to the stars, ready to embrace their new home and the challenges that lie ahead. Themes of resilience and community are highlighted as they redefine what home means to them.',
#   'importance': 1.0,
#   'conflict': 0.4,
#   'chapter': 'Chapter 12: A New Beginning',
#   'characters': {'Captain Elara': {'count': 4,
#     'role': 'Oversees the final preparations for the fleet.'},
#    'Dr. Malik': {'count': 4,
#     'role': 'Analyzes data on potential habitable planets.'},
#    'Commander Jax': {'count': 4,
#     'role': 'Leader of a rival ship, demanding more resources.'},
#    'Lina': {'count': 4,
#     'role': 'Community organizer representing the civilians'}},
#   'locations': {'Main assembly hall of the flagship': {'count': 1,
#     'role': 'The fleet gathers for a council meeting to discuss their future.'},
#    'Surface of the new planet': {'count': 1,
#     'role': "Dr. Malik and Tessa lead the first expedition to explore the planet's surface."},
#    'Construction site on the new planet': {'count': 1,
#     'role': 'The fleet encounters unexpected obstacles during construction.'},
#    'Central plaza of the new settlement': {'count': 1,
#     'role': 'The fleet holds a ceremony to celebrate their new beginning.'}},
#   'scenes': 4}]

# %%
# save the updated story outline to a file
with open(f"json/{story_name}/story_outline.json", "w") as f:
    json.dump(story_outline, f, indent=4)

# %% [markdown]
# ## generate text

# %%
# read in story outline
with open(f"json/{story_name}/story_outline.json") as f:
    story_outline = json.load(f)

title = story_outline["title"]
chapters = story_outline["chapters"]
scenes = story_outline["scenes"]
chapter_names = [chapter["chapter"] for chapter in chapters]

# %%
# create a folder to store the chapter files
if not os.path.exists(f"json/{story_name}/chapters"):
    os.makedirs(f"json/{story_name}/chapters")

# %%
for i, chapter in enumerate(chapter_names):
    if i != 6:
        continue
    chap_scenes = [scene for scene in scenes if scene["chapter"] == chapter]
    num_scenes = len(chap_scenes)
    print(f"{chapter}")
    print(f"Number of scenes: {num_scenes}")
    prompt = f"""You are a novelist. Using the story outline below, please write out {chapter}, 
                delineating each scene with "XXX" and making sure each scene has exactly the correct 
                characters (and their respective emotions, importance, etc.), location, and using the 
                chapter and scene summaries to guide your writing. 
                All (and no other) characters and locations should be used.

                Don't explicitly write the scene titles or locations in your output. Each scene should 
                be at least 10 paragraphs long. This chapter should have exactly {num_scenes} scene{'s' if num_scenes > 1 else ''}.

                Here is the story outline:
                {chap_scenes}

                Just output the chapter text (with "XXX" dividers between each scene) and nothing else. 
                Don't add "XXX" at the end of the last scene.
                """
    
    invalid_input = True
    while invalid_input: # try until valid input
        # see if exception is thrown
        try:
            res = llm.invoke(prompt)
            invalid_input = False
        except Exception as e:
            print("Exception thrown. Trying again.")
            print("Error:", e)
            invalid_input = True

    # save the chapter text to a file
    with open(f"json/{story_name}/chapters/{chapter}.txt", "w") as f:
        f.write(res.content)

    print(f"{chapter} written.")
# Out:
# Chapter 7: The Lost Colony
# Number of scenes: 1
# Chapter 7: The Lost Colony written.

# %%
# check number of scenes in each chapter
for i, chapter in enumerate(chapters):
    # read in chapter text
    with open(f"json/{story_name}/chapters/{chapter['chapter']}.txt") as f:
        chapter_text = f.read()
    
    # count number of scenes (number of 'XXX' dividers + 1)
    num_scenes = chapter_text.count("XXX") + 1

    # compare to expected number of scenes
    if num_scenes == chapter["scenes"]:
        print(f"{chapter['chapter']} has the correct number of scenes.")
    else:
        print(f"{chapter['chapter']} has the wrong number of scenes. Expected {chapter['scenes']}, got {num_scenes}.")
# Out:
# Chapter 1: The Last Days of Earth has the correct number of scenes.
# Chapter 2: The Fleet Assembles has the correct number of scenes.
# Chapter 3: The Void of Space has the correct number of scenes.
# Chapter 4: Echoes of the Past has the correct number of scenes.
# Chapter 5: The First Encounter has the correct number of scenes.
# Chapter 6: Divided Loyalties has the correct number of scenes.
# Chapter 7: The Lost Colony has the correct number of scenes.
# Chapter 8: A New Home? has the correct number of scenes.
# Chapter 9: The Great Divide has the correct number of scenes.
# Chapter 10: The Battle for Survival has the correct number of scenes.
# Chapter 11: Reflections in the Stars has the correct number of scenes.
# Chapter 12: A New Beginning has the correct number of scenes.

# %%
# combine all chapters into a single file
chapter_files = [f"json/{story_name}/chapters/{chapter['chapter']}.txt" for chapter in chapters]

# read in all chapter files
chapter_texts = []
for file in chapter_files:
    with open(file) as f:
        chapter_texts.append(f.read())

chapter_texts
# Out:
# ['The sky hung heavy with ash, a muted gray blanket smothering the remnants of what was once a vibrant blue. The air was thick with the scent of decay, a constant reminder of the environmental collapse that had consumed the planet. Cities lay in ruins, their skeletal structures jutting out like broken teeth against the horizon. The Narrator\'s voice echoed in the silence, a somber reflection on the devastation that had become the new normal. \n\nIn the distance, the last generation ships loomed, colossal vessels that promised a flicker of hope in the darkness. Captain Elara stood at the edge of the launch site, her gaze fixed on the ships as they prepared for their final journey. Determination coursed through her veins, a fierce resolve to lead the remnants of humanity into the unknown. She could feel the weight of the world pressing down on her shoulders, but she refused to falter. \n\nDr. Malik was nearby, his brow furrowed in concentration as he analyzed data on potential habitable planets. Anxiety gnawed at him, a relentless companion as he sifted through the numbers and projections. Each statistic felt like a ticking clock, counting down the moments until they would leave Earth behind forever. He glanced at Elara, her steadfast demeanor a stark contrast to his own turmoil. They were both aware of the stakes, the lives that depended on their success. \n\nAs the sun dipped below the horizon, casting an eerie glow over the launch site, the Narrator\'s voice painted a vivid picture of the chaos that had led them to this moment. The societal breakdown had been swift and brutal, a cascade of failures that left humanity scrambling for survival. Elara and Malik were among the few who had managed to hold onto hope, but even that was beginning to fray at the edges. \n\nThe preparations for launch were underway, a flurry of activity that belied the gravity of the situation. Engineers and technicians moved with purpose, their faces set in grim determination. Elara moved among them, offering words of encouragement, her heart heavy with the knowledge that this would be the last time they would see their home. Each farewell felt like a dagger to her heart, a reminder of what they were leaving behind. \n\nDr. Malik joined her, his voice barely above a whisper as he shared his concerns about the viability of their destination. "What if we don\'t find a suitable planet? What if this is all for nothing?" His words hung in the air, a palpable tension that threatened to unravel the fragile hope they clung to. Elara met his gaze, her own fears mirrored in his eyes. \n\n"We have to believe," she replied, her voice steady despite the turmoil within. "We owe it to those who can\'t leave, to make this journey count." The determination in her voice sparked a flicker of hope in Malik, but it was quickly overshadowed by the weight of their mission. They were not just leaving Earth; they were carrying the hopes and dreams of an entire species with them. \n\nAs night fell, the launch site transformed into a surreal landscape, illuminated by the harsh glow of floodlights. The ships stood ready, their metallic surfaces gleaming ominously. The Narrator\'s voice resonated with the gravity of the moment, a reminder of the sacrifices that had brought them to this point. Elara took a deep breath, steeling herself for what lay ahead. \n\nThe final countdown began, a chilling reminder of the time slipping away. Elara\'s heart raced as she prepared to bid farewell to her family and friends. She could see them gathered at the edge of the launch site, their faces a mixture of sorrow and pride. Each step toward them felt like a farewell to her very soul, a painful acknowledgment of the life she was leaving behind. \n\nXXX\n\nThe atmosphere was thick with emotion as Captain Elara approached her family, her heart heavy with the weight of impending separation. The launch site buzzed with activity, but all she could focus on were the faces of her loved ones, etched wit ...
#  'Captain Elara stood at the command console of the flagship, her gaze fixed on the vast expanse of stars beyond the viewport. The fleet had finally arrived in orbit around Earth, a sight both breathtaking and daunting. Each generation ship, a testament to human ingenuity and resilience, floated in formation, their hulls gleaming under the distant sunlight. Elara felt a surge of determination; this was the moment they had all worked towards, the culmination of years of planning and sacrifice. She could almost hear the whispers of her crew, their hopes and fears mingling in the silence of space. \n\nAs she moved through the ship, Elara could sense the tension in the air. The crew was busy preparing for departure, but there was an undercurrent of anxiety that she couldn’t ignore. She stopped to speak with Engineer Tessa, who was hunched over a control panel, her fingers flying over the keys. Tessa’s brow was furrowed, and Elara could see the flicker of doubt in her eyes. “Tessa, how are the systems holding up?” Elara asked, her voice steady. \n\nTessa looked up, her expression a mix of anxiety and determination. “I’m just double-checking everything, Captain. I want to make sure we’re ready for anything.” Elara nodded, appreciating Tessa’s dedication. But she could see the shadows of the engineer’s past lurking just beneath the surface, threatening to pull her under. “You’ve got this. We all believe in you,” Elara reassured her, hoping to instill some confidence. \n\nMeanwhile, Diplomat Rian was busy coordinating with the other ships, his demeanor calm but his mind racing. He understood the delicate balance of power among the crews and knew that maintaining peace was crucial. As he floated between ships, he could feel the weight of their expectations pressing down on him. “We need to work together,” he urged a group of engineers from another vessel, trying to mediate their concerns over resource allocation. \n\nThe engineers exchanged glances, their expressions skeptical. “Why should we trust you?” one of them challenged, crossing his arms defiantly. Rian took a deep breath, reminding himself of the importance of diplomacy in this fragile moment. “Because our survival depends on it. We’re all in this together, and we need to support each other if we want to succeed.” \n\nAs the discussions continued, Elara returned to the command console, her heart heavy with the responsibility of leadership. She knew that the stakes were high, and any misstep could lead to chaos. The fleet was a fragile alliance, and she was determined to hold it together. She glanced out at the ships, each one a beacon of hope, and felt a renewed sense of purpose. \n\nXXX\n\nThe atmosphere in the fleet assembly area grew increasingly tense as conflicts began to surface among the crews. Elara stood at the center of the gathering, her frustration mounting as voices rose in heated arguments. “We need more resources!” Commander Jax of the rival ship shouted, his aggressive tone cutting through the air. “Our supplies are running low, and we can’t afford to be left behind!” \n\nElara stepped forward, trying to maintain control. “We all have limited resources, Commander. We need to find a way to share what we have.” But Jax was undeterred, his eyes blazing with defiance. “You don’t understand! My crew is counting on me to protect them. We can’t just sit back and wait for handouts!” \n\nCaught in the middle, Tessa felt a wave of conflict wash over her. She had always been a team player, but the rising tensions made her question her loyalties. She glanced at Rian, who was frantically trying to negotiate a truce between the factions. “We can’t let this escalate,” he said, his voice strained. “We need to find common ground before it’s too late.” \n\nAs the arguments continued, Tessa’s anxiety bubbled to the surface. She wanted to speak up, to advocate for collaboration, but the fear of backlash held her back. Instead, she watched as the crews divided into factions, each o ...
#  'Captain Elara stood at the helm of the flagship, her hands gripping the console as if it were a lifeline. The control room buzzed with the frantic energy of the crew, their faces illuminated by the flickering screens that displayed a chaotic array of data. Alarms blared, a cacophony of warning signals that echoed through the metallic chamber, each one a reminder of the crisis unfolding around them. Elara’s heart raced, but she forced herself to maintain a calm exterior. She had to be the anchor in this storm, the steady hand guiding her crew through the void of space.\n\n“Status report!” she barked, her voice cutting through the noise. She turned to Engineer Mira, who was hunched over a terminal, her fingers flying across the keyboard. Mira’s brow was furrowed, her expression a mix of anxiety and determination. Elara could see the tension in her shoulders, the way she bit her lip as she worked. “Mira, we need to know what we’re dealing with.”\n\nMira glanced up, her eyes wide with worry. “Captain, we’ve lost power to the main thrusters. It’s a critical malfunction. I’m trying to reroute the energy from the auxiliary systems, but the crew is starting to panic. I can’t focus with all this noise.” Her voice trembled slightly, betraying the anxiety she was trying to suppress.\n\nElara nodded, understanding the weight of the situation. “I need you to stay focused, Mira. We can’t afford to lose control now. Jax, what’s your assessment?” She turned to her First Officer, who stood with arms crossed, a scowl etched on his face. The tension between them had been building for days, and now it threatened to boil over.\n\nJax stepped forward, his frustration palpable. “Elara, we can’t keep trying to fix this with band-aid solutions. We need to consider a full system reboot. It’s the only way to ensure we don’t drift into a gravitational pull we can’t escape.” His voice was sharp, challenging her authority in front of the crew. “You’re risking everyone’s lives by sticking to your plan.”\n\nElara felt a surge of anger at Jax’s insubordination, but she knew better than to let it show. “And what do you propose we do, Jax? Shut everything down and hope for the best? We don’t have that luxury. We need to stabilize the ship first.” She took a deep breath, trying to keep her voice steady. “We can’t afford to lose our momentum.”\n\nMira interjected, her voice rising above the din. “Captain, if we don’t act quickly, we could be stranded. I can try to fix the thrusters, but I need time. If Jax thinks a reboot is the answer, we should at least consider it.” Her eyes darted between Elara and Jax, sensing the growing tension. “We need to work together, not against each other.”\n\nElara felt the weight of her crew’s expectations pressing down on her. She was their leader, but the burden of that responsibility felt heavier than ever. “I appreciate your input, Mira, but we don’t have time for a debate. Jax, I need you to support Mira. Help her with the rerouting. We’ll keep the reboot as a last resort.” She turned back to Mira, her voice softening. “You can do this. I believe in you.”\n\nJax’s expression darkened, but he nodded, albeit reluctantly. “Fine. But if this doesn’t work, we’re going to have to reconsider our options.” He moved to assist Mira, his frustration simmering just beneath the surface. Elara watched them for a moment, her heart heavy with the knowledge that their unity was fragile. The void of space outside the ship felt more ominous than ever, a reminder of how quickly everything could unravel.\n\nAs Mira worked, Elara’s mind raced with possibilities. She could feel the weight of the crew’s eyes on her, their hopes and fears intertwined. The alarms continued to blare, a relentless reminder of their precarious situation. She had to make the right call, not just for herself, but for everyone aboard. The silence of space was unforgiving, and she couldn’t let it swallow them whole.',
#  "Dr. Malik stood in the dim light of his home, the walls echoing with memories that felt both distant and achingly close. The air was thick with the scent of old wood and the faintest hint of jasmine from the garden outside, a reminder of the life he had left behind. He glanced at the family portraits lining the walls, each frame a testament to moments that now felt like fragments of a dream. His heart ached as he traced the outline of a photograph featuring his wife and children, their smiles frozen in time, a stark contrast to the sorrow that now filled his chest.\n\n“Dad, are you coming?” The voice of his youngest son, Amir, broke through the silence, pulling him back to the present. Malik turned to see Amir standing at the doorway, his small frame silhouetted against the light. The boy’s eyes were wide with anticipation, but Malik could see the worry lurking beneath the surface. He forced a smile, but it felt heavy on his lips, a mask for the turmoil inside.\n\n“I’ll be right there, buddy,” he replied, his voice cracking slightly. He wanted nothing more than to hold his family close, to reassure them that everything would be alright. But deep down, he knew that he was about to embark on a journey that would take him far from them, perhaps forever. The weight of his decision pressed down on him, a burden he had carried for too long.\n\nAs he stepped outside, the sun dipped low on the horizon, casting a golden hue over the garden. His wife, Layla, was kneeling by the flowerbeds, her hands gently tending to the blooms. She looked up, her eyes meeting his, and in that moment, he saw the love and the pain reflected back at him. “You’re going to be late,” she said softly, her voice steady despite the tremor in her hands.\n\n“I know,” he replied, stepping closer. He knelt beside her, taking her hands in his. “I just… I wanted to say goodbye properly.” The words hung in the air, heavy with unspoken fears. Layla’s gaze softened, but he could see the tears pooling in her eyes, threatening to spill over.\n\n“Promise me you’ll come back,” she whispered, her voice breaking. “Promise me you’ll find a way.” Malik felt his heart shatter at her plea. He wanted to promise her the world, to assure her that he would return, but the truth was far more complicated. He could only nod, his throat tight with emotion.\n\nAs they embraced, he felt the warmth of her body against his, the familiar scent of her hair enveloping him. It was a moment he wished he could freeze in time, to hold onto forever. But the reality of his mission loomed large, a reminder that he was leaving everything he loved behind. He pulled back, looking into her eyes, trying to memorize every detail—the way her brow furrowed when she was worried, the way her lips curled into a smile when she was happy.\n\n“Take care of the kids,” he said, his voice barely above a whisper. “They need you.” Layla nodded, her expression resolute, but he could see the cracks in her facade. He turned to Amir, who was watching them with wide, innocent eyes. “Be brave, little man,” he said, kneeling to meet his son’s gaze. “You’re the man of the house now.”\n\nAmir nodded, though his lip trembled. Malik felt a pang of guilt wash over him. He was leaving his family to face a world that was already too harsh for them. With one last look at his wife and son, he turned away, each step feeling heavier than the last. The door closed behind him with a finality that echoed in his heart, a sound that marked the end of one chapter and the beginning of another.\n\nXXX\n\nTessa stood in the living room of her childhood home, the familiar surroundings stirring a whirlwind of emotions within her. The walls were adorned with drawings she had made as a child, each one a snapshot of her dreams and aspirations. She could almost hear the laughter of her parents as they encouraged her creativity, their voices a comforting melody that played in her mind. But now, as she looked around, nostalgia washed over her, mingling ...
#  'Captain Elara stood at the helm of the flagship, her eyes fixed on the vast expanse of stars that surrounded them. The bridge was alive with the hum of machinery and the soft beeping of consoles, but an undercurrent of tension filled the air. An unknown vessel had been detected on the scanners, and the crew was buzzing with a mix of curiosity and concern. Elara felt a knot tighten in her stomach; the unknown was always a source of anxiety, yet she was determined to face whatever lay ahead. She turned to her first officer, who was monitoring the readings closely. \n\n“Status report,” she commanded, her voice steady despite the turmoil within. The officer glanced up, his brow furrowed. “The vessel is approaching at a moderate speed, Captain. It’s unlike anything we’ve encountered before.” Elara nodded, her mind racing with possibilities. What could this vessel want? Were they friend or foe? She glanced at the viewscreen, where the silhouette of the alien ship loomed larger, its design both intriguing and intimidating. \n\n“Prepare for potential communication,” she instructed, her gaze shifting to Diplomat Rian, who was already at work, fingers dancing over the console as he prepared the necessary protocols. Rian looked up, excitement flickering in his eyes, but it was tempered by caution. “I’ll need time to analyze their signals, Captain. We can’t rush this.” \n\nElara felt a surge of impatience but understood the importance of careful deliberation. “I trust your judgment, Rian. Just keep me updated.” She turned back to the viewscreen, her heart pounding as the unknown vessel drew closer. The crew exchanged glances, their expressions a mix of hope and fear. Elara took a deep breath, steeling herself for what was to come. \n\nAs the alien ship entered hailing range, Rian’s fingers flew over the controls, attempting to establish a connection. Elara watched intently, her anxiety mounting. “We’re ready to transmit,” Rian announced, his voice steady but laced with anticipation. “On your command, Captain.” \n\n“Open a channel,” Elara ordered, her heart racing. The silence that followed felt deafening. She could feel the weight of the moment pressing down on her, the fate of their encounter hanging in the balance. “This is Captain Elara of the Starfleet. We come in peace.” \n\nThe response was immediate, a series of garbled signals that filled the room with static. Rian’s brow furrowed as he worked to decipher the sounds. “It’s… it’s unlike any language I’ve encountered,” he murmured, his excitement mingling with frustration. “I’ll need to analyze the patterns.” \n\nElara’s determination surged. “We can’t let fear dictate our actions. Keep trying, Rian. We need to understand them.” The tension in the room was palpable as they awaited a breakthrough, the unknown vessel looming ominously on the viewscreen. \n\nXXX\n\nIn the communication room, Rian was immersed in a sea of data, his mind racing as he attempted to translate the alien signals. The room was dimly lit, the glow of screens illuminating his focused expression. Elara stood beside him, her presence a steadying force amidst the chaos. “Any progress?” she asked, her voice low, almost a whisper. \n\n“Some,” Rian replied, his eyes darting across the screens. “I think I’ve identified a few key phrases, but it’s still fragmented. They seem to be expressing… concern?” His excitement was palpable, but it was tempered by the weight of uncertainty. \n\nElara felt a flicker of hope. “Concern? That’s a good sign, isn’t it?” She leaned closer, studying the patterns on the screen. “If they’re concerned, it means they’re not hostile.” \n\n“Or they could be defensive,” Rian countered, his brow furrowing. “We need to be cautious. I don’t want to misinterpret their intentions.” Elara nodded, understanding the delicate balance they were navigating. \n\n“Let’s try to establish a basic dialogue,” she suggested. “If we can convey our peaceful intentions, perhaps we can bridge the gap.” Rian hesitat ...
#  'Captain Elara stood at the helm of the fleet\'s central command room, her heart racing as she surveyed the faces of her crew. The air was thick with tension, a palpable energy that crackled like static electricity. She could feel the weight of their expectations pressing down on her shoulders, and the responsibility of leadership felt heavier than ever. The holographic display flickered above her, showing the fleet\'s current position in the vastness of space, but all she could focus on were the murmurs of dissent that had begun to rise among her crew.\n\n"Captain, we need to discuss our next move," First Officer Jax interjected, his voice cutting through the low hum of conversation. His frustration was evident, his brow furrowed as he stepped forward, challenging her authority. "The longer we wait, the more vulnerable we become. We can\'t just sit here and hope for the best."\n\nElara clenched her fists, trying to maintain her composure. She understood Jax\'s concerns; they were valid. But the last thing she wanted was to fracture the unity of the fleet. "I know the risks, Jax," she replied, her voice steady but strained. "But we need to consider all options. Rushing into a decision could lead to disaster."\n\nTessa, a crew member who had always admired Elara\'s leadership, stood off to the side, her heart pounding in her chest. She felt caught in the crossfire of the escalating conflict between her captain and first officer. Jax\'s passion was infectious, and she could see the fire in his eyes, but Elara\'s calm determination also resonated with her. How could she choose a side when both were fighting for the fleet\'s survival?\n\n"With all due respect, Captain," Jax pressed on, his voice rising slightly, "we can\'t afford to be indecisive. The enemy is out there, and they won\'t wait for us to figure things out. We need to take action now." His words hung in the air, charged with urgency, and Tessa felt the tension in the room shift as others began to nod in agreement.\n\nElara\'s jaw tightened, and she could feel the divide forming among her crew. Some were rallying behind Jax, their faces lit with the thrill of action, while others remained loyal to her, their expressions a mix of concern and uncertainty. "We need to work together," she insisted, her voice firm. "This isn\'t just about one decision; it\'s about the future of the fleet. We can\'t let our emotions cloud our judgment."\n\nJax shook his head, his frustration boiling over. "You’re asking us to wait while our enemies gather strength! We need to strike first, to show them we won\'t back down. If we don\'t act now, we risk losing everything." His passion was palpable, and Tessa could see the way some crew members were swayed by his fervor.\n\nElara took a deep breath, trying to quell the rising tide of anxiety within her. She could feel the loyalty of her crew wavering, and the thought of losing their trust was almost unbearable. "I understand your urgency, Jax, but we must be strategic. A hasty decision could lead to unnecessary casualties. We owe it to our crew to think this through."\n\nThe room fell silent, the weight of her words hanging heavily in the air. Tessa felt the conflict within her intensify. She admired Elara\'s cautious approach, but Jax\'s call to action resonated with her desire to protect her fellow crew members. She glanced around the room, searching for signs of support, but all she saw were faces torn between two leaders.\n\nFinally, Jax crossed his arms, his expression a mix of defiance and disappointment. "If you won\'t lead us into battle, then perhaps it\'s time for someone else to take the helm." His challenge echoed in the command room, and Tessa\'s heart sank. She had never seen Jax so passionate, yet the thought of a mutiny sent a chill down her spine.\n\nElara\'s eyes narrowed, her determination hardening. "I will not let this fleet be divided by fear or ambition. We are stronger together, and I will not allow anyone to undermine ...
#  'Captain Elara stood at the helm of the Fleet Command Center, her gaze fixed on the vast expanse of stars displayed on the holographic screen before her. The dim lights of the room flickered slightly, casting shadows that danced across the faces of her crew. The atmosphere was thick with tension, a palpable energy that crackled in the air as they processed the distress signal that had just come through. It was faint, almost lost among the cosmic noise, but it was there—a call for help from a derelict colony ship. Elara’s heart raced with a mix of excitement and trepidation. This could be a pivotal moment for the fleet, a chance to uncover what had happened to those who had vanished into the void.\n\n“Captain, we’re receiving the signal again,” a technician called out, his fingers flying over the control panel. “It’s coming from the coordinates we’ve pinpointed. It’s definitely a colony ship.” The words hung in the air, heavy with implications. Elara felt a surge of determination. This was what they had trained for, what they had hoped to find in the uncharted territories of space. But as she looked around the room, she could see the uncertainty etched on the faces of her crew. They were all aware of the risks involved in investigating a derelict ship, especially one that had been silent for so long.\n\n“Prepare a shuttle for immediate launch,” Elara commanded, her voice steady despite the whirlwind of thoughts racing through her mind. “We need to assess the situation and determine if there are survivors.” She could feel the weight of her decision pressing down on her, but she was resolute. The fleet had a duty to respond to distress signals, to seek out those in need. It was a fundamental part of their mission, and she would not turn her back on it now.\n\nFirst Officer Jax stepped forward, his brow furrowed with concern. “Captain, I understand the urgency, but we need to consider the potential dangers. A derelict ship could be a trap, or worse, it could be infested with something we’re not prepared to handle.” His voice was laced with anxiety, and Elara could see the worry in his eyes. Jax had always been the cautious one, the voice of reason when her instincts pushed her forward. She appreciated his perspective, but this time, she felt a fire within her that she couldn’t ignore.\n\n“I understand your concerns, Jax,” Elara replied, her tone firm yet empathetic. “But we can’t let fear dictate our actions. We have a responsibility to investigate. If there are survivors, we owe it to them to try.” She could see Jax’s shoulders tense at her words, the internal struggle playing out on his face. He was torn between his duty to protect the crew and the moral imperative to help those in need. Elara knew that this was a defining moment for both of them, a test of their leadership and their commitment to their mission.\n\n“Let’s not forget what happened with the last colony ship we encountered,” Jax pressed, his voice rising slightly. “We lost good people. We can’t afford to be reckless.” The memory of that mission hung heavy in the air, a ghost that haunted their every decision. Elara felt a pang of guilt at the thought, but she also knew that they couldn’t let past failures dictate their future. They had to learn from their experiences, not be paralyzed by them.\n\n“Jax, I appreciate your caution, but we have protocols in place for these situations,” Elara said, her voice softening. “We’ll send a small team to assess the ship. If it’s safe, we’ll bring back any survivors. If not, we’ll retreat and regroup. We can’t let fear hold us back.” She could see the conflict in Jax’s eyes, the battle between his instincts and his loyalty to her as captain. It was a delicate balance, one that she had to navigate carefully.\n\n“Alright, Captain,” Jax finally relented, though his voice was still tinged with apprehension. “I’ll prepare the team and run a full diagnostic on the shuttle before we launch.” Elara nodded, grateful for his cooperation, ...
#  'The bridge of the lead ship hummed with the low thrum of machinery, a comforting sound that accompanied the crew\'s anticipation. Captain Reyes stood at the helm, his eyes fixed on the viewscreen displaying the new planet, a swirling mass of blues and greens. Hope surged within him as he imagined the possibilities that lay ahead. "Prepare for initial scans," he commanded, his voice steady and confident. The crew moved with purpose, their excitement palpable. Tessa, a crew member with bright eyes and an infectious smile, was practically bouncing on her heels. \n\n"Can you believe it? This could be our new home!" she exclaimed, her enthusiasm lighting up the room. Reyes turned to her, a smile breaking across his face. "I can feel it too, Tessa. This planet has potential." But as he spoke, Dr. Malik, the chief scientist, stood at the console, his brow furrowed in concentration. He glanced up, skepticism etched on his face. "We need to be cautious, Captain. We don’t know what we’re dealing with yet." \n\nReyes nodded, acknowledging Malik\'s concerns but unwilling to let them dampen his spirits. "I understand, but we have to remain optimistic. We’ve come too far to turn back now." Tessa chimed in, "Exactly! Think of all the possibilities! New resources, a fresh start!" Malik sighed, his cautious demeanor contrasting sharply with the hopeful energy in the room. "Possibilities are one thing, but we need data. We can\'t let excitement cloud our judgment." \n\nAs the scans began, the tension in the air thickened. Reyes watched the readouts, his heart racing with anticipation. "Look at those readings! The atmosphere is breathable, and the surface conditions seem stable." Tessa leaned closer, her eyes wide with wonder. "This is incredible! We could set up a colony here!" Malik\'s expression remained grim. "We need to analyze the data further. There could be hidden dangers." \n\nThe crew continued their work, but the divide between hope and caution grew more pronounced. Reyes felt the weight of leadership pressing down on him. He wanted to inspire his crew, to lead them into a new era, but Malik\'s skepticism gnawed at him. "Let’s not rush into anything," Malik reiterated, his voice firm. "We need to be thorough." Reyes took a deep breath, trying to balance the conflicting emotions swirling within him. "Agreed, but let’s not forget why we’re here. We’re searching for a new home." \n\nXXX\n\nThe surface of the new planet was a kaleidoscope of colors, a vibrant landscape that seemed to pulse with life. Dr. Malik led the expedition, his determination evident as he focused on collecting data. Tessa followed closely, her curiosity piqued by the alien flora and fauna surrounding them. "Look at that plant!" she exclaimed, pointing to a towering structure with luminescent leaves. "It’s beautiful!" \n\nMalik, however, remained focused on his instruments, jotting down notes with a furrowed brow. "Beauty doesn’t equate to safety, Tessa. We need to be vigilant." Tessa nodded, but her excitement was hard to contain. "I know, but this is what we’ve been dreaming of! A chance to explore!" A crew member, skeptical of the mission, voiced his concerns. "What if something goes wrong? We don’t know what’s out here." \n\nMalik turned to the crew member, his voice steady. "That’s why we’re taking precautions. Stay close and keep your eyes open." Tessa felt a twinge of worry at the crew member\'s words but pushed it aside. She was determined to discover the wonders of this new world. As they ventured deeper into the forest, the atmosphere shifted, the air thickening with an unexplainable tension. \n\nSuddenly, a rustle in the underbrush sent a jolt of fear through Tessa. "Did you hear that?" she whispered, her heart racing. Malik raised a hand, signaling for silence. The crew held their breath, eyes darting around. Then, without warning, a creature burst from the foliage, its eyes glinting with primal instinct. Panic erupted among the crew as they scrambled t ...
#  'Captain Elara stood at the helm of the Observation Deck, her gaze fixed on the swirling tempest of colors that enveloped the planet below. The screens flickered with data, each line of code a stark reminder of the hostile environment they had just uncovered. Panic rippled through the crew, a palpable tension that hung in the air like a thick fog. Elara felt the weight of her position pressing down on her, but she steeled herself, determined to maintain order amidst the chaos. “We need to stay calm,” she urged, her voice steady despite the turmoil around her. “We’ve faced challenges before, and we will face this one together.”\n\nFirst Officer Jax stood beside her, arms crossed, his brow furrowed in frustration. “Together? You mean your way or the highway, Captain. This isn’t just a challenge; it’s a death sentence if we don’t rethink our approach.” His words cut through the air, igniting a spark of dissent among the crew members gathered around the deck. Tessa, a junior crew member, shifted nervously, her heart racing as she caught snippets of the escalating argument. She could feel the anxiety creeping in, a gnawing fear that threatened to overwhelm her. “Can’t we just focus on the data? There must be a way to analyze the situation without jumping to conclusions,” she suggested, her voice trembling slightly.\n\nElara turned to Jax, her determination unwavering. “We can’t afford to panic. We need to assess our options and make a plan. If we let fear dictate our actions, we’ll lose everything.” The tension in the room was thick, and Elara could sense the divide forming, a chasm that threatened to split the crew into factions. Jax’s defiance only fueled her resolve. “You’re not listening to reason, Elara. We need to consider all possibilities, including retreat. This planet is a death trap!” His voice rose, echoing off the metallic walls of the Observation Deck.\n\nTessa felt caught in the crossfire, her heart aching for both her captain and her first officer. She admired Elara’s strength but couldn’t shake the feeling that Jax had a point. “What if we’re not equipped to handle this? What if we’re putting everyone at risk?” she interjected, her voice barely above a whisper. The crew members around her murmured in agreement, their faces a mix of fear and uncertainty. Elara’s eyes softened for a moment, recognizing the weight of Tessa’s words, but she quickly masked her vulnerability with a steely resolve.\n\n“Listen to me,” Elara said, her voice rising above the murmurs. “We are explorers. We’ve faced the unknown before, and we’ve always come out stronger. We can’t let fear dictate our choices. We need to gather more data and formulate a strategy.” The crew fell silent, the tension palpable as they absorbed her words. Jax’s expression hardened, his skepticism evident. “And what if your strategy leads us to our doom? You’re asking us to gamble with our lives.”\n\nThe atmosphere in the Observation Deck was electric, charged with conflicting emotions. Tessa felt the weight of the moment pressing down on her, the anxiety swirling within her like a storm. She glanced between Elara and Jax, feeling the divide grow wider. “We need to work together,” she pleaded, her voice breaking slightly. “We can’t afford to split apart now.” But her words seemed to hang in the air, unanswered, as the two leaders stood firm in their convictions.\n\nAs the debate raged on, Elara’s determination clashed with Jax’s defiance, creating a rift that threatened to tear the crew apart. Tessa felt a deep sense of loss creeping in, the realization that their unity was crumbling before her eyes. “We can’t let this happen,” she thought desperately, wishing for a way to bridge the gap between her captain and her first officer. But as the tension escalated, she knew that the great divide was already forming, and there was little she could do to stop it.\n\nXXX\n\nThe Main Hall was filled with a charged atmosphere as Elara and Jax stood before the crew, ready to pr ...
#  'The tension in the Main Hall of the Fleet Ship was palpable, a thick fog of anxiety and frustration hanging in the air. Tessa stood at the forefront, her heart pounding with determination as she faced the assembly of faction leaders. The dim lights flickered overhead, casting shadows that danced across the faces of those gathered. Each faction had come with their grievances, their demands echoing in the cavernous space. Tessa’s voice rose above the murmurs, fueled by a fierce passion for her people’s needs. “We cannot continue to ignore the plight of those who are suffering! Our resources are dwindling, and we need a fair distribution plan!” \n\nDr. Malik, the mediator, shifted nervously at the side of the room. His brow furrowed with anxiety as he glanced between Tessa and Captain Reyes, who stood with arms crossed, his expression a mix of frustration and authority. “Tessa, I understand your concerns, but we must find a way to discuss this without escalating tensions further,” he urged, his voice steady yet laced with desperation. He could feel the weight of the room pressing down on him, the factions’ simmering anger threatening to boil over at any moment.\n\nCaptain Reyes cleared his throat, attempting to regain control of the situation. “We are all in this together, but we must prioritize the safety of the fleet. If we allow our differences to divide us, we risk losing everything.” His authoritative tone resonated, but the frustration in his eyes betrayed the struggle he faced in maintaining order. Tessa could see the cracks forming in the unity he sought to uphold, and it fueled her resolve. \n\n“Safety? What about our survival?” Tessa shot back, her voice rising with passion. “We can’t just sit here and pretend everything is fine while our people starve! We need action, not empty promises!” The room erupted into a cacophony of voices, each faction clamoring to be heard, their grievances overlapping in a chaotic symphony of discontent. Dr. Malik raised his hands in a futile attempt to calm the crowd, his heart racing as he sensed the impending storm.\n\nAs the arguments escalated, Tessa felt a surge of fearlessness wash over her. She had to stand firm for her friends and faction, even if it meant standing alone. “We need to come together and find a solution that works for everyone, not just the powerful!” she shouted, her voice cutting through the noise. The room fell silent for a moment, all eyes on her, and she felt the weight of their expectations pressing down on her shoulders.\n\nBut before she could continue, a loud crash echoed from the Resource Storage Bay, shattering the fragile peace. The sound sent a ripple of panic through the assembly, and Captain Reyes’s expression shifted from frustration to alarm. “Stay here! I’ll check it out!” he commanded, his authoritative voice slicing through the tension. Tessa exchanged a worried glance with Dr. Malik, who nodded, his anxiety palpable. They both knew that whatever was happening could change everything.\n\nXXX\n\nThe Resource Storage Bay was a scene of chaos. Tessa rushed in, her heart racing as she took in the sight before her. Factions clashed violently, shouts of anger and pain filling the air. Rico, a member of a rival faction, led the charge, his face twisted in rage as he swung a makeshift weapon at one of Tessa’s friends. Fear gripped her heart, but she pushed it aside, fueled by a fierce determination to protect those she cared about.\n\n“Stop! This isn’t the way!” Tessa shouted, her voice barely audible over the din of battle. She could see Dr. Malik trying to intervene, his desperate attempts to mediate drowned out by the chaos. Tessa’s friends were fighting back, but the odds were against them. She felt a surge of adrenaline as she charged forward, ready to defend her faction at all costs. “Get away from them!” she yelled, her voice fierce and unwavering.\n\nRico turned, surprise flashing across his face as he saw Tessa charging toward him. “You think yo ...
#  'Captain Elara stood at the command center, her gaze fixed on the vast expanse of space displayed on the main screen. The remnants of the battle still lingered in the air, a heavy silence enveloping the room as the crew assessed the damage. Reports of losses and injuries filtered in, each one a reminder of the cost they had paid. Elara felt a somber weight settle in her chest, the faces of those they had lost flashing through her mind like haunting specters. She turned to Jax, who was hunched over a console, his fingers trembling as he scrolled through the casualty list. The guilt etched on his face was palpable, and Elara felt a pang of empathy for him.\n\n“Jax,” she said softly, her voice barely above a whisper. “We did everything we could.” But even as she spoke, she knew the words felt hollow. The truth was that they had failed to protect their own. Jax looked up, his eyes glistening with unshed tears. “But it wasn’t enough, Captain. I should have done more.” His voice cracked, and Elara could see the remorse consuming him. She stepped closer, placing a reassuring hand on his shoulder, hoping to convey some semblance of comfort.\n\nThe command center was filled with the low hum of machinery and the distant chatter of crew members discussing the aftermath. Elara’s heart ached as she listened to their conversations, each one a reminder of the lives that had been irrevocably changed. She felt the weight of leadership pressing down on her, the burden of responsibility for every decision made. “We need to regroup,” she said, her voice steadier now. “We can’t let this defeat define us.” Jax nodded, but the doubt in his eyes lingered. \n\nAs they continued to assess the damage, Elara’s mind raced with thoughts of what lay ahead. They had to find a way to honor those they had lost while also forging a path forward. The crew needed hope, a reason to believe that their sacrifices had not been in vain. She glanced at Jax, who was still lost in his thoughts, and felt a surge of determination. “We will rebuild,” she declared, her voice rising with conviction. “We owe it to them.” \n\nJax finally met her gaze, and for a moment, the weight of his guilt seemed to lift. “You’re right, Captain. We can’t give up.” Elara felt a flicker of hope ignite within her. Together, they would face the challenges ahead, united in their resolve to honor the fallen and protect the living. \n\nXXX\n\nThe observation deck was dimly lit, the stars outside twinkling like distant memories. The crew gathered in silence, each person grappling with their grief as they prepared to hold a memorial for those lost in the conflict. Captain Elara stood at the forefront, her heart heavy with sorrow. She looked out at the faces of her crew, each one reflecting a mixture of pain and resilience. “We come together today to remember our fallen comrades,” she began, her voice trembling slightly. “They fought bravely, and their sacrifice will never be forgotten.”\n\nJax stood beside her, his eyes red-rimmed and glistening with tears. He felt the weight of loss pressing down on him, a suffocating reminder of the lives that had been extinguished too soon. As Elara spoke, he struggled to find the words to express his own grief. The memories of laughter and camaraderie flooded his mind, and he felt a deep sense of remorse for not being able to protect them. \n\nMira stood a few steps behind Jax, her heart aching for him. She could see the turmoil within him, the struggle to find closure amidst the pain. As Elara continued to speak, Mira reached out, gently squeezing Jax’s hand in a gesture of support. He turned to her, gratitude shining through his tears. “I don’t know how to move on from this,” he admitted, his voice barely above a whisper. \n\n“You don’t have to do it alone,” Mira replied softly, her eyes filled with empathy. “We’re all in this together.” Jax nodded, feeling a flicker of warmth in her words. The memorial service continued, and Elara shared stories of the fallen ...
#  'Captain Elara stood at the head of the long, polished table in the main assembly hall of the flagship, her gaze sweeping over the faces of her crew. The room was filled with a palpable tension, a mix of hope and uncertainty as they gathered to discuss their future on the new planet. She felt a surge of determination coursing through her veins; this was a pivotal moment for them all. “Thank you for coming,” she began, her voice steady and clear. “Today, we chart a course for our new beginning.” \n\nDr. Malik, seated to her right, leaned forward, his expression hopeful. “We have a unique opportunity here,” he said, his enthusiasm infectious. “This planet offers resources we’ve only dreamed of. If we approach this with sustainable practices, we can create a thriving community.” His passion for the environment was evident, and Elara admired his commitment. She nodded, encouraging him to continue. \n\nLina, representing the civilians, chimed in with fervor. “We need to ensure that everyone’s voice is heard in this process. It’s not just about survival; it’s about building a community where everyone feels valued.” Her eyes sparkled with passion, and Elara felt a wave of gratitude for her presence. Lina’s ability to connect with the crew and civilians alike was invaluable. \n\nCommander Jax, however, remained wary. He crossed his arms, his brow furrowed. “While I appreciate the optimism, we must also consider security. We don’t know what threats this planet may hold. We need to prioritize safety protocols before we dive into community building.” His protective nature was evident, but Elara sensed the tension in his voice. She understood his concerns but hoped to find a balance between caution and progress.\n\nAs the discussion unfolded, Elara facilitated the dialogue, ensuring that each voice was heard. The room buzzed with ideas, visions of what their new settlement could become. She felt a sense of unity forming among them, a shared purpose that transcended their individual roles. “Let’s create teams that can focus on both community building and security,” she suggested, hoping to bridge the gap between Jax’s concerns and Malik’s enthusiasm. \n\nThe meeting continued, with each member contributing their thoughts and ideas. Elara felt a renewed sense of hope as they brainstormed solutions, envisioning a future where they could thrive together. The challenges ahead were daunting, but she believed in the strength of their unity. As the meeting drew to a close, she felt a surge of inspiration. “Let’s take this energy and channel it into action. We have a new beginning waiting for us.” \n\nXXX\n\nOn the surface of the new planet, the sun shone brightly, casting a warm glow over the construction site. Captain Elara stood at the forefront, overseeing the efforts with a sense of purpose. She felt inspired by the sight of her crew working together, their determination evident in every movement. “Let’s make this place our home,” she called out, her voice ringing with enthusiasm. \n\nDr. Malik was busy leading the environmental assessment team, his focus unwavering. He examined the soil and flora, taking notes and sharing insights with his team. “We need to ensure that our construction methods are sustainable,” he reminded them, his hopeful demeanor driving the team forward. Elara admired his dedication; he was the heart of their environmental efforts. \n\nLina moved among the workers, her encouraging words lifting their spirits. “Remember, we’re not just building structures; we’re creating a community!” she shouted, her voice filled with passion. The workers responded with cheers, their energy revitalized by her presence. Elara felt a swell of pride as she watched Lina foster teamwork and camaraderie among the crew. \n\nMeanwhile, Commander Jax patrolled the perimeter, his protective instincts on high alert. He observed the surroundings, ensuring that safety protocols were being followed. “Stay vigilant,” he reminded his team, his expressi ...

# %%
# add chapter title to beginning of each chapter
combined_text = f"{title}\n\n"

for i, chapter in enumerate(chapters):
    combined_text += f"{chapter['chapter']}\n\n"
    combined_text += chapter_texts[i]
    combined_text += "\n\n"

combined_text
# Out:
# 'Starlight Refugees\n\nChapter 1: The Last Days of Earth\n\nThe sky hung heavy with ash, a muted gray blanket smothering the remnants of what was once a vibrant blue. The air was thick with the scent of decay, a constant reminder of the environmental collapse that had consumed the planet. Cities lay in ruins, their skeletal structures jutting out like broken teeth against the horizon. The Narrator\'s voice echoed in the silence, a somber reflection on the devastation that had become the new normal. \n\nIn the distance, the last generation ships loomed, colossal vessels that promised a flicker of hope in the darkness. Captain Elara stood at the edge of the launch site, her gaze fixed on the ships as they prepared for their final journey. Determination coursed through her veins, a fierce resolve to lead the remnants of humanity into the unknown. She could feel the weight of the world pressing down on her shoulders, but she refused to falter. \n\nDr. Malik was nearby, his brow furrowed in concentration as he analyzed data on potential habitable planets. Anxiety gnawed at him, a relentless companion as he sifted through the numbers and projections. Each statistic felt like a ticking clock, counting down the moments until they would leave Earth behind forever. He glanced at Elara, her steadfast demeanor a stark contrast to his own turmoil. They were both aware of the stakes, the lives that depended on their success. \n\nAs the sun dipped below the horizon, casting an eerie glow over the launch site, the Narrator\'s voice painted a vivid picture of the chaos that had led them to this moment. The societal breakdown had been swift and brutal, a cascade of failures that left humanity scrambling for survival. Elara and Malik were among the few who had managed to hold onto hope, but even that was beginning to fray at the edges. \n\nThe preparations for launch were underway, a flurry of activity that belied the gravity of the situation. Engineers and technicians moved with purpose, their faces set in grim determination. Elara moved among them, offering words of encouragement, her heart heavy with the knowledge that this would be the last time they would see their home. Each farewell felt like a dagger to her heart, a reminder of what they were leaving behind. \n\nDr. Malik joined her, his voice barely above a whisper as he shared his concerns about the viability of their destination. "What if we don\'t find a suitable planet? What if this is all for nothing?" His words hung in the air, a palpable tension that threatened to unravel the fragile hope they clung to. Elara met his gaze, her own fears mirrored in his eyes. \n\n"We have to believe," she replied, her voice steady despite the turmoil within. "We owe it to those who can\'t leave, to make this journey count." The determination in her voice sparked a flicker of hope in Malik, but it was quickly overshadowed by the weight of their mission. They were not just leaving Earth; they were carrying the hopes and dreams of an entire species with them. \n\nAs night fell, the launch site transformed into a surreal landscape, illuminated by the harsh glow of floodlights. The ships stood ready, their metallic surfaces gleaming ominously. The Narrator\'s voice resonated with the gravity of the moment, a reminder of the sacrifices that had brought them to this point. Elara took a deep breath, steeling herself for what lay ahead. \n\nThe final countdown began, a chilling reminder of the time slipping away. Elara\'s heart raced as she prepared to bid farewell to her family and friends. She could see them gathered at the edge of the launch site, their faces a mixture of sorrow and pride. Each step toward them felt like a farewell to her very soul, a painful acknowledgment of the life she was leaving behind. \n\nXXX\n\nThe atmosphere was thick with emotion as Captain Elara approached her family, her heart heavy with the weight of impending separation. The launch site buzzed with activity, but all she c ...

# %%
# save the combined text to a file
with open(f"scripts/{story_name}.txt", "w") as f:
    f.write(combined_text)

# %% [markdown]
# ## format story

# %%
# read in combined text
with open(f"scripts/{story_name}.txt") as f:
    story_text = f.read()

# %%
# replace curly quotes with straight quotes
story_text = story_text.replace("“", "\"").replace("”", "\"").replace("‘", "'").replace("’", "'")

# %%
# save the combined text to a file
with open(f"scripts/{story_name}.txt", "w") as f:
    f.write(story_text)

# %%
def split_long_lines(filename, folder="scripts", max_length=80):
    # Open the file for reading
    with open(folder + "/" + filename, 'r') as file:
        lines = file.readlines()

    new_lines = []
    
    # Iterate through each line
    for line in lines:
        while len(line) > max_length:
            # Find the last space before the max_length
            split_index = line[:max_length].rfind(' ')
            if split_index == -1:
                split_index = max_length  # No space found, split at max_length
                
            # Append the portion of the line up to the split point
            new_lines.append(line[:split_index].strip() + '\n')
            
            # Continue processing the rest of the line
            line = line[split_index:].strip()
        
        new_lines.append(line + '\n')  # Add the rest of the line (if any) or short lines directly

    # remove any lines that are 'XXX'
    new_lines = [line for line in new_lines if line.strip() != 'XXX']
    
    # Write the modified lines back to the file or a new file
    with open(folder + '/split_' + filename, 'w') as file:
        file.writelines(new_lines)

# %%
split_long_lines(f'{story_name}.txt')

# %%
def remove_extra_newlines(filename, folder):
    # Open the file for reading
    with open(folder + "/" + filename, 'r') as file:
        lines = file.read()
    
    # Replace 3+ newlines with just 2 newlines
    cleaned_lines = re.sub(r'\n{3,}', '\n\n', lines)

    # Write the cleaned content back to the file (or a new file)
    with open(folder + "/" + filename, 'w') as file:
        file.write(cleaned_lines)

# %%
remove_extra_newlines(f'split_{story_name}.txt', 'scripts')

# %%
# rename files
# story_name.txt --> story_name_og.txt
# split_story_name.txt --> story_name.txt

os.rename(f"scripts/{story_name}.txt", f"scripts/{story_name}_og.txt")
os.rename(f"scripts/split_{story_name}.txt", f"scripts/{story_name}.txt")

# %% [markdown]
# ## get line numbers for each scene (after parsing-data.ipynb is run)

# %%
def get_scene_boundaries(text_file_path, line_file_path):
    # Read the main text file and find positions of "XXX"
    with open(text_file_path, 'r') as text_file:
        text_lines = text_file.readlines()
    
    # read file with line numbers
    with open(line_file_path, 'r') as line_file:
        line_numbers = line_file.readlines()
    
    # Gather start and end line numbers for each scene based on "XXX" markers
    scene_boundaries = []
    scene_start = 1  # Assuming line numbers start from 1
    for idx, line in enumerate(text_lines):
        if "XXX" in line:
            # find first line after "XXX" that is not empty
            next_line = text_lines[idx + 2][:50]

            # find line number in line_numbers file
            end_index = -1
            for i, line_num in enumerate(line_numbers):
                if next_line in line_num:
                    end_index = i + 1
                    scene_boundaries.append((scene_start, end_index - 1))
                    scene_start = end_index  # Set next scene start after "XXX"
                    idx += 3
                    break
    
    # add last scene boundary
    scene_boundaries.append((scene_start, len(line_numbers)))
    
    
    # Translate scene boundaries to line numbers
    # scene_line_numbers = [(line_numbers[start - 1], line_numbers[end - 1]) for start, end in scene_boundaries]
    
    return scene_boundaries

# %%
# Paths to your files
chapter_folder = f'chapters/{story_name}'              # Folder with chapter files
scripts_folder = f'scripts'                         # Folder with script files
text_file_path = f'{scripts_folder}/{story_name}_og.txt'  # File with main text and "XXX"

# read in story_outline.json
with open(f'json/{story_name}/story_outline.json', 'r') as file:
    story_outline = json.load(file)

chapters = story_outline['chapters']
scenes = story_outline['scenes']

chapter_lines = {}

for chapter in chapters:
    chapter_name = chapter['chapter']
    line_file_path = f'{chapter_folder}/{chapter_name}.txt'      # File with line numbers

    # Call the function and display results
    scene_line_numbers = get_scene_boundaries(text_file_path, line_file_path) 

    # Print scene line numbers
    print(chapter_name)
    for idx, (start, end) in enumerate(scene_line_numbers, 1):
        print(f"scene {idx}: starts at line {start}, ends at line {end}")
    print()

    chapter_lines[chapter_name] = scene_line_numbers
# Out:
# Chapter 1: The Last Days of Earth
# scene 1: starts at line 1, ends at line 51
# scene 2: starts at line 52, ends at line 100
#
# Chapter 2: The Fleet Assembles
# scene 1: starts at line 1, ends at line 36
# scene 2: starts at line 37, ends at line 65
# scene 3: starts at line 66, ends at line 91
# scene 4: starts at line 92, ends at line 118
# scene 5: starts at line 119, ends at line 143
#
# Chapter 3: The Void of Space
# scene 1: starts at line 1, ends at line 55
#
# Chapter 4: Echoes of the Past
# scene 1: starts at line 1, ends at line 50
# scene 2: starts at line 51, ends at line 98
# scene 3: starts at line 99, ends at line 147
# scene 4: starts at line 148, ends at line 98
# scene 5: starts at line 99, ends at line 233
#
# Chapter 5: The First Encounter
# scene 1: starts at line 1, ends at line 40
# scene 2: starts at line 41, ends at line 70
# scene 3: starts at line 71, ends at line 100
# scene 4: starts at line 101, ends at line 40
# scene 5: starts at line 41, ends at line 156
#
# Chapter 6: Divided Loyalties
# scene 1: starts at line 1, ends at line 65
#
# Chapter 7: The Lost Colony
# scene 1: starts at line 1, ends at line 70
#
# Chapter 8: A New Home?
# scene 1: starts at line 1, ends at line 34
# scene 2: starts at line 35, ends at line 61
# scene 3: starts at line 62, ends at line 87
# scene 4: starts at line 88, ends at line 112
# scene 5: starts at line 113, ends at line 141
#
# Chapter 9: The Great Divide
# scene 1: starts at line 1, ends at line 54
# scene 2: starts at line 55, ends at line 98
# scene 3: starts at line 99, ends at line 134
# scene 4: starts at line 135, ends at line 176
#
# Chapter 10: The Battle for Survival
# scene 1: starts at line 1, ends at line 42
# scene 2: starts at line 43, ends at line 75
# scene 3: starts at line 76, ends at line 102
# scene 4: starts at line 103, ends at line 135
#
# Chapter 11: Reflections in the Stars
# scene 1: starts at line 1, ends at line 33
# scene 2: starts at line 34, ends at line 72
# scene 3: starts at line 73, ends at line 104
# scene 4: starts at line 105, ends at line 137
# scene 5: starts at line 138, ends at line 174
#
# Chapter 12: A New Beginning
# scene 1: starts at line 1, ends at line 36
# scene 2: starts at line 37, ends at line 66
# scene 3: starts at line 67, ends at line 97
# scene 4: starts at line 98, ends at line 127

# %%
chapter_lines
# Out:
# {'Chapter 1: The Last Days of Earth': [(1, 51), (52, 100)],
#  'Chapter 2: The Fleet Assembles': [(1, 36),
#   (37, 65),
#   (66, 91),
#   (92, 118),
#   (119, 143)],
#  'Chapter 3: The Void of Space': [(1, 55)],
#  'Chapter 4: Echoes of the Past': [(1, 50),
#   (51, 98),
#   (99, 147),
#   (148, 98),
#   (99, 233)],
#  'Chapter 5: The First Encounter': [(1, 40),
#   (41, 70),
#   (71, 100),
#   (101, 40),
#   (41, 156)],
#  'Chapter 6: Divided Loyalties': [(1, 65)],
#  'Chapter 7: The Lost Colony': [(1, 70)],
#  'Chapter 8: A New Home?': [(1, 34),
#   (35, 61),
#   (62, 87),
#   (88, 112),
#   (113, 141)],
#  'Chapter 9: The Great Divide': [(1, 54), (55, 98), (99, 134), (135, 176)],
#  'Chapter 10: The Battle for Survival': [(1, 42),
#   (43, 75),
#   (76, 102),
#   (103, 135)],
#  'Chapter 11: Reflections in the Stars': [(1, 33),
#   (34, 72),
#   (73, 104),
#   (105, 137),
#   (138, 174)],
#  'Chapter 12: A New Beginning': [(1, 36), (37, 66), (67, 97), (98, 127)]}

# %%
# add "first_line" and "last_line" to each scene
for chapter in chapters:
    chapter_name = chapter['chapter']
    print(chapter_name)
    scene_line_numbers = chapter_lines[chapter_name]
    print(scene_line_numbers)
    scene_num = 0
    for i, scene in enumerate(scenes):
        compare_chapter = chapter_name
        if scene['chapter'] == compare_chapter:
            print(scene['chapter'], compare_chapter)
            print(scene_num)
            scene['first_line'] = scene_line_numbers[scene_num][0] 
            scene['last_line'] = scene_line_numbers[scene_num][1]
            scene_num += 1
# Out:
# Chapter 1: The Last Days of Earth
# [(1, 51), (52, 100)]
# Chapter 1: The Last Days of Earth Chapter 1: The Last Days of Earth
# 0
# Chapter 1: The Last Days of Earth Chapter 1: The Last Days of Earth
# 1
# Chapter 2: The Fleet Assembles
# [(1, 36), (37, 65), (66, 91), (92, 118), (119, 143)]
# Chapter 2: The Fleet Assembles Chapter 2: The Fleet Assembles
# 0
# Chapter 2: The Fleet Assembles Chapter 2: The Fleet Assembles
# 1
# Chapter 2: The Fleet Assembles Chapter 2: The Fleet Assembles
# 2
# Chapter 2: The Fleet Assembles Chapter 2: The Fleet Assembles
# 3
# Chapter 2: The Fleet Assembles Chapter 2: The Fleet Assembles
# 4
# Chapter 3: The Void of Space
# [(1, 55)]
# Chapter 3: The Void of Space Chapter 3: The Void of Space
# 0
# Chapter 4: Echoes of the Past
# [(1, 50), (51, 98), (99, 147), (148, 98), (99, 233)]
# Chapter 4: Echoes of the Past Chapter 4: Echoes of the Past
# 0
# Chapter 4: Echoes of the Past Chapter 4: Echoes of the Past
# 1
# Chapter 4: Echoes of the Past Chapter 4: Echoes of the Past
# 2
# Chapter 4: Echoes of the Past Chapter 4: Echoes of the Past
# 3
# Chapter 4: Echoes of the Past Chapter 4: Echoes of the Past
# 4
# Chapter 5: The First Encounter
# [(1, 40), (41, 70), (71, 100), (101, 40), (41, 156)]
# Chapter 5: The First Encounter Chapter 5: The First Encounter
# 0
# Chapter 5: The First Encounter Chapter 5: The First Encounter
# 1
# Chapter 5: The First Encounter Chapter 5: The First Encounter
# 2
# Chapter 5: The First Encounter Chapter 5: The First Encounter
# 3
# Chapter 5: The First Encounter Chapter 5: The First Encounter
# 4
# Chapter 6: Divided Loyalties
# [(1, 65)]
# Chapter 6: Divided Loyalties Chapter 6: Divided Loyalties
# 0
# Chapter 7: The Lost Colony
# [(1, 70)]
# Chapter 7: The Lost Colony Chapter 7: The Lost Colony
# 0
# Chapter 8: A New Home?
# [(1, 34), (35, 61), (62, 87), (88, 112), (113, 141)]
# Chapter 8: A New Home? Chapter 8: A New Home?
# 0
# Chapter 8: A New Home? Chapter 8: A New Home?
# 1
# Chapter 8: A New Home? Chapter 8: A New Home?
# 2
# Chapter 8: A New Home? Chapter 8: A New Home?
# 3
# Chapter 8: A New Home? Chapter 8: A New Home?
# 4
# Chapter 9: The Great Divide
# [(1, 54), (55, 98), (99, 134), (135, 176)]
# Chapter 9: The Great Divide Chapter 9: The Great Divide
# 0
# Chapter 9: The Great Divide Chapter 9: The Great Divide
# 1
# Chapter 9: The Great Divide Chapter 9: The Great Divide
# 2
# Chapter 9: The Great Divide Chapter 9: The Great Divide
# 3
# Chapter 10: The Battle for Survival
# [(1, 42), (43, 75), (76, 102), (103, 135)]
# Chapter 10: The Battle for Survival Chapter 10: The Battle for Survival
# 0
# Chapter 10: The Battle for Survival Chapter 10: The Battle for Survival
# 1
# Chapter 10: The Battle for Survival Chapter 10: The Battle for Survival
# 2
# Chapter 10: The Battle for Survival Chapter 10: The Battle for Survival
# 3
# Chapter 11: Reflections in the Stars
# [(1, 33), (34, 72), (73, 104), (105, 137), (138, 174)]
# Chapter 11: Reflections in the Stars Chapter 11: Reflections in the Stars
# 0
# Chapter 11: Reflections in the Stars Chapter 11: Reflections in the Stars
# 1
# Chapter 11: Reflections in the Stars Chapter 11: Reflections in the Stars
# 2
# Chapter 11: Reflections in the Stars Chapter 11: Reflections in the Stars
# 3
# Chapter 11: Reflections in the Stars Chapter 11: Reflections in the Stars
# 4
# Chapter 12: A New Beginning
# [(1, 36), (37, 66), (67, 97), (98, 127)]
# Chapter 12: A New Beginning Chapter 12: A New Beginning
# 0
# Chapter 12: A New Beginning Chapter 12: A New Beginning
# 1
# Chapter 12: A New Beginning Chapter 12: A New Beginning
# 2
# Chapter 12: A New Beginning Chapter 12: A New Beginning
# 3

# %%
scenes
# Out:
# [{'title': 'The Crumbling World',
#   'number': 1,
#   'summary': 'A panoramic view of Earth’s devastation as the last generation ships are being prepared for launch.',
#   'chapter': 'Chapter 1: The Last Days of Earth',
#   'location': 'Earth, various locations',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Narrator',
#     'role': 'Describes the environmental collapse and societal breakdown.',
#     'importance': 1.0,
#     'emotion': 'somber',
#     'sentiment': -1.0,
#     'importance_rank': 1},
#    {'name': 'Captain Elara',
#     'role': 'Oversees the final preparations for the fleet.',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Dr. Malik',
#     'role': 'Analyzes data on potential habitable planets.',
#     'importance': 1.0,
#     'emotion': 'anxious',
#     'sentiment': -1.0,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 1,
#   'last_line': 51},
#  {'title': 'The Farewell',
#   'number': 2,
#   'summary': 'Key characters say their goodbyes to loved ones and the Earth they are leaving behind.',
#   'chapter': 'Chapter 1: The Last Days of Earth',
#   'location': 'Launch site',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Bids farewell to her family and friends.',
#     'importance': 1.0,
#     'emotion': 'heartbroken',
#     'sentiment': -1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Reflects on his sacrifices and the weight of his mission.',
#     'importance': 1.0,
#     'emotion': 'regretful',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Various Families',
#     'role': 'Express their sorrow and hope as they part ways.',
#     'importance': 0.8,
#     'emotion': 'mixed',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 2,
#   'first_line': 52,
#   'last_line': 100},
#  {'title': 'The Gathering',
#   'number': 3,
#   'summary': "The generation ships arrive in orbit around Earth, each ship's crew preparing for departure.",
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'location': 'Orbit around Earth',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, overseeing the assembly of ships.',
#     'importance': 1.0,
#     'emotion': 'Determined',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Engineer Tessa',
#     'role': 'Struggling with her past while preparing her ship for launch.',
#     'importance': 1.0,
#     'emotion': 'Anxious',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Diplomat Rian',
#     'role': 'Trying to mediate between different ship crews to maintain peace.',
#     'importance': 1.0,
#     'emotion': 'Diplomatic',
#     'sentiment': 1.0,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 3,
#   'first_line': 1,
#   'last_line': 36},
#  {'title': 'Tensions Rise',
#   'number': 4,
#   'summary': 'Conflicts arise between different ship crews over resources and leadership.',
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'location': 'Fleet assembly area',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Trying to keep the peace among the crews.',
#     'importance': 1.0,
#     'emotion': 'Frustrated',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Engineer Tessa',
#     'role': 'Caught in the middle of a heated argument.',
#     'importance': 1.0,
#     'emotion': 'Conflicted',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Diplomat Rian',
#     'role': 'Working hard to negotiate a truce.',
#     'importance': 1.0,
#     'emotion': 'Stressed',
#     'sentiment': 0.0,
#     'importance_rank': 3},
#    {'name': 'Commander Jax',
#     'role': 'Leader of a rival ship, demanding more resources.',
#     'importance': 1.0,
#     'emotion': 'Aggressive',
#     'sentiment': -1.0,
#     'importance_rank': 4}],
#   'importance_rank': 2,
#   'conflict_rank': 1,
#   'first_line': 37,
#   'last_line': 65},
#  {'title': 'Alliances Form',
#   'number': 5,
#   'summary': 'Some crews begin to form alliances to strengthen their position.',
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'location': 'Fleet assembly area',
#   'importance': 1.0,
#   'conflict': 0.4,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Encouraging collaboration among the ships.',
#     'importance': 1.0,
#     'emotion': 'Hopeful',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Engineer Tessa',
#     'role': 'Finding common ground with another engineer.',
#     'importance': 1.0,
#     'emotion': 'Relieved',
#     'sentiment': 1.0,
#     'importance_rank': 2},
#    {'name': 'Diplomat Rian',
#     'role': 'Facilitating discussions between allied ships.',
#     'importance': 1.0,
#     'emotion': 'Optimistic',
#     'sentiment': 1.0,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 4,
#   'first_line': 66,
#   'last_line': 91},
#  {'title': 'Final Preparations',
#   'number': 6,
#   'summary': 'The crews make last-minute checks and preparations for launch.',
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'location': 'Docking bays of the ships',
#   'importance': 1.0,
#   'conflict': 0.3,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Conducting final inspections of the fleet.',
#     'importance': 1.0,
#     'emotion': 'Focused',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Engineer Tessa',
#     'role': 'Double-checking systems to ensure safety.',
#     'importance': 1.0,
#     'emotion': 'Nervous',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Diplomat Rian',
#     'role': 'Reassuring the crews before launch.',
#     'importance': 1.0,
#     'emotion': 'Calm',
#     'sentiment': 1.0,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 5,
#   'first_line': 92,
#   'last_line': 118},
#  {'title': 'Launch into the Unknown',
#   'number': 7,
#   'summary': 'The fleet launches, leaving Earth behind and venturing into space.',
#   'chapter': 'Chapter 2: The Fleet Assembles',
#   'location': 'Space, departing from Earth',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leading the fleet into the unknown.',
#     'importance': 1.0,
#     'emotion': 'Proud',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Engineer Tessa',
#     'role': 'Experiencing a mix of fear and excitement.',
#     'importance': 1.0,
#     'emotion': 'Excited',
#     'sentiment': 1.0,
#     'importance_rank': 2},
#    {'name': 'Diplomat Rian',
#     'role': 'Watching the launch with a sense of hope and dread.',
#     'importance': 1.0,
#     'emotion': 'Hopeful',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 2,
#   'first_line': 119,
#   'last_line': 143},
#  {'title': 'Navigating the Abyss',
#   'number': 8,
#   'summary': 'The fleet encounters a critical technical malfunction that threatens their journey.',
#   'chapter': 'Chapter 3: The Void of Space',
#   'location': 'Control Room of the flagship',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader trying to maintain order during the crisis',
#     'importance': 1.0,
#     'emotion': 'stressed and determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': "Challenging Elara's decisions and advocating for a different approach",
#     'importance': 1.0,
#     'emotion': 'frustrated and rebellious',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Engineer Mira',
#     'role': 'Trying to fix the malfunction while dealing with crew panic',
#     'importance': 0.8,
#     'emotion': 'anxious but focused',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 1,
#   'last_line': 55},
#  {'title': 'Scene 1: The Last Goodbye',
#   'number': 9,
#   'summary': 'Dr. Malik reflects on his final moments on Earth, saying goodbye to his family.',
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'location': "Earth, Dr. Malik's home",
#   'importance': 0.9,
#   'conflict': 0.6,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'A scientist who left Earth to save humanity',
#     'importance': 1.0,
#     'emotion': 'Sorrowful and regretful',
#     'sentiment': -0.8,
#     'importance_rank': 1},
#    {'name': "Malik's Family",
#     'role': 'Symbolizes what he lost',
#     'importance': 0.8,
#     'emotion': 'Heartbroken',
#     'sentiment': -0.9,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 1,
#   'last_line': 50},
#  {'title': "Scene 2: Tessa's Memories",
#   'number': 10,
#   'summary': 'Tessa recalls her childhood and the moments that led her to join the fleet.',
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'location': "Earth, Tessa's childhood home",
#   'importance': 0.8,
#   'conflict': 0.4,
#   'characters': [{'name': 'Tessa',
#     'role': 'A young engineer with dreams of exploration',
#     'importance': 1.0,
#     'emotion': 'Nostalgic and hopeful',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': "Tessa's Parents",
#     'role': 'Represent her motivation to leave Earth',
#     'importance': 0.7,
#     'emotion': 'Supportive but worried',
#     'sentiment': 0.1,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 3,
#   'first_line': 51,
#   'last_line': 98},
#  {'title': 'Scene 3: The Weight of Regret',
#   'number': 11,
#   'summary': 'The crew gathers to share their stories, revealing their regrets and fears.',
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'location': 'Common area of the generation ship',
#   'importance': 0.8,
#   'conflict': 0.5,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Facilitator of the discussion',
#     'importance': 0.9,
#     'emotion': 'Determined yet pained',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Participant sharing her story',
#     'importance': 0.8,
#     'emotion': 'Vulnerable',
#     'sentiment': -0.3,
#     'importance_rank': 2},
#    {'name': 'Crew Members',
#     'role': 'Represent diverse backgrounds and regrets',
#     'importance': 0.6,
#     'emotion': 'Mixed emotions',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 2,
#   'first_line': 99,
#   'last_line': 147},
#  {'title': 'Scene 4: Echoes in the Void',
#   'number': 12,
#   'summary': 'The crew listens to recordings from Earth, stirring deep emotions.',
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'location': "Ship's communication room",
#   'importance': 0.7,
#   'conflict': 0.3,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Analyzing the recordings',
#     'importance': 0.8,
#     'emotion': 'Haunted by memories',
#     'sentiment': -0.6,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Emotional response to the recordings',
#     'importance': 0.7,
#     'emotion': 'Overwhelmed',
#     'sentiment': -0.7,
#     'importance_rank': 2},
#    {'name': 'Crew Members',
#     'role': 'Reacting to the recordings',
#     'importance': 0.5,
#     'emotion': 'Reflective',
#     'sentiment': 0.1,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 5,
#   'first_line': 148,
#   'last_line': 98},
#  {'title': 'Scene 5: A New Resolve',
#   'number': 13,
#   'summary': 'After sharing their stories, the crew finds strength in unity and purpose.',
#   'chapter': 'Chapter 4: Echoes of the Past',
#   'location': 'Common area of the generation ship',
#   'importance': 0.9,
#   'conflict': 0.4,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Inspiring the crew to move forward',
#     'importance': 1.0,
#     'emotion': 'Hopeful',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Reinforcing the need for a new beginning',
#     'importance': 0.9,
#     'emotion': 'Determined',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Crew Members',
#     'role': 'United in their resolve',
#     'importance': 0.7,
#     'emotion': 'Empowered',
#     'sentiment': 0.7,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 4,
#   'first_line': 99,
#   'last_line': 233},
#  {'title': 'The Approach',
#   'number': 14,
#   'summary': 'The fleet detects an unknown vessel approaching, sparking curiosity and concern.',
#   'chapter': 'Chapter 5: The First Encounter',
#   'location': 'Bridge of the flagship',
#   'importance': 0.9,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, assessing the situation',
#     'importance': 1.0,
#     'emotion': 'anxious yet determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Diplomat Rian',
#     'role': 'Preparing for potential communication',
#     'importance': 1.0,
#     'emotion': 'excited but cautious',
#     'sentiment': 0.5,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 4,
#   'first_line': 1,
#   'last_line': 40},
#  {'title': 'First Contact',
#   'number': 15,
#   'summary': 'The fleet attempts to communicate with the alien vessel, leading to a breakthrough and confusion.',
#   'chapter': 'Chapter 5: The First Encounter',
#   'location': 'Communication room',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'characters': [{'name': 'Diplomat Rian',
#     'role': 'Translating signals and establishing contact',
#     'importance': 1.0,
#     'emotion': 'hopeful',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Captain Elara',
#     'role': 'Monitoring the communication process',
#     'importance': 1.0,
#     'emotion': 'tense',
#     'sentiment': -0.2,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 3,
#   'first_line': 41,
#   'last_line': 70},
#  {'title': 'Misunderstanding',
#   'number': 16,
#   'summary': 'A misinterpretation of signals leads to a standoff between the fleets.',
#   'chapter': 'Chapter 5: The First Encounter',
#   'location': 'Space between the two vessels',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Trying to de-escalate the situation',
#     'importance': 1.0,
#     'emotion': 'frustrated',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Alien Commander Zorak',
#     'role': 'Leader of the alien vessel, feeling threatened',
#     'importance': 1.0,
#     'emotion': 'defensive',
#     'sentiment': -0.6,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 2,
#   'first_line': 71,
#   'last_line': 100},
#  {'title': 'Tension Rises',
#   'number': 17,
#   'summary': 'The standoff escalates as both sides prepare for potential conflict.',
#   'chapter': 'Chapter 5: The First Encounter',
#   'location': 'Bridge of the flagship',
#   'importance': 0.8,
#   'conflict': 1.0,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Making critical decisions under pressure',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Diplomat Rian',
#     'role': 'Trying to find a peaceful solution',
#     'importance': 1.0,
#     'emotion': 'desperate',
#     'sentiment': -0.3,
#     'importance_rank': 2}],
#   'importance_rank': 5,
#   'conflict_rank': 1,
#   'first_line': 101,
#   'last_line': 40},
#  {'title': 'Resolution',
#   'number': 18,
#   'summary': 'A breakthrough in communication leads to a tentative truce and understanding.',
#   'chapter': 'Chapter 5: The First Encounter',
#   'location': 'Communication room',
#   'importance': 1.0,
#   'conflict': 0.4,
#   'characters': [{'name': 'Diplomat Rian',
#     'role': 'Facilitating the dialogue that leads to peace',
#     'importance': 1.0,
#     'emotion': 'relieved',
#     'sentiment': 0.8,
#     'importance_rank': 1},
#    {'name': 'Captain Elara',
#     'role': 'Acknowledging the importance of cooperation',
#     'importance': 1.0,
#     'emotion': 'hopeful',
#     'sentiment': 0.6,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 5,
#   'first_line': 41,
#   'last_line': 156},
#  {'title': 'Scene 1: The Gathering Storm',
#   'number': 19,
#   'summary': 'Tensions rise as factions begin to form within the fleet.',
#   'chapter': 'Chapter 6: Divided Loyalties',
#   'location': "Fleet's central command room",
#   'importance': 0.9,
#   'conflict': 0.8,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, trying to maintain order',
#     'importance': 1.0,
#     'emotion': 'stressed and determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': "Challenger to Elara's authority",
#     'importance': 1.0,
#     'emotion': 'frustrated and passionate',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Crew member caught in the middle',
#     'importance': 0.8,
#     'emotion': 'conflicted and anxious',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 1,
#   'last_line': 65},
#  {'title': 'Discovery of the Colony Ship',
#   'number': 20,
#   'summary': 'The fleet detects a distress signal from a derelict colony ship.',
#   'chapter': 'Chapter 7: The Lost Colony',
#   'location': 'Fleet Command Center',
#   'importance': 1.0,
#   'conflict': 0.6,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, makes the decision to investigate the signal.',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': 'Skeptical of the mission, worried about potential dangers.',
#     'importance': 0.8,
#     'emotion': 'anxious',
#     'sentiment': 0.0,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 1,
#   'last_line': 70},
#  {'title': 'Arrival at the New Planet',
#   'number': 21,
#   'summary': 'The fleet arrives at the new planet and begins initial scans.',
#   'chapter': 'Chapter 8: A New Home?',
#   'location': 'Bridge of the lead ship',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Reyes',
#     'role': 'Leader of the fleet, optimistic about the new planet',
#     'importance': 1.0,
#     'emotion': 'hopeful',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': "Chief scientist, skeptical about the planet's viability",
#     'importance': 1.0,
#     'emotion': 'cautious',
#     'sentiment': 0.0,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Crew member, excited about the potential for a new home',
#     'importance': 0.8,
#     'emotion': 'enthusiastic',
#     'sentiment': 1.0,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 5,
#   'first_line': 1,
#   'last_line': 34},
#  {'title': 'First Expedition',
#   'number': 22,
#   'summary': "Dr. Malik and Tessa lead the first expedition to explore the planet's surface.",
#   'chapter': 'Chapter 8: A New Home?',
#   'location': 'Surface of the new planet',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Leader of the expedition, focused on data collection',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Supportive team member, eager to discover',
#     'importance': 0.8,
#     'emotion': 'curious',
#     'sentiment': 1.0,
#     'importance_rank': 2},
#    {'name': 'Crew Member 1',
#     'role': 'Skeptical about the mission, voices concerns',
#     'importance': 0.6,
#     'emotion': 'worried',
#     'sentiment': -1.0,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 4,
#   'first_line': 35,
#   'last_line': 61},
#  {'title': 'Dangerous Discoveries',
#   'number': 23,
#   'summary': 'The team encounters dangerous wildlife and environmental hazards.',
#   'chapter': 'Chapter 8: A New Home?',
#   'location': 'Dense forest on the planet',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Trying to keep the team safe while gathering data',
#     'importance': 1.0,
#     'emotion': 'anxious',
#     'sentiment': -1.0,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Injured during an encounter with wildlife',
#     'importance': 0.9,
#     'emotion': 'fearful',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Crew Member 2',
#     'role': 'Panicking and urging retreat',
#     'importance': 0.7,
#     'emotion': 'terrified',
#     'sentiment': -1.0,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 2,
#   'first_line': 62,
#   'last_line': 87},
#  {'title': 'Divisions Among the Crew',
#   'number': 24,
#   'summary': "The findings from the expedition create divisions among the crew about the planet's viability.",
#   'chapter': 'Chapter 8: A New Home?',
#   'location': "Fleet's common area",
#   'importance': 1.0,
#   'conflict': 0.8,
#   'characters': [{'name': 'Captain Reyes',
#     'role': 'Trying to maintain morale and unity among the crew',
#     'importance': 1.0,
#     'emotion': 'frustrated',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Advocating for caution and further research',
#     'importance': 1.0,
#     'emotion': 'defensive',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Caught in the middle, trying to mediate',
#     'importance': 0.8,
#     'emotion': 'conflicted',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 4,
#   'conflict_rank': 3,
#   'first_line': 88,
#   'last_line': 112},
#  {'title': 'Shocking Revelation',
#   'number': 25,
#   'summary': "The chapter ends with a shocking revelation about the planet's true nature.",
#   'chapter': 'Chapter 8: A New Home?',
#   'location': 'Bridge of the lead ship',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Captain Reyes',
#     'role': 'Reacting to the revelation, feeling betrayed',
#     'importance': 1.0,
#     'emotion': 'shocked',
#     'sentiment': -1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Confirming the findings, feeling vindicated',
#     'importance': 1.0,
#     'emotion': 'grim',
#     'sentiment': -1.0,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Struggling to process the implications',
#     'importance': 0.9,
#     'emotion': 'dismayed',
#     'sentiment': -1.0,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 1,
#   'first_line': 113,
#   'last_line': 141},
#  {'title': 'The Discovery',
#   'number': 26,
#   'summary': "The fleet uncovers the planet's hostile environment, leading to panic and fear.",
#   'chapter': 'Chapter 9: The Great Divide',
#   'location': 'Observation Deck',
#   'importance': 1.0,
#   'conflict': 0.8,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, trying to maintain order',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': "Elara's second-in-command, skeptical of her decisions",
#     'importance': 1.0,
#     'emotion': 'frustrated',
#     'sentiment': -0.5,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Crew member caught in the chaos',
#     'importance': 0.8,
#     'emotion': 'anxious',
#     'sentiment': -0.3,
#     'importance_rank': 3}],
#   'importance_rank': 1,
#   'conflict_rank': 3,
#   'first_line': 1,
#   'last_line': 54},
#  {'title': 'The Faction Meeting',
#   'number': 27,
#   'summary': 'Elara and Jax present their survival strategies to the crew, igniting tensions.',
#   'chapter': 'Chapter 9: The Great Divide',
#   'location': 'Main Hall',
#   'importance': 1.0,
#   'conflict': 0.9,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Defending her vision for survival',
#     'importance': 1.0,
#     'emotion': 'passionate',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': "Challenging Elara's approach",
#     'importance': 1.0,
#     'emotion': 'defiant',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Mediator trying to keep peace',
#     'importance': 0.9,
#     'emotion': 'conflicted',
#     'sentiment': 0.0,
#     'importance_rank': 3},
#    {'name': 'Crew Members',
#     'role': 'Divided audience reacting to the proposals',
#     'importance': 0.7,
#     'emotion': 'divided',
#     'sentiment': 0.0,
#     'importance_rank': 5},
#    {'name': 'Dr. Mira',
#     'role': "Scientist supporting Elara's plan",
#     'importance': 0.8,
#     'emotion': 'hopeful',
#     'sentiment': 0.6,
#     'importance_rank': 4}],
#   'importance_rank': 2,
#   'conflict_rank': 2,
#   'first_line': 55,
#   'last_line': 98},
#  {'title': 'The Rift',
#   'number': 28,
#   'summary': 'The factions officially split, leading to emotional confrontations.',
#   'chapter': 'Chapter 9: The Great Divide',
#   'location': 'Docking Bay',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Heartbroken over the division',
#     'importance': 1.0,
#     'emotion': 'sorrowful',
#     'sentiment': -0.6,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': 'Feeling justified in his actions',
#     'importance': 1.0,
#     'emotion': 'triumphant',
#     'sentiment': 0.4,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Caught between friends, feeling lost',
#     'importance': 1.0,
#     'emotion': 'desperate',
#     'sentiment': -0.5,
#     'importance_rank': 3},
#    {'name': 'Crew Members',
#     'role': 'Choosing sides, creating tension',
#     'importance': 0.9,
#     'emotion': 'angry',
#     'sentiment': -0.7,
#     'importance_rank': 4}],
#   'importance_rank': 3,
#   'conflict_rank': 1,
#   'first_line': 99,
#   'last_line': 134},
#  {'title': 'The Aftermath',
#   'number': 29,
#   'summary': 'The emotional fallout of the split affects the entire fleet.',
#   'chapter': 'Chapter 9: The Great Divide',
#   'location': 'Common Area',
#   'importance': 1.0,
#   'conflict': 0.7,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Trying to rally her supporters',
#     'importance': 1.0,
#     'emotion': 'resolute',
#     'sentiment': 0.0,
#     'importance_rank': 1},
#    {'name': 'First Officer Jax',
#     'role': "Celebrating his new faction's independence",
#     'importance': 1.0,
#     'emotion': 'elated',
#     'sentiment': 0.5,
#     'importance_rank': 2},
#    {'name': 'Tessa',
#     'role': 'Reflecting on her choices and friendships',
#     'importance': 1.0,
#     'emotion': 'melancholic',
#     'sentiment': -0.4,
#     'importance_rank': 3},
#    {'name': 'Crew Members',
#     'role': 'Struggling with the new reality',
#     'importance': 0.8,
#     'emotion': 'conflicted',
#     'sentiment': -0.2,
#     'importance_rank': 4}],
#   'importance_rank': 4,
#   'conflict_rank': 4,
#   'first_line': 135,
#   'last_line': 176},
#  {'title': 'The Gathering Storm',
#   'number': 30,
#   'summary': 'Factions gather to discuss their grievances and demands.',
#   'chapter': 'Chapter 10: The Battle for Survival',
#   'location': 'Main Hall of the Fleet Ship',
#   'importance': 0.9,
#   'conflict': 0.7,
#   'characters': [{'name': 'Tessa',
#     'role': "A passionate advocate for her faction's needs",
#     'importance': 0.8,
#     'emotion': 'determined',
#     'sentiment': 0.5,
#     'importance_rank': 3},
#    {'name': 'Dr. Malik',
#     'role': 'The mediator trying to keep peace',
#     'importance': 0.9,
#     'emotion': 'anxious',
#     'sentiment': 0.2,
#     'importance_rank': 1},
#    {'name': 'Captain Reyes',
#     'role': 'The authoritative leader trying to maintain order',
#     'importance': 0.9,
#     'emotion': 'frustrated',
#     'sentiment': -0.3,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 4,
#   'first_line': 1,
#   'last_line': 42},
#  {'title': 'The First Skirmish',
#   'number': 31,
#   'summary': 'Tensions erupt into violence as factions clash over resources.',
#   'chapter': 'Chapter 10: The Battle for Survival',
#   'location': 'Resource Storage Bay',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Tessa',
#     'role': 'Defender of her friends and faction',
#     'importance': 1.0,
#     'emotion': 'fearless',
#     'sentiment': 0.4,
#     'importance_rank': 1},
#    {'name': 'Rico',
#     'role': 'A rival faction member leading the attack',
#     'importance': 0.8,
#     'emotion': 'angry',
#     'sentiment': -0.5,
#     'importance_rank': 3},
#    {'name': 'Dr. Malik',
#     'role': 'Trying to intervene and stop the fighting',
#     'importance': 0.9,
#     'emotion': 'desperate',
#     'sentiment': -0.2,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 43,
#   'last_line': 75},
#  {'title': 'The Turning Point',
#   'number': 32,
#   'summary': 'A critical moment where Tessa makes a brave decision.',
#   'chapter': 'Chapter 10: The Battle for Survival',
#   'location': 'Amidst the chaos of the battle',
#   'importance': 1.0,
#   'conflict': 1.0,
#   'characters': [{'name': 'Tessa',
#     'role': 'Taking a stand to protect her friends',
#     'importance': 1.0,
#     'emotion': 'heroic',
#     'sentiment': 0.6,
#     'importance_rank': 1},
#    {'name': 'Captain Reyes',
#     'role': 'Realizing the need for unity',
#     'importance': 0.8,
#     'emotion': 'determined',
#     'sentiment': 0.3,
#     'importance_rank': 2},
#    {'name': 'Rico',
#     'role': "Caught off guard by Tessa's bravery",
#     'importance': 0.7,
#     'emotion': 'surprised',
#     'sentiment': 0.0,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 2,
#   'first_line': 76,
#   'last_line': 102},
#  {'title': 'The Aftermath',
#   'number': 33,
#   'summary': 'The battle leaves the fleet in disarray and uncertainty.',
#   'chapter': 'Chapter 10: The Battle for Survival',
#   'location': 'Main Hall of the Fleet Ship',
#   'importance': 1.0,
#   'conflict': 0.8,
#   'characters': [{'name': 'Dr. Malik',
#     'role': 'Assessing the damage and loss of life',
#     'importance': 0.9,
#     'emotion': 'sorrowful',
#     'sentiment': -0.6,
#     'importance_rank': 1},
#    {'name': 'Tessa',
#     'role': 'Reflecting on the cost of the conflict',
#     'importance': 0.8,
#     'emotion': 'haunted',
#     'sentiment': -0.5,
#     'importance_rank': 3},
#    {'name': 'Captain Reyes',
#     'role': 'Trying to restore order and hope',
#     'importance': 0.9,
#     'emotion': 'resolute',
#     'sentiment': 0.1,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 3,
#   'first_line': 103,
#   'last_line': 135},
#  {'title': 'Scene 1: The Aftermath',
#   'number': 34,
#   'summary': 'The fleet assesses the damage and loss after the battle.',
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'location': 'Command Center',
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': "Leader reflecting on the battle's consequences",
#     'importance': 1.0,
#     'emotion': 'somber',
#     'sentiment': -0.5,
#     'importance_rank': 1},
#    {'name': 'Jax',
#     'role': 'Crew member grappling with guilt',
#     'importance': 1.0,
#     'emotion': 'remorseful',
#     'sentiment': -0.7,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 1,
#   'first_line': 1,
#   'last_line': 33},
#  {'title': 'Scene 2: A Moment of Silence',
#   'number': 35,
#   'summary': 'The crew holds a memorial for those lost in the conflict.',
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'location': 'Observation Deck',
#   'importance': 1.0,
#   'conflict': 0.2,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leading the memorial service',
#     'importance': 1.0,
#     'emotion': 'sorrowful',
#     'sentiment': -0.6,
#     'importance_rank': 1},
#    {'name': 'Jax',
#     'role': 'Struggling to find closure',
#     'importance': 1.0,
#     'emotion': 'tearful',
#     'sentiment': -0.8,
#     'importance_rank': 2},
#    {'name': 'Mira',
#     'role': 'Offering support to Jax',
#     'importance': 0.8,
#     'emotion': 'empathetic',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 2,
#   'conflict_rank': 5,
#   'first_line': 34,
#   'last_line': 72},
#  {'title': 'Scene 3: Conversations in the Dark',
#   'number': 36,
#   'summary': 'Characters share their thoughts and feelings about the future.',
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'location': 'Crew Quarters',
#   'importance': 1.0,
#   'conflict': 0.4,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Discussing the need for unity',
#     'importance': 1.0,
#     'emotion': 'determined',
#     'sentiment': 0.3,
#     'importance_rank': 1},
#    {'name': 'Jax',
#     'role': 'Expressing doubts about their mission',
#     'importance': 1.0,
#     'emotion': 'conflicted',
#     'sentiment': -0.4,
#     'importance_rank': 2},
#    {'name': 'Mira',
#     'role': 'Encouraging hope and resilience',
#     'importance': 1.0,
#     'emotion': 'optimistic',
#     'sentiment': 0.6,
#     'importance_rank': 3}],
#   'importance_rank': 3,
#   'conflict_rank': 3,
#   'first_line': 73,
#   'last_line': 104},
#  {'title': 'Scene 4: Reflections on Choices',
#   'number': 37,
#   'summary': 'Elara and Jax confront their past decisions and their impact on the crew.',
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'location': "Elara's Quarters",
#   'importance': 1.0,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Reflecting on her leadership choices',
#     'importance': 1.0,
#     'emotion': 'introspective',
#     'sentiment': -0.2,
#     'importance_rank': 1},
#    {'name': 'Jax',
#     'role': 'Acknowledging his mistakes',
#     'importance': 1.0,
#     'emotion': 'ashamed',
#     'sentiment': -0.6,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 2,
#   'first_line': 105,
#   'last_line': 137},
#  {'title': 'Scene 5: A New Vision',
#   'number': 38,
#   'summary': 'The crew comes together to discuss their vision for the future.',
#   'chapter': 'Chapter 11: Reflections in the Stars',
#   'location': 'Main Hall',
#   'importance': 1.0,
#   'conflict': 0.3,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Inspiring the crew with a new mission',
#     'importance': 1.0,
#     'emotion': 'hopeful',
#     'sentiment': 0.7,
#     'importance_rank': 1},
#    {'name': 'Jax',
#     'role': 'Voicing concerns but willing to contribute',
#     'importance': 1.0,
#     'emotion': 'cautiously optimistic',
#     'sentiment': 0.2,
#     'importance_rank': 2},
#    {'name': 'Mira',
#     'role': 'Facilitating the discussion',
#     'importance': 0.8,
#     'emotion': 'supportive',
#     'sentiment': 0.5,
#     'importance_rank': 3}],
#   'importance_rank': 5,
#   'conflict_rank': 4,
#   'first_line': 138,
#   'last_line': 174},
#  {'title': 'Unity in Diversity',
#   'number': 39,
#   'summary': 'The fleet gathers for a council meeting to discuss their future.',
#   'chapter': 'Chapter 12: A New Beginning',
#   'location': 'Main assembly hall of the flagship',
#   'importance': 1.0,
#   'conflict': 0.3,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Leader of the fleet, guiding the discussions',
#     'importance': 1.0,
#     'emotion': 'Determined',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Scientist advocating for sustainable practices',
#     'importance': 0.8,
#     'emotion': 'Hopeful',
#     'sentiment': 1.0,
#     'importance_rank': 3},
#    {'name': 'Commander Jax',
#     'role': 'Military leader concerned about security',
#     'importance': 0.7,
#     'emotion': 'Wary',
#     'sentiment': 0.0,
#     'importance_rank': 4},
#    {'name': 'Lina',
#     'role': 'Community organizer representing the civilians',
#     'importance': 0.9,
#     'emotion': 'Passionate',
#     'sentiment': 1.0,
#     'importance_rank': 2}],
#   'importance_rank': 1,
#   'conflict_rank': 3,
#   'first_line': 1,
#   'last_line': 36},
#  {'title': 'Building the Future',
#   'number': 40,
#   'summary': 'Teams are formed to start constructing the new settlement.',
#   'chapter': 'Chapter 12: A New Beginning',
#   'location': 'Surface of the new planet',
#   'importance': 1.0,
#   'conflict': 0.4,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Overseeing the construction efforts',
#     'importance': 1.0,
#     'emotion': 'Inspired',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Leading the environmental assessment team',
#     'importance': 0.8,
#     'emotion': 'Focused',
#     'sentiment': 1.0,
#     'importance_rank': 3},
#    {'name': 'Commander Jax',
#     'role': 'Ensuring safety protocols are followed',
#     'importance': 0.7,
#     'emotion': 'Protective',
#     'sentiment': 0.0,
#     'importance_rank': 4},
#    {'name': 'Lina',
#     'role': 'Motivating the workers and fostering teamwork',
#     'importance': 0.9,
#     'emotion': 'Encouraging',
#     'sentiment': 1.0,
#     'importance_rank': 2}],
#   'importance_rank': 2,
#   'conflict_rank': 2,
#   'first_line': 37,
#   'last_line': 66},
#  {'title': 'Facing Challenges Together',
#   'number': 41,
#   'summary': 'The fleet encounters unexpected obstacles during construction.',
#   'chapter': 'Chapter 12: A New Beginning',
#   'location': 'Construction site on the new planet',
#   'importance': 0.9,
#   'conflict': 0.5,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Resolving conflicts among team members',
#     'importance': 1.0,
#     'emotion': 'Calm',
#     'sentiment': 0.5,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Finding solutions to environmental issues',
#     'importance': 0.8,
#     'emotion': 'Stressed',
#     'sentiment': 0.0,
#     'importance_rank': 3},
#    {'name': 'Commander Jax',
#     'role': 'Dealing with security threats from wildlife',
#     'importance': 0.7,
#     'emotion': 'Alert',
#     'sentiment': -0.5,
#     'importance_rank': 4},
#    {'name': 'Lina',
#     'role': 'Mediating disputes and keeping morale high',
#     'importance': 0.9,
#     'emotion': 'Optimistic',
#     'sentiment': 1.0,
#     'importance_rank': 2}],
#   'importance_rank': 4,
#   'conflict_rank': 1,
#   'first_line': 67,
#   'last_line': 97},
#  {'title': 'A Ceremony of Hope',
#   'number': 42,
#   'summary': 'The fleet holds a ceremony to celebrate their new beginning.',
#   'chapter': 'Chapter 12: A New Beginning',
#   'location': 'Central plaza of the new settlement',
#   'importance': 1.0,
#   'conflict': 0.2,
#   'characters': [{'name': 'Captain Elara',
#     'role': 'Delivering a speech about unity and hope',
#     'importance': 1.0,
#     'emotion': 'Uplifted',
#     'sentiment': 1.0,
#     'importance_rank': 1},
#    {'name': 'Dr. Malik',
#     'role': 'Sharing scientific insights about their new home',
#     'importance': 0.8,
#     'emotion': 'Excited',
#     'sentiment': 1.0,
#     'importance_rank': 3},
#    {'name': 'Commander Jax',
#     'role': 'Acknowledging the sacrifices made during the journey',
#     'importance': 0.7,
#     'emotion': 'Reflective',
#     'sentiment': 0.0,
#     'importance_rank': 4},
#    {'name': 'Lina',
#     'role': 'Leading the community in celebration',
#     'importance': 0.9,
#     'emotion': 'Joyful',
#     'sentiment': 1.0,
#     'importance_rank': 2}],
#   'importance_rank': 3,
#   'conflict_rank': 4,
#   'first_line': 98,
#   'last_line': 127}]

# %%
# update json file
with open(f'json/{story_name}/story_outline.json', 'w') as file:
    json.dump(story_outline, file, indent=4)
